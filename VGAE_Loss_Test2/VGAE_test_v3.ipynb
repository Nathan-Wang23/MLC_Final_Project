# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import os
import numpy as np
from torch_geometric.nn import global_add_pool, GATConv, CGConv, VGAE,GCNConv, RGCNConv, global_mean_pool
import pickle
from itertools import combinations
from sklearn.model_selection import train_test_split
from torch_geometric.data import DataLoader, Data
from torch.utils.data import Dataset, DataLoader
from torch_geometric.data import Data, Batch
from tqdm import tqdm
import torch.optim as optim
import math
from torch_geometric.data import DataLoader
from torch_geometric.nn import RGCNConv, global_mean_pool
from torch_geometric.data import Data, Batch
from torch.utils.data import Dataset, DataLoader
import pickle
from torch.optim import Adam, RMSprop
from tqdm import tqdm
from rdkit.Chem.rdMolDescriptors import CalcMolFormula
import pandas as pd
import pickle

# %%
from contextlib import contextmanager
import sys
import os
import torch
from ase import Atoms
from ase.data import chemical_symbols
from ase.calculators.morse import MorsePotential
from ase.optimize import QuasiNewton
import numpy as np
import pickle
from rdkit.Chem import rdchem

import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from ase import Atoms
from ase.io import read
from torch_geometric.data import Data
from torch_geometric.nn import MessagePassing
from torch_geometric.utils import to_networkx
# from torch_geometric.data import DataLoader, TensorDataset
from torch_geometric.loader import DataLoader
from sklearn.model_selection import train_test_split
from ase.build import molecule
import pandas as pd
from rdkit import Chem
from rdkit.Chem import AllChem
import random
from torch_geometric.nn import global_add_pool, GATConv, CGConv, GCNConv, RGCNConv
from torch_geometric.nn.models.schnet import GaussianSmearing
from sklearn.metrics import roc_auc_score, precision_score, confusion_matrix
import matplotlib.pyplot as plt
import pickle
from collections import Counter
import seaborn as sns
import time
from torch.optim.lr_scheduler import StepLR
import torch
from torch_geometric.data import Data

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %%
def debug_nan(tensor, name="Tensor"):
    if torch.isnan(tensor).any():
        print(f"NaN detected in {name}")
        print(tensor)

# %%
class RGCN_VGAE(nn.Module):
    def __init__(self, in_channels, out_channels, num_relations, num_node_features, max_nodes, bond_dim, atom_dim):
        super(RGCN_VGAE, self).__init__()
        self.num_relations = num_relations
        self.max_nodes = max_nodes
        self.atom_dim = atom_dim
        self.bond_dim = bond_dim

        self.rgcn1 = RGCNConv(in_channels, out_channels, num_relations=num_relations)
        self.rgcn2 = RGCNConv(out_channels, out_channels, num_relations=num_relations)
        # self.rgcn3 = RGCNConv(out_channels, out_channels, num_relations=num_relations)

        self.fc_mu = nn.Linear(out_channels, out_channels)
        self.fc_logvar = nn.Linear(out_channels, out_channels)

        self.adj_decoder = nn.Sequential(
            nn.Linear(out_channels, out_channels),
            nn.ReLU(),
            nn.Linear(out_channels, max_nodes * max_nodes * bond_dim)
        )
        self.feature_decoder = nn.Linear(out_channels, max_nodes * atom_dim)

    def reparameterize(self, mu, logvar):
        if self.training:
            std = torch.exp(0.5 * logvar)
            eps = torch.randn_like(std)
            return eps.mul(std).add_(mu)
        else:
            return mu

    def forward(self, data):
        x, edge_index, edge_attr, batch = data.x, data.edge_index, data.edge_attr, data.batch
        edge_attr = torch.argmax(edge_attr, dim=1).long()

        # print(x.shape)
        # print(edge_index.shape)
        # print(edge_attr.shape)
        x = F.relu(self.rgcn1(x, edge_index, edge_attr))
        x = F.relu(self.rgcn2(x, edge_index, edge_attr))
        # x = F.relu(self.rgcn3(x, edge_index, edge_attr))
        x = global_mean_pool(x, batch)

        mu = self.fc_mu(x)
        logvar = self.fc_logvar(x)

        z = self.reparameterize(mu, logvar)
        print(z.shape)
        A_pred = self.adj_decoder(z).view(-1, self.max_nodes, self.max_nodes, self.bond_dim)
        A_pred = F.softmax(A_pred, dim=-1)

        features_pred = self.feature_decoder(z).view(-1, self.max_nodes, self.atom_dim)
        features_pred = F.softmax(features_pred, dim=-1)

        return A_pred, features_pred, mu, logvar

    def decode(self, z):
        A_pred = self.adj_decoder(z).view(-1, self.max_nodes, self.max_nodes, self.bond_dim)
        A_pred = F.softmax(A_pred, dim=-1)

        features_pred = self.feature_decoder(z).view(-1, self.max_nodes, self.atom_dim)
        features_pred = F.softmax(features_pred, dim=-1)

        return A_pred, features_pred

# %%
# with open("../data/combined_data.pkl", "rb") as file:
#     combined_data = pickle.load(file)

atomic_number_tensors = torch.load("data/atomic_number_tensors.pt")
bond_tensors = torch.load("data/bond_tensors.pt")

# %%
NUM_ATOMS = 63
ATOM_DIM = 11
BOND_DIM = 5
LATENT_DIM = 512
HIDDEN_CHANNELS = 256
NUM_RELATION_TYPES = BOND_DIM - 1
NODE_FEATURE_DIM = ATOM_DIM - 1
# NODE_FEATURE_DIM = ATOM_DIM
BATCH_SIZE = 512
NUM_EPOCHS = 300

# %%
model = RGCN_VGAE(NODE_FEATURE_DIM, LATENT_DIM, NUM_RELATION_TYPES, NODE_FEATURE_DIM, NUM_ATOMS, BOND_DIM, ATOM_DIM).to(device)

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=0.0007)
#0.0001

# %%
class GraphDataset(Dataset):
    def __init__(self, adjacency_matrices, atom_features):
        self.adjacency_matrices = adjacency_matrices
        self.atom_features = atom_features

    def __len__(self):
        return self.adjacency_matrices.size(0)

    def __getitem__(self, idx):
        return self.adjacency_matrices[idx], self.atom_features[idx]

dataset = GraphDataset(bond_tensors, atomic_number_tensors)

dataloader = DataLoader(dataset, batch_size=BATCH_SIZE, shuffle=True)

# %%
weights_atoms = torch.ones(ATOM_DIM).to(device)
weights_bonds = torch.ones(BOND_DIM).to(device)

weights_atoms[0] = 0.5
weights_atoms[10] = 8
weights_bonds[4] = 0.5

weights_atoms.to(device)
weights_bonds.to(device)

def calculate_kl_divergence(mu, logvar):
    kl_divergence = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp())
    return kl_divergence

# def calculate_uniqueness_loss(bonds_pred, atoms_pred):
#     datapoints = process_graph_data_to_data_objects(bonds_pred, atoms_pred)
#     num_unique = 0
#     seen_set = set()
#     for dp in datapoints:
#         mol, formula = to_chemula(dp)
#         if formula not in seen_set:
#             num_unique += 1
#             seen_set.add(formula)
#     return num_unique

def loss_function(preds, labels, mu, logvar, preds_atomic, atomic_numbers, lambda_kld, device):

    batch_size = preds.shape[0]
    labels = torch.argmax(labels, dim=-1)
    atomic_numbers = torch.argmax(atomic_numbers, dim=-1)
    preds, labels = preds.to(device), labels.to(device)
    preds_atomic, atomic_numbers = preds_atomic.to(device), atomic_numbers.to(device)
    mu, logvar = mu.to(device), logvar.to(device)

    # print(preds.shape)
    # print(labels.shape)
    # print(preds_atomic.shape)
    # print(atomic_numbers.shape)

    ce_bond = F.cross_entropy(preds.view(-1, preds.size(-1)), labels.view(-1), weight=weights_bonds.to(device))
    ce_atomic = F.cross_entropy(preds_atomic.view(-1, preds_atomic.size(-1)), atomic_numbers.view(-1), weight=weights_atoms.to(device))

    kld = calculate_kl_divergence(mu, logvar)

    atom_presence_mask = torch.argmax(preds_atomic, dim=-1) != 10
    atom_count = torch.sum(atom_presence_mask)
    atom_count = atom_count / batch_size
    atomic_regulizer = atom_count / batch_size * 3


    bond_presence_mask = torch.argmax(preds, dim=-1) != 4
    bond_count = torch.sum(bond_presence_mask)
    bond_count = bond_count / batch_size

    if int(atom_count) <= 50:
        print(atom_count)
        atomic_regulizer = 2000 - 10 * int(atom_count)

    if bond_count < 100:
        bond_regulizer = 0.0
    elif bond_count <= 50:
        bond_regulizer = 2000 - 5 * bond_count
    else:
        bond_regulizer = 10

    # unique_counts = set()

    # for b in preds_atomic:
    #     atom_counts = np.zeros(11, dtype=int)
    #     for j in range(63):
    #         for k in range(11):
    #             if b[j, k] == 1:
    #                 atom_counts[k] += 1
    #     counts_tuple = tuple(atom_counts)
    #     unique_counts.add(counts_tuple)

    # num_same = len(unique_counts)
    # print(num_same)

    total_loss = 0.4 * ce_bond + lambda_kld * kld + 1.9 * ce_atomic + 0.6 * atomic_regulizer + 0.2 * bond_regulizer

    print(kld, ce_atomic, ce_bond, atomic_regulizer, bond_regulizer)
    return total_loss

# %%
def process_graph_data_to_data_objects(batch_adjacency, batch_atoms, grad = False):
    batch_size = batch_adjacency.shape[0]
    num_nodes = batch_adjacency.shape[1]
    num_bond_types = batch_adjacency.shape[3] - 1
    num_atom_types = batch_atoms.shape[2] - 1
    # print(num_atom_types)

    data_objects = []

    for idx in range(batch_size):
        edge_index = []
        edge_attr = []
        x = []
        node_index_map = {}

        adjacency = batch_adjacency[idx]
        atoms = batch_atoms[idx]

        new_idx = 0

        for i in range(num_nodes):
            for j in range(i + 1, num_nodes):
                bond_type = torch.argmax(adjacency[i, j])
                # if adjacency[i,j][num_bond_types] > 0.18:
                #     # print('overwrite')
                    # continue
                if bond_type < num_bond_types:  # Bond exists
                    atom_type_i = torch.argmax(atoms[i])
                    atom_type_j = torch.argmax(atoms[j])
                    if atom_type_i == num_atom_types or atom_type_j == num_atom_types: # Both atoms must exist
                        continue
                    if i not in node_index_map:
                        node_index_map[i] = new_idx
                        new_idx+=1
                        x.append(torch.nn.functional.one_hot(torch.argmax(atoms[i]), num_classes=num_atom_types).float())
                    if j not in node_index_map:
                        node_index_map[j] = new_idx
                        new_idx+=1
                        x.append(torch.nn.functional.one_hot(torch.argmax(atoms[j]), num_classes=num_atom_types).float())
                    edge_index.append([node_index_map[i], node_index_map[j]])
                    bond_one_hot = torch.zeros(num_bond_types)
                    bond_one_hot[bond_type] = 1
                    edge_attr.append(bond_one_hot)
                    # print(bond_type)
                    # edge_attr.append(bond_type/num_bond_types)

        if edge_index:
            edge_index_tensor = torch.tensor(edge_index, dtype=torch.long).t().contiguous()
            edge_attr_tensor = torch.stack(edge_attr, dim=0)

        else:

            edge_index_tensor = torch.empty((2, 0), dtype=torch.long)
            edge_attr_tensor = torch.empty((0, num_bond_types), dtype=torch.float)


        if x:
            node_features_tensor = torch.stack(x, dim=0)
        else:
            node_features_tensor = torch.empty((0, num_atom_types), dtype=torch.float)


        # if grad:
        #     node_features_tensor.requires_grad_(True)
        #     edge_attr.requires_grad_(True)
        graph_data = Data(x=node_features_tensor, edge_index=edge_index_tensor, edge_attr=edge_attr_tensor, adj_matrix=adjacency, node_features=atoms)
        data_objects.append(graph_data)

    return data_objects

# %%
data_dataset = []
for adj_matrix, node_features in dataloader:
    adj_matrix.to(device)
    node_features.to(device)
    print(adj_matrix.shape, node_features.shape)
    data = process_graph_data_to_data_objects(adj_matrix, node_features)
    data_dataset.append(data)

data_object_loader = DataLoader(data_dataset, batch_size=BATCH_SIZE, shuffle=True)
# Out:
# torch.Size([512, 63, 63, 5]) torch.Size([512, 63, 11])
# torch.Size([512, 63, 63, 5]) torch.Size([512, 63, 11])
# torch.Size([512, 63, 63, 5]) torch.Size([512, 63, 11])
# torch.Size([512, 63, 63, 5]) torch.Size([512, 63, 11])
# torch.Size([512, 63, 63, 5]) torch.Size([512, 63, 11])
# torch.Size([512, 63, 63, 5]) torch.Size([512, 63, 11])
# torch.Size([136, 63, 63, 5]) torch.Size([136, 63, 11])

# %%
# def collate(batch):
#     return Batch.from_data_list(batch)

# %%
# data_object_loader = DataLoader(data_dataset, batch_size=BATCH_SIZE, shuffle=True, collate_fn=collate)

# %%
# for b in data_object_loader:
#     print(b)
#     break


# print(len(data_dataset))

# %%
num_epochs = 1000
for epoch in range(num_epochs):
    total_loss = 0
    #lambda_kld = min(1.0, 0.01 +  epoch/ num_epochs)
    lambda_kld = 1.5
    batch_count = 0
    for data in data_object_loader:

        # print(adj_matrix.shape)
        optimizer.zero_grad()

        # adj_matrix.to(device)
        # node_features.to(device)

        # data = process_graph_data_to_data_objects(adj_matrix, node_features)
        data = Batch.from_data_list(data).to(device)
        print(data)
        reconstructed, reconstructed_atoms, mu, logvar = model(data)

        loss = loss_function(
            reconstructed, data.adj_matrix,
            mu, logvar,
            reconstructed_atoms, data.node_features,
            lambda_kld, device
        )
        total_loss += loss.item()

        # Backpropagation
        loss.backward()
        optimizer.step()

        #for name, param in model.named_parameters():
        #    if param.requires_grad:
        #        print(f"Gradients of {name}: {param.grad}")

    # Calculate average loss for reporting
    avg_loss = total_loss / len(dataloader)
    print(f'Epoch {epoch + 1}, Loss: {loss.item()}')
# Out:
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(449.2181, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3983, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.6101, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.1799, device='cuda:0') 10
# Epoch 1, Loss: 681.1358642578125
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(202.2115, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3976, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.5832, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.1790, device='cuda:0') 10
# Epoch 2, Loss: 310.6134338378906
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(106.5733, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3977, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.5537, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.1784, device='cuda:0') 10
# Epoch 3, Loss: 167.14418029785156
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(69.1280, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3971, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.5212, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.1778, device='cuda:0') 10
# Epoch 4, Loss: 110.96160888671875
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(49.3759, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3964, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.4859, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.1770, device='cuda:0') 10
# Epoch 5, Loss: 81.31764221191406
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(33.8799, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3951, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.4467, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.1754, device='cuda:0') 10
# Epoch 6, Loss: 58.05450439453125
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(24.1485, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3946, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.4053, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.1745, device='cuda:0') 0.0
# Epoch 7, Loss: 41.43928146362305
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(19.4281, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3937, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.3636, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.1738, device='cuda:0') 0.0
# Epoch 8, Loss: 34.339988708496094
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(16.8133, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3927, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.3182, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.1723, device='cuda:0') 0.0
# Epoch 9, Loss: 30.396730422973633
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(14.5694, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3922, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.2733, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.1711, device='cuda:0') 0.0
# Epoch 10, Loss: 27.01128387451172
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(12.8135, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3914, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.2301, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.1699, device='cuda:0') 0.0
# Epoch 11, Loss: 24.3579158782959
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(11.6811, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3908, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.1917, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.1693, device='cuda:0') 0.0
# Epoch 12, Loss: 22.642295837402344
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(10.5881, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3891, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.1502, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.1676, device='cuda:0') 0.0
# Epoch 13, Loss: 20.98200035095215
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(9.3229, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3883, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.1156, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.1665, device='cuda:0') 0.0
# Epoch 14, Loss: 19.068368911743164
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(8.3099, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3876, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.0804, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.1661, device='cuda:0') 0.0
# Epoch 15, Loss: 17.53314781188965
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(7.6318, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3865, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.0513, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.1647, device='cuda:0') 0.0
# Epoch 16, Loss: 16.501401901245117
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(6.9429, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3859, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.0304, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.1635, device='cuda:0') 0.0
# Epoch 17, Loss: 15.45776081085205
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(6.2174, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3847, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.0097, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.1621, device='cuda:0') 0.0
# Epoch 18, Loss: 14.358211517333984
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(5.6418, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3842, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9941, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.1610, device='cuda:0') 0.0
# Epoch 19, Loss: 13.486808776855469
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(50.8487, device='cuda:0')
# tensor(5.1158, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3828, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9798, device='cuda:0', grad_fn=<NllLossBackward0>) 1500 0.0
# Epoch 20, Loss: 912.5929565429688
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(50.3382, device='cuda:0')
# tensor(4.5428, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3812, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9694, device='cuda:0', grad_fn=<NllLossBackward0>) 1500 0.0
# Epoch 21, Loss: 911.72607421875
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(49.9622, device='cuda:0')
# tensor(4.0904, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3804, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9612, device='cuda:0', grad_fn=<NllLossBackward0>) 1510 0.0
# Epoch 22, Loss: 917.0426635742188
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(49.7763, device='cuda:0')
# tensor(3.7791, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3791, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9539, device='cuda:0', grad_fn=<NllLossBackward0>) 1510 0.0
# Epoch 23, Loss: 916.5703735351562
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(49.4160, device='cuda:0')
# tensor(3.4463, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3786, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9490, device='cuda:0', grad_fn=<NllLossBackward0>) 1510 0.0
# Epoch 24, Loss: 916.0682983398438
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(49.1292, device='cuda:0')
# tensor(3.1286, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3774, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9442, device='cuda:0', grad_fn=<NllLossBackward0>) 1510 0.0
# Epoch 25, Loss: 915.587646484375
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(48.6712, device='cuda:0')
# tensor(2.9248, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3759, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9408, device='cuda:0', grad_fn=<NllLossBackward0>) 1520 0.0
# Epoch 26, Loss: 921.2777709960938
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(48.5063, device='cuda:0')
# tensor(2.7405, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3757, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9383, device='cuda:0', grad_fn=<NllLossBackward0>) 1520 0.0
# Epoch 27, Loss: 921.0
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(48.2027, device='cuda:0')
# tensor(2.5432, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3744, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9359, device='cuda:0', grad_fn=<NllLossBackward0>) 1520 0.0
# Epoch 28, Loss: 920.700439453125
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(47.6817, device='cuda:0')
# tensor(2.4201, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3732, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9338, device='cuda:0', grad_fn=<NllLossBackward0>) 1530 0.0
# Epoch 29, Loss: 926.5126953125
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(47.3309, device='cuda:0')
# tensor(2.3172, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3721, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9324, device='cuda:0', grad_fn=<NllLossBackward0>) 1530 0.0
# Epoch 30, Loss: 926.3558349609375
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(47.4139, device='cuda:0')
# tensor(2.1855, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3724, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9312, device='cuda:0', grad_fn=<NllLossBackward0>) 1530 0.0
# Epoch 31, Loss: 926.1582641601562
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(46.8687, device='cuda:0')
# tensor(2.0911, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3708, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9303, device='cuda:0', grad_fn=<NllLossBackward0>) 1540 0.0
# Epoch 32, Loss: 932.0132446289062
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(46.3151, device='cuda:0')
# tensor(2.0033, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3681, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9292, device='cuda:0', grad_fn=<NllLossBackward0>) 1540 0.0
# Epoch 33, Loss: 931.8759765625
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(46.2626, device='cuda:0')
# tensor(1.8783, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3674, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9284, device='cuda:0', grad_fn=<NllLossBackward0>) 1540 0.0
# Epoch 34, Loss: 931.6868286132812
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(46.1113, device='cuda:0')
# tensor(1.7836, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3661, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9279, device='cuda:0', grad_fn=<NllLossBackward0>) 1540 0.0
# Epoch 35, Loss: 931.5420532226562
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(45.6303, device='cuda:0')
# tensor(1.7081, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3649, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9273, device='cuda:0', grad_fn=<NllLossBackward0>) 1550 0.0
# Epoch 36, Loss: 937.4263305664062
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(45.5179, device='cuda:0')
# tensor(1.6156, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3651, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9269, device='cuda:0', grad_fn=<NllLossBackward0>) 1550 0.0
# Epoch 37, Loss: 937.2879028320312
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(45.2185, device='cuda:0')
# tensor(1.5437, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3634, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9264, device='cuda:0', grad_fn=<NllLossBackward0>) 1550 0.0
# Epoch 38, Loss: 937.176513671875
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(44.9464, device='cuda:0')
# tensor(1.4749, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3626, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9261, device='cuda:0', grad_fn=<NllLossBackward0>) 1560 0.0
# Epoch 39, Loss: 943.0716552734375
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(44.6954, device='cuda:0')
# tensor(1.3915, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3607, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9258, device='cuda:0', grad_fn=<NllLossBackward0>) 1560 0.0
# Epoch 40, Loss: 942.9428100585938
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(44.3582, device='cuda:0')
# tensor(1.3342, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3584, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9255, device='cuda:0', grad_fn=<NllLossBackward0>) 1560 0.0
# Epoch 41, Loss: 942.8524780273438
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(44.1229, device='cuda:0')
# tensor(1.2851, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3579, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9254, device='cuda:0', grad_fn=<NllLossBackward0>) 1560 0.0
# Epoch 42, Loss: 942.7778930664062
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(44.0263, device='cuda:0')
# tensor(1.2328, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3574, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9253, device='cuda:0', grad_fn=<NllLossBackward0>) 1560 0.0
# Epoch 43, Loss: 942.6983032226562
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(43.7258, device='cuda:0')
# tensor(1.1980, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3551, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9251, device='cuda:0', grad_fn=<NllLossBackward0>) 1570 0.0
# Epoch 44, Loss: 948.6416625976562
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(43.3834, device='cuda:0')
# tensor(1.1579, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3536, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9250, device='cuda:0', grad_fn=<NllLossBackward0>) 1570 0.0
# Epoch 45, Loss: 948.5785522460938
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(42.8319, device='cuda:0')
# tensor(1.1169, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3514, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9249, device='cuda:0', grad_fn=<NllLossBackward0>) 1580 0.0
# Epoch 46, Loss: 954.5130615234375
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(42.9737, device='cuda:0')
# tensor(1.0874, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3516, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9248, device='cuda:0', grad_fn=<NllLossBackward0>) 1580 0.0
# Epoch 47, Loss: 954.4689331054688
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(42.5840, device='cuda:0')
# tensor(1.0494, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3492, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9247, device='cuda:0', grad_fn=<NllLossBackward0>) 1580 0.0
# Epoch 48, Loss: 954.407470703125
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(42.9401, device='cuda:0')
# tensor(1.0163, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3496, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9247, device='cuda:0', grad_fn=<NllLossBackward0>) 1580 0.0
# Epoch 49, Loss: 954.358642578125
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(42.3708, device='cuda:0')
# tensor(0.9872, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3477, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9246, device='cuda:0', grad_fn=<NllLossBackward0>) 1580 0.0
# Epoch 50, Loss: 954.3112182617188
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(42.2605, device='cuda:0')
# tensor(0.9538, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3480, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9246, device='cuda:0', grad_fn=<NllLossBackward0>) 1580 0.0
# Epoch 51, Loss: 954.2618408203125
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(41.8382, device='cuda:0')
# tensor(0.9283, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3442, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9246, device='cuda:0', grad_fn=<NllLossBackward0>) 1590 0.0
# Epoch 52, Loss: 960.2163696289062
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(41.9821, device='cuda:0')
# tensor(0.9003, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3447, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9246, device='cuda:0', grad_fn=<NllLossBackward0>) 1590 0.0
# Epoch 53, Loss: 960.1752319335938
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(41.6807, device='cuda:0')
# tensor(0.8734, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3438, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9245, device='cuda:0', grad_fn=<NllLossBackward0>) 1590 0.0
# Epoch 54, Loss: 960.1332397460938
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(41.7353, device='cuda:0')
# tensor(0.8527, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3425, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9245, device='cuda:0', grad_fn=<NllLossBackward0>) 1590 0.0
# Epoch 55, Loss: 960.0995483398438
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(41.4328, device='cuda:0')
# tensor(0.8303, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3405, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9245, device='cuda:0', grad_fn=<NllLossBackward0>) 1590 0.0
# Epoch 56, Loss: 960.0621337890625
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(40.8908, device='cuda:0')
# tensor(0.8132, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3368, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9245, device='cuda:0', grad_fn=<NllLossBackward0>) 1600 0.0
# Epoch 57, Loss: 966.029541015625
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(40.8246, device='cuda:0')
# tensor(0.7959, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3365, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9245, device='cuda:0', grad_fn=<NllLossBackward0>) 1600 0.0
# Epoch 58, Loss: 966.0029296875
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(40.6229, device='cuda:0')
# tensor(0.7782, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3344, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9245, device='cuda:0', grad_fn=<NllLossBackward0>) 1600 0.0
# Epoch 59, Loss: 965.9725341796875
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(40.6786, device='cuda:0')
# tensor(0.7632, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3361, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9244, device='cuda:0', grad_fn=<NllLossBackward0>) 1600 0.0
# Epoch 60, Loss: 965.9531860351562
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(40.2899, device='cuda:0')
# tensor(0.7453, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3331, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9244, device='cuda:0', grad_fn=<NllLossBackward0>) 1600 0.0
# Epoch 61, Loss: 965.920654296875
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(40.4527, device='cuda:0')
# tensor(0.7300, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3329, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9244, device='cuda:0', grad_fn=<NllLossBackward0>) 1600 0.0
# Epoch 62, Loss: 965.897216796875
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(40.1250, device='cuda:0')
# tensor(0.7147, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3302, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9244, device='cuda:0', grad_fn=<NllLossBackward0>) 1600 0.0
# Epoch 63, Loss: 965.8692016601562
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(39.5095, device='cuda:0')
# tensor(0.7006, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3259, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9244, device='cuda:0', grad_fn=<NllLossBackward0>) 1610 0.0
# Epoch 64, Loss: 971.8397827148438
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(39.4800, device='cuda:0')
# tensor(0.6881, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3269, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9244, device='cuda:0', grad_fn=<NllLossBackward0>) 1610 0.0
# Epoch 65, Loss: 971.8231201171875
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(39.7038, device='cuda:0')
# tensor(0.6744, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3260, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1610 0.0
# Epoch 66, Loss: 971.8006591796875
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(39.7983, device='cuda:0')
# tensor(0.6626, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3265, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9244, device='cuda:0', grad_fn=<NllLossBackward0>) 1610 0.0
# Epoch 67, Loss: 971.7840576171875
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(39.6261, device='cuda:0')
# tensor(0.6501, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3243, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1610 0.0
# Epoch 68, Loss: 971.7610473632812
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(39.5147, device='cuda:0')
# tensor(0.6388, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3242, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1610 0.0
# Epoch 69, Loss: 971.7438354492188
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(39.3361, device='cuda:0')
# tensor(0.6275, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3213, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1610 0.0
# Epoch 70, Loss: 971.721435546875
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(39.1040, device='cuda:0')
# tensor(0.6163, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3205, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1610 0.0
# Epoch 71, Loss: 971.7030639648438
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(39.1450, device='cuda:0')
# tensor(0.6064, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3202, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1610 0.0
# Epoch 72, Loss: 971.6875610351562
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(38.9002, device='cuda:0')
# tensor(0.5961, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3175, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1620 0.0
# Epoch 73, Loss: 977.6670532226562
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(38.3414, device='cuda:0')
# tensor(0.5870, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3145, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1620 0.0
# Epoch 74, Loss: 977.647705078125
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(38.6838, device='cuda:0')
# tensor(0.5775, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3144, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1620 0.0
# Epoch 75, Loss: 977.6333618164062
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(38.2321, device='cuda:0')
# tensor(0.5686, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3117, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1620 0.0
# Epoch 76, Loss: 977.6148681640625
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(38.3403, device='cuda:0')
# tensor(0.5599, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3117, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1620 0.0
# Epoch 77, Loss: 977.6019287109375
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(38.3372, device='cuda:0')
# tensor(0.5511, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3104, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1620 0.0
# Epoch 78, Loss: 977.5861206054688
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(38.3235, device='cuda:0')
# tensor(0.5418, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3106, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1620 0.0
# Epoch 79, Loss: 977.5725708007812
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(38.0641, device='cuda:0')
# tensor(0.5336, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3076, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1620 0.0
# Epoch 80, Loss: 977.5546875
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(37.7889, device='cuda:0')
# tensor(0.5251, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3062, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1630 0.0
# Epoch 81, Loss: 983.5391235351562
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(37.6271, device='cuda:0')
# tensor(0.5166, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3043, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1630 0.0
# Epoch 82, Loss: 983.5227661132812
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(37.6082, device='cuda:0')
# tensor(0.5094, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3022, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1630 0.0
# Epoch 83, Loss: 983.5081176757812
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(38.0273, device='cuda:0')
# tensor(0.5007, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3042, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1620 0.0
# Epoch 84, Loss: 977.4988403320312
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(37.6712, device='cuda:0')
# tensor(0.4932, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3017, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1630 0.0
# Epoch 85, Loss: 983.4827880859375
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(37.8130, device='cuda:0')
# tensor(0.4856, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3019, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1630 0.0
# Epoch 86, Loss: 983.4716796875
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(37.5630, device='cuda:0')
# tensor(0.4780, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3000, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1630 0.0
# Epoch 87, Loss: 983.4568481445312
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(37.5641, device='cuda:0')
# tensor(0.4713, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.2995, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1630 0.0
# Epoch 88, Loss: 983.4457397460938
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(37.4948, device='cuda:0')
# tensor(0.4640, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.2998, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1630 0.0
# Epoch 89, Loss: 983.435302734375
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(37.0746, device='cuda:0')
# tensor(0.4570, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.2963, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1630 0.0
# Epoch 90, Loss: 983.418212890625
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(37.1597, device='cuda:0')
# tensor(0.4503, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.2924, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1630 0.0
# Epoch 91, Loss: 983.4008178710938
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(37.4139, device='cuda:0')
# tensor(0.4431, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.2958, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1630 0.0
# Epoch 92, Loss: 983.3963012695312
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(37.0756, device='cuda:0')
# tensor(0.4363, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.2934, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9242, device='cuda:0', grad_fn=<NllLossBackward0>) 1630 0.0
# Epoch 93, Loss: 983.381591796875
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(37.0756, device='cuda:0')
# tensor(0.4297, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.2916, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1630 0.0
# Epoch 94, Loss: 983.3683471679688
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(36.9328, device='cuda:0')
# tensor(0.4230, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.2897, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9242, device='cuda:0', grad_fn=<NllLossBackward0>) 1640 0.0
# Epoch 95, Loss: 989.3545532226562
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(36.8214, device='cuda:0')
# tensor(0.4164, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.2870, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9242, device='cuda:0', grad_fn=<NllLossBackward0>) 1640 0.0
# Epoch 96, Loss: 989.3395385742188
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(36.6387, device='cuda:0')
# tensor(0.4098, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.2872, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1640 0.0
# Epoch 97, Loss: 989.3302001953125
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(36.5851, device='cuda:0')
# tensor(0.4034, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.2856, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9242, device='cuda:0', grad_fn=<NllLossBackward0>) 1640 0.0
# Epoch 98, Loss: 989.3175659179688
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(36.7458, device='cuda:0')
# tensor(0.3971, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.2858, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1640 0.0
# Epoch 99, Loss: 989.308349609375
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(36.6418, device='cuda:0')
# tensor(0.3911, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.2858, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9242, device='cuda:0', grad_fn=<NllLossBackward0>) 1640 0.0
# Epoch 100, Loss: 989.29931640625
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(36.5200, device='cuda:0')
# tensor(0.3850, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.2823, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9242, device='cuda:0', grad_fn=<NllLossBackward0>) 1640 0.0
# Epoch 101, Loss: 989.2835083007812
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(36.3960, device='cuda:0')
# tensor(0.3789, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.2822, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9242, device='cuda:0', grad_fn=<NllLossBackward0>) 1640 0.0
# Epoch 102, Loss: 989.2742309570312
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(36.1555, device='cuda:0')
# tensor(0.3731, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.2791, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9242, device='cuda:0', grad_fn=<NllLossBackward0>) 1640 0.0
# Epoch 103, Loss: 989.2596435546875
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(36.2490, device='cuda:0')
# tensor(0.3672, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.2794, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9242, device='cuda:0', grad_fn=<NllLossBackward0>) 1640 0.0
# Epoch 104, Loss: 989.2512817382812
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(36.2479, device='cuda:0')
# tensor(0.3615, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.2764, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9242, device='cuda:0', grad_fn=<NllLossBackward0>) 1640 0.0
# Epoch 105, Loss: 989.237060546875
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(36.0347, device='cuda:0')
# tensor(0.3557, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.2748, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9242, device='cuda:0', grad_fn=<NllLossBackward0>) 1640 0.0
# Epoch 106, Loss: 989.2254638671875
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(36.1628, device='cuda:0')
# tensor(0.3502, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.2775, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9242, device='cuda:0', grad_fn=<NllLossBackward0>) 1640 0.0
# Epoch 107, Loss: 989.2222290039062
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(36.0704, device='cuda:0')
# tensor(0.3446, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.2757, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9242, device='cuda:0', grad_fn=<NllLossBackward0>) 1640 0.0
# Epoch 108, Loss: 989.21044921875
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(35.9948, device='cuda:0')
# tensor(0.3391, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.2744, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9242, device='cuda:0', grad_fn=<NllLossBackward0>) 1650 0.0
# Epoch 109, Loss: 995.19970703125
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(35.9874, device='cuda:0')
# tensor(0.3338, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.2718, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9242, device='cuda:0', grad_fn=<NllLossBackward0>) 1650 0.0
# Epoch 110, Loss: 995.1868896484375
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(35.9464, device='cuda:0')
# tensor(0.3286, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.2712, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9242, device='cuda:0', grad_fn=<NllLossBackward0>) 1650 0.0
# Epoch 111, Loss: 995.1777954101562
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(35.7941, device='cuda:0')
# tensor(0.3235, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.2707, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9242, device='cuda:0', grad_fn=<NllLossBackward0>) 1650 0.0
# Epoch 112, Loss: 995.169189453125
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(35.7143, device='cuda:0')
# tensor(0.3184, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.2693, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9242, device='cuda:0', grad_fn=<NllLossBackward0>) 1650 0.0
# Epoch 113, Loss: 995.158935546875
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(35.8004, device='cuda:0')
# tensor(0.3135, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.2705, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9242, device='cuda:0', grad_fn=<NllLossBackward0>) 1650 0.0
# Epoch 114, Loss: 995.1537475585938
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(35.9244, device='cuda:0')
# tensor(0.3088, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.2677, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9242, device='cuda:0', grad_fn=<NllLossBackward0>) 1650 0.0
# Epoch 115, Loss: 995.1414794921875
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(35.5704, device='cuda:0')
# tensor(0.3038, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.2645, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9242, device='cuda:0', grad_fn=<NllLossBackward0>) 1650 0.0
# Epoch 116, Loss: 995.1279296875
# ...
# tensor(0.0062, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.0811, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9239, device='cuda:0', grad_fn=<NllLossBackward0>) 1700 0.0
# Epoch 962, Loss: 1024.3330078125
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(30.5126, device='cuda:0')
# tensor(0.0056, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.0797, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9239, device='cuda:0', grad_fn=<NllLossBackward0>) 1700 0.0
# Epoch 963, Loss: 1024.3294677734375
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(30.8477, device='cuda:0')
# tensor(0.0055, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.0817, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9239, device='cuda:0', grad_fn=<NllLossBackward0>) 1700 0.0
# Epoch 964, Loss: 1024.3330078125
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(30.3361, device='cuda:0')
# tensor(0.0059, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.0768, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9239, device='cuda:0', grad_fn=<NllLossBackward0>) 1700 0.0
# Epoch 965, Loss: 1024.3243408203125
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(30.6355, device='cuda:0')
# tensor(0.0061, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.0786, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9239, device='cuda:0', grad_fn=<NllLossBackward0>) 1700 0.0
# Epoch 966, Loss: 1024.3280029296875
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(30.7006, device='cuda:0')
# tensor(0.0063, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.0807, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9239, device='cuda:0', grad_fn=<NllLossBackward0>) 1700 0.0
# Epoch 967, Loss: 1024.3321533203125
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(31.0368, device='cuda:0')
# tensor(0.0059, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.0841, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9239, device='cuda:0', grad_fn=<NllLossBackward0>) 1690 0.0
# Epoch 968, Loss: 1018.3382568359375
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(30.9464, device='cuda:0')
# tensor(0.0056, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.0825, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9239, device='cuda:0', grad_fn=<NllLossBackward0>) 1700 0.0
# Epoch 969, Loss: 1024.334716796875
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(30.7889, device='cuda:0')
# tensor(0.0055, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.0815, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9239, device='cuda:0', grad_fn=<NllLossBackward0>) 1700 0.0
# Epoch 970, Loss: 1024.33251953125
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(30.6775, device='cuda:0')
# tensor(0.0055, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.0809, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9239, device='cuda:0', grad_fn=<NllLossBackward0>) 1700 0.0
# Epoch 971, Loss: 1024.33154296875
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(30.9412, device='cuda:0')
# tensor(0.0058, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.0815, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9239, device='cuda:0', grad_fn=<NllLossBackward0>) 1700 0.0
# Epoch 972, Loss: 1024.3331298828125
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(30.8466, device='cuda:0')
# tensor(0.0058, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.0820, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9239, device='cuda:0', grad_fn=<NllLossBackward0>) 1700 0.0
# Epoch 973, Loss: 1024.3341064453125
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(30.8309, device='cuda:0')
# tensor(0.0058, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.0820, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9239, device='cuda:0', grad_fn=<NllLossBackward0>) 1700 0.0
# Epoch 974, Loss: 1024.333984375
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(30.9517, device='cuda:0')
# tensor(0.0056, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.0855, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9239, device='cuda:0', grad_fn=<NllLossBackward0>) 1700 0.0
# Epoch 975, Loss: 1024.34033203125
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(30.9275, device='cuda:0')
# tensor(0.0055, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.0847, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9239, device='cuda:0', grad_fn=<NllLossBackward0>) 1700 0.0
# Epoch 976, Loss: 1024.3387451171875
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(30.8088, device='cuda:0')
# tensor(0.0054, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.0815, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9239, device='cuda:0', grad_fn=<NllLossBackward0>) 1700 0.0
# Epoch 977, Loss: 1024.33251953125
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(30.7847, device='cuda:0')
# tensor(0.0054, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.0792, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9239, device='cuda:0', grad_fn=<NllLossBackward0>) 1700 0.0
# Epoch 978, Loss: 1024.3282470703125
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(30.6481, device='cuda:0')
# tensor(0.0055, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.0780, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9239, device='cuda:0', grad_fn=<NllLossBackward0>) 1700 0.0
# Epoch 979, Loss: 1024.3260498046875
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(30.8981, device='cuda:0')
# tensor(0.0055, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.0818, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9239, device='cuda:0', grad_fn=<NllLossBackward0>) 1700 0.0
# Epoch 980, Loss: 1024.333251953125
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(30.9674, device='cuda:0')
# tensor(0.0055, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.0818, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9239, device='cuda:0', grad_fn=<NllLossBackward0>) 1700 0.0
# Epoch 981, Loss: 1024.3333740234375
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(30.7174, device='cuda:0')
# tensor(0.0054, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.0825, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9239, device='cuda:0', grad_fn=<NllLossBackward0>) 1700 0.0
# Epoch 982, Loss: 1024.33447265625
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(30.7027, device='cuda:0')
# tensor(0.0053, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.0783, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9239, device='cuda:0', grad_fn=<NllLossBackward0>) 1700 0.0
# Epoch 983, Loss: 1024.326416015625
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(30.8361, device='cuda:0')
# tensor(0.0053, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.0821, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9239, device='cuda:0', grad_fn=<NllLossBackward0>) 1700 0.0
# Epoch 984, Loss: 1024.33349609375
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(30.6376, device='cuda:0')
# tensor(0.0053, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.0779, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9239, device='cuda:0', grad_fn=<NllLossBackward0>) 1700 0.0
# Epoch 985, Loss: 1024.3255615234375
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(30.5882, device='cuda:0')
# tensor(0.0054, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.0802, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9239, device='cuda:0', grad_fn=<NllLossBackward0>) 1700 0.0
# Epoch 986, Loss: 1024.330078125
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(30.9832, device='cuda:0')
# tensor(0.0054, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.0814, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9239, device='cuda:0', grad_fn=<NllLossBackward0>) 1700 0.0
# Epoch 987, Loss: 1024.3323974609375
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(30.7437, device='cuda:0')
# tensor(0.0054, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.0816, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9239, device='cuda:0', grad_fn=<NllLossBackward0>) 1700 0.0
# Epoch 988, Loss: 1024.332763671875
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(30.8729, device='cuda:0')
# tensor(0.0053, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.0850, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9239, device='cuda:0', grad_fn=<NllLossBackward0>) 1700 0.0
# Epoch 989, Loss: 1024.3389892578125
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(30.5714, device='cuda:0')
# tensor(0.0053, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.0759, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9239, device='cuda:0', grad_fn=<NllLossBackward0>) 1700 0.0
# Epoch 990, Loss: 1024.32177734375
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(30.7290, device='cuda:0')
# tensor(0.0053, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.0793, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9239, device='cuda:0', grad_fn=<NllLossBackward0>) 1700 0.0
# Epoch 991, Loss: 1024.3282470703125
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(30.9569, device='cuda:0')
# tensor(0.0053, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.0839, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9239, device='cuda:0', grad_fn=<NllLossBackward0>) 1700 0.0
# Epoch 992, Loss: 1024.3367919921875
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(30.8676, device='cuda:0')
# tensor(0.0053, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.0801, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9239, device='cuda:0', grad_fn=<NllLossBackward0>) 1700 0.0
# Epoch 993, Loss: 1024.3297119140625
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(30.5966, device='cuda:0')
# tensor(0.0053, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.0762, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9239, device='cuda:0', grad_fn=<NllLossBackward0>) 1700 0.0
# Epoch 994, Loss: 1024.3223876953125
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(30.5840, device='cuda:0')
# tensor(0.0053, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.0747, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9239, device='cuda:0', grad_fn=<NllLossBackward0>) 1700 0.0
# Epoch 995, Loss: 1024.3194580078125
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(30.5116, device='cuda:0')
# tensor(0.0052, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.0797, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9239, device='cuda:0', grad_fn=<NllLossBackward0>) 1700 0.0
# Epoch 996, Loss: 1024.3289794921875
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(30.6555, device='cuda:0')
# tensor(0.0053, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.0786, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9239, device='cuda:0', grad_fn=<NllLossBackward0>) 1700 0.0
# Epoch 997, Loss: 1024.32666015625
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(30.9863, device='cuda:0')
# tensor(0.0052, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.0830, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9239, device='cuda:0', grad_fn=<NllLossBackward0>) 1700 0.0
# Epoch 998, Loss: 1024.3350830078125
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(30.8351, device='cuda:0')
# tensor(0.0052, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.0816, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9239, device='cuda:0', grad_fn=<NllLossBackward0>) 1700 0.0
# Epoch 999, Loss: 1024.332275390625
# DataBatch(x=[18128, 10], edge_index=[2, 18682], edge_attr=[18682, 4], adj_matrix=[59976, 63, 5], node_features=[59976, 11], batch=[18128])
# torch.Size([952, 512])
# tensor(30.8382, device='cuda:0')
# tensor(0.0052, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.0815, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9239, device='cuda:0', grad_fn=<NllLossBackward0>) 1700 0.0
# Epoch 1000, Loss: 1024.3321533203125

# %% [markdown]
# ### Use if Sampling with Conditioning

# %%
def get_dist():
    model.eval()
    with torch.no_grad():
        for data in data_object_loader:
            data = Batch.from_data_list(data).to(device)
            _, _, mu, logvar = model(data)
            return mu, logvar

# %%
def sample_z_ours(mu, logvar, num_samples=1):
    std = torch.exp(0.5 * logvar)
    eps = torch.randn_like(std)
    return mu + eps * std

# %%
def generate_graph_ours(model, num_samples=1, latent_dim=256, device="cuda"):
    mmu, llog = get_dist()
    sampled_ours = sample_z_ours(mmu, llog)

    with torch.no_grad():
        A_pred, features_pred = model.decode(sampled_ours)

    return A_pred, features_pred

# %% [markdown]
# ### Use if Sampling without Conditioning

# %%
def sample_z(latent_dim, num_samples=1, device="cuda"):
    return torch.randn(num_samples, latent_dim).to(device)

# %%
def generate_graph(model, num_samples=1, latent_dim=LATENT_DIM, device="cuda"):
    z = sample_z(latent_dim, num_samples, device)

    with torch.no_grad():
        A_pred, features_pred = model.decode(z)

    return A_pred, features_pred

# %%
# #one_hot_bond_reduced, one_hot_atoms_reduced = drop_extras(one_hot_bond[0].view(1,63, 63, 5), one_hot_atoms[0].view(1, 63,11))

# datapoints = process_graph_data_to_data_objects(bonds_pred, atoms_pred)

# %%
atomic_mapping = {0: 6, 1: 7, 2:8, 3:9, 4:14, 5:15, 6:16, 7:17, 8:35, 9:53}

# %%
def get_bond_type(bond_type):
    bond_type = torch.argmax(bond_type, dim=-1).item()
    if bond_type == 0:
        return rdchem.BondType.SINGLE
    elif bond_type == 1:
        return rdchem.BondType.DOUBLE
    elif bond_type == 2:
        return rdchem.BondType.TRIPLE
    elif bond_type == 3:
        return rdchem.BondType.AROMATIC
    else:
        return None

# %%
def is_valid(data):
    node_features = data.x
    edge_index = data.edge_index
    edge_attr = data.edge_attr

    atomic_numbers = []
    for num in node_features.argmax(dim=-1).tolist():
        atomic_numbers.append(atomic_mapping[num])

    mol = Chem.RWMol()
    for atomic_num in atomic_numbers:
        atom = Chem.Atom(atomic_num)
        mol.AddAtom(atom)

    for i, (bond_start, bond_end) in enumerate(edge_index.t().tolist()):
        bond_val = edge_attr[i]
        bond_type = get_bond_type(bond_val)
        mol.AddBond(bond_start, bond_end, bond_type)

    validity = Chem.SanitizeMol(mol, catchErrors=True)

    return validity == Chem.SanitizeFlags.SANITIZE_NONE

# %%
unique_molecules = set()
def is_unique(data):
    node_features = data.x
    edge_index = data.edge_index
    edge_attr = data.edge_attr

    atomic_numbers = []
    for num in node_features.argmax(dim=-1).tolist():
        atomic_numbers.append(atomic_mapping[num])

    mol = Chem.RWMol()
    for atomic_num in atomic_numbers:
        atom = Chem.Atom(atomic_num)
        mol.AddAtom(atom)

    for i, (bond_start, bond_end) in enumerate(edge_index.t().tolist()):
        bond_val = edge_attr[i]
        bond_type = get_bond_type(bond_val)
        mol.AddBond(bond_start, bond_end, bond_type)

    canonical_smiles = Chem.MolToSmiles(mol, isomericSmiles=True)
    if canonical_smiles not in unique_molecules:
        unique_molecules.add(canonical_smiles)
        return True
    else:
        return False

# %%
torch.save(model.state_dict(), "models/vae_model_best_test.pt")

# %%
print(model)
# Out:
# RGCN_VGAE(
#   (rgcn1): RGCNConv(10, 512, num_relations=4)
#   (rgcn2): RGCNConv(512, 512, num_relations=4)
#   (fc_mu): Linear(in_features=512, out_features=512, bias=True)
#   (fc_logvar): Linear(in_features=512, out_features=512, bias=True)
#   (adj_decoder): Sequential(
#     (0): Linear(in_features=512, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=512, out_features=19845, bias=True)
#   )
#   (feature_decoder): Linear(in_features=512, out_features=693, bias=True)
# )

# %%
import re
def expand_formula(formula):
    pattern = r'([A-Z][a-z]?)(\d*)'
    expanded_list = []
    total_atoms = 0

    matches = re.findall(pattern, formula)
    for element, count in matches:
        count = int(count) if count else 1
        expanded_list.extend([element] * count)
        total_atoms += count

    return expanded_list, total_atoms

# %%
def get_molecule(datapoint):
    _, formula = to_chemula(datapoint)
    l, total_atoms = expand_formula(formula)

    # #atomic_numbers = datapoint.x.argmax(dim=1).tolist()
    # atomic_numbers_unmapped = datapoint.x.argmax(dim=1).tolist()
    # atomic_numbers = []
    # for at in atomic_numbers_unmapped:
    #     atomic_numbers.append(atomic_mapping[at])
    # positions = datapoint.positions.numpy()
    positions = np.random.rand(len(l), 3) * 10

    # molecule = Atoms(numbers=atomic_numbers, positions=positions)
    molecule = Atoms(symbols=l, positions=positions)

    return molecule, total_atoms

@contextmanager
def suppress_stdout():
    with open(os.devnull, "w") as devnull:
        old_stdout = sys.stdout
        sys.stdout = devnull
        try:
            yield
        finally:
            sys.stdout = old_stdout

def get_dft(datapoint, De=0.242, re=0.74, alpha=1.5):
    molecule, _ = get_molecule(datapoint)
    print('Molecule:', molecule)
    dft_calculator = MorsePotential(De=De, r0=re, alpha=alpha)
    molecule.set_calculator(dft_calculator)
    # energy = molecule.get_potential_energy()
    with suppress_stdout():
        opt = QuasiNewton(molecule)
        opt.run(fmax=0.02)
    optimized_energy = molecule.get_potential_energy()
    return optimized_energy

# energy = get_dft(datapoint)

# print(f'DFT Energy: {energy} eV')

# %%
def to_chemula(data):
    node_features = data.x
    edge_index = data.edge_index
    edge_attr = data.edge_attr

    atomic_numbers = []
    for num in node_features.argmax(dim=-1).tolist():
        atomic_numbers.append(atomic_mapping[num])

    mol = Chem.RWMol()
    for atomic_num in atomic_numbers:
        atom = Chem.Atom(atomic_num)
        mol.AddAtom(atom)

    for i, (bond_start, bond_end) in enumerate(edge_index.t().tolist()):
        bond_val = edge_attr[i]
        bond_type = get_bond_type(bond_val)
        mol.AddBond(bond_start, bond_end, bond_type)
    for atom in mol.GetAtoms():
        atom.UpdatePropertyCache(strict=False)
    # Chem.SanitizeMol(mol)
    return mol, CalcMolFormula(mol)

# %%
Chem.MolFromSmiles('NN')

# %%
class GraphEncoder(nn.Module):
    def __init__(self, input_dim, num_relations):
        super(GraphEncoder, self).__init__()
        self.rgcnconv1 = RGCNConv(input_dim, 512, num_relations=num_relations)
        self.rgcnconv2 = RGCNConv(512, 256, num_relations=num_relations)
        self.rgcnconv3 = RGCNConv(256, 128, num_relations=num_relations)

    def forward(self, x, edge_index, edge_attr):
        x = self.rgcnconv1(x, edge_index, edge_attr)
        x = nn.ReLU()(x)
        x = self.rgcnconv2(x, edge_index, edge_attr)
        x = nn.ReLU()(x)
        x = self.rgcnconv3(x, edge_index, edge_attr)
        x = nn.ReLU()(x)
        return x

class BioClassifier(nn.Module):
    def __init__(self, input_dim, num_heads):
        super(BioClassifier, self).__init__()

        self.encoder = GraphEncoder(input_dim, num_heads)
        self.fc1 = nn.Linear(128, 64)
        self.bn1 = nn.BatchNorm1d(64)
        self.fc2 = nn.Linear(64, 1)
        self.dropout = nn.Dropout(0.4)

    def forward(self, data):
        x, edge_index, edge_attr = data.x, data.edge_index, data.edge_attr
        x = x.float()

        x = self.encoder(x, edge_index, edge_attr)
        x = global_add_pool(x, data.batch)
        x = self.dropout(x)
        x = self.fc1(x)
        x = nn.ReLU()(x)
        x = self.bn1(x)
        x = self.dropout(x)
        x = self.fc2(x)
        x = torch.sigmoid(x)
        return x.squeeze(dim=1)

# %%
model_bio_eval = BioClassifier(10, 4).to(device)

state_dict = torch.load('models/rcgn_model_7428.pt')
model_bio_eval.load_state_dict(state_dict)

model_bio_eval.eval()
def get_model_prediction(datapoint):
    pred = model_bio_eval(datapoint)
    return pred.item()

# %%
# print(datapoint)
# datapoint.edge_attr = torch.argmax(datapoint.edge_attr, dim=1).to(device)
# datapoint.edge_index = datapoint.edge_index.to(device)
# datapoint.x = datapoint.x.to(device)

# %%
# print(datapoint.edge_attr)

# %%
# dft = get_dft(datapoint)
# y = get_model_prediction(datapoint) * 100

# print(f'DFT (remember negative is good): {dft}')
# print(f'Chance of Biodgradability: {y:.2f}%')

# %% [markdown]
# ## Generating from Our Latent Space

# %%
# generated_list_ours = []
# list_len = 100
# for i in tqdm(range(list_len)):
#     bonds_pred_ours, atoms_pred_ours = generate_graph_ours(model)
#     datapoints = process_graph_data_to_data_objects(bonds_pred_ours, atoms_pred_ours)
#     datapoint = datapoints[0]
#     validity = is_valid(datapoint)
#     mol, formula = to_chemula(datapoint)
#     ase_atoms = get_molecule(datapoint)
#     energy = get_dft(datapoint)
#     datapoint.edge_attr = torch.argmax(datapoint.edge_attr, dim=1).to(device)
#     datapoint.edge_index = datapoint.edge_index.to(device)
#     datapoint.x = datapoint.x.to(device)
#     y = get_model_prediction(datapoint) * 100
#     generated_list_ours.append({"bond_preds": bonds_pred, "atom_preds": atoms_pred, "is_valid": validity, "ase_atom": ase_atoms, "mol": mol, "formula": formula, "energy":energy, "bio":y})

# %% [markdown]
# ## Generating from Rand Normal Distribution

# %%
generated_list = []
num_errors = 0

while len(generated_list) < 100:
    try:
        bonds_pred, atoms_pred = generate_graph(model)
        datapoints = process_graph_data_to_data_objects(bonds_pred, atoms_pred)
        datapoint = datapoints[0]
        validity = is_valid(datapoint)
        mol, formula = to_chemula(datapoint)
        ase_atoms, total_atoms = get_molecule(datapoint)
        energy = get_dft(datapoint)
        datapoint.edge_attr = torch.argmax(datapoint.edge_attr, dim=1).to(device)
        datapoint.edge_index = datapoint.edge_index.to(device)
        datapoint.x = datapoint.x.to(device)
        y = get_model_prediction(datapoint) * 100
        generated_list.append({"atom_count": total_atoms, "is_valid": validity, "ase_atom": ase_atoms, "mol": mol, "formula": formula, "energy":energy, "bio":y})
    except Exception as e:
        num_errors += 1
        print("ERROR!!!!!!")
        print(e)
# Out:
# Molecule: Atoms(symbols='C2H7NO2', pbc=False)
# Molecule: Atoms(symbols='C4H11NO3', pbc=False)
# Molecule: Atoms(symbols='C5H16N2O', pbc=False)
# Molecule: Atoms(symbols='C2H8N2O', pbc=False)
# Molecule: Atoms(symbols='C2H8N2O2', pbc=False)
# Molecule: Atoms(symbols='C5H13N', pbc=False)
# Molecule: Atoms(symbols='C4H11N', pbc=False)
# Molecule: Atoms(symbols='C3H12N2O2', pbc=False)
# Molecule: Atoms(symbols='C4H10', pbc=False)
# Molecule: Atoms(symbols='C2H6O3', pbc=False)
# Molecule: Atoms(symbols='CH6N2O', pbc=False)
# Molecule: Atoms(symbols='C6H15NO', pbc=False)
# Molecule: Atoms(symbols='C5H15NO', pbc=False)
# Molecule: Atoms(symbols='C4H10O2', pbc=False)
# Molecule: Atoms(symbols='C3H9N', pbc=False)
# Molecule: Atoms(symbols='C4H11NO2', pbc=False)
# Molecule: Atoms(symbols='C4H13NO', pbc=False)
# Molecule: Atoms(symbols='C3H8O2', pbc=False)
# Molecule: Atoms(symbols='C3H9NO2', pbc=False)
# Molecule: Atoms(symbols='C3H10N2', pbc=False)
# Molecule: Atoms(symbols='CH5NO2', pbc=False)
# Molecule: Atoms(symbols='C5H14N2O', pbc=False)
# Molecule: Atoms(symbols='C5H15N3O', pbc=False)
# Molecule: Atoms(symbols='C2H7NO3', pbc=False)
# Molecule: Atoms(symbols='C6H18N2O', pbc=False)
# Molecule: Atoms(symbols='C2H9N3', pbc=False)
# Molecule: Atoms(symbols='C4H14N2', pbc=False)
# Molecule: Atoms(symbols='C5H14O', pbc=False)
# Molecule: Atoms(symbols='C5H16N2O', pbc=False)
# Molecule: Atoms(symbols='C3H9N', pbc=False)
# Molecule: Atoms(symbols='C2H7NO2', pbc=False)
# Molecule: Atoms(symbols='C3H9NO', pbc=False)
# Molecule: Atoms(symbols='CH6N2O2', pbc=False)
# Molecule: Atoms(symbols='C3H12N2O3', pbc=False)
# Molecule: Atoms(symbols='C3H8O', pbc=False)
# Molecule: Atoms(symbols='C3H10N2O', pbc=False)
# Molecule: Atoms(symbols='C2H7NO3', pbc=False)
# Molecule: Atoms(symbols='C3H12N2O', pbc=False)
# Molecule: Atoms(symbols='C3H10N2O', pbc=False)
# Molecule: Atoms(symbols='C5H15NO', pbc=False)
# Molecule: Atoms(symbols='C6H14O2', pbc=False)
# Molecule: Atoms(symbols='C4H11NO2', pbc=False)
# Molecule: Atoms(symbols='C5H13NO', pbc=False)
# Molecule: Atoms(symbols='C6H17NO', pbc=False)
# Molecule: Atoms(symbols='C4H10O', pbc=False)
# Molecule: Atoms(symbols='C4H14N2O', pbc=False)
# Molecule: Atoms(symbols='CH6N2O', pbc=False)
# Molecule: Atoms(symbols='C2H7NO', pbc=False)
# Molecule: Atoms(symbols='C6H15NO', pbc=False)
# Molecule: Atoms(symbols='C6H17NO', pbc=False)
# Molecule: Atoms(symbols='C6H17NO2', pbc=False)
# Molecule: Atoms(symbols='C2H8N2O', pbc=False)
# Molecule: Atoms(symbols='C6H14O', pbc=False)
# Molecule: Atoms(symbols='C5H15NO2', pbc=False)
# Molecule: Atoms(symbols='C8H20', pbc=False)
# Molecule: Atoms(symbols='C3H11N3O3', pbc=False)
# Molecule: Atoms(symbols='C3H11NO2', pbc=False)
# Molecule: Atoms(symbols='C3H12N2O2', pbc=False)
# Molecule: Atoms(symbols='C3H11N3', pbc=False)
# Molecule: Atoms(symbols='C2H8N2O2', pbc=False)
# Molecule: Atoms(symbols='C7H16O2', pbc=False)
# Molecule: Atoms(symbols='C4H12N2', pbc=False)
# Molecule: Atoms(symbols='C2H6O2', pbc=False)
# Molecule: Atoms(symbols='C4H11NO2', pbc=False)
# Molecule: Atoms(symbols='C3H10N2O', pbc=False)
# Molecule: Atoms(symbols='C2H8N2', pbc=False)
# Molecule: Atoms(symbols='C4H10O2', pbc=False)
# Molecule: Atoms(symbols='C3H12N2O2', pbc=False)
# Molecule: Atoms(symbols='CH6N2O', pbc=False)
# Molecule: Atoms(symbols='C5H13N', pbc=False)
# Molecule: Atoms(symbols='C6H16O', pbc=False)
# Molecule: Atoms(symbols='C3H12N2O3', pbc=False)
# Molecule: Atoms(symbols='C5H12O', pbc=False)
# Molecule: Atoms(symbols='CH6N2O', pbc=False)
# Molecule: Atoms(symbols='CH4O3', pbc=False)
# Molecule: Atoms(symbols='C3H9NO', pbc=False)
# Molecule: Atoms(symbols='C5H13NO', pbc=False)
# Molecule: Atoms(symbols='C2H8N2O2', pbc=False)
# Molecule: Atoms(symbols='C2H8N2O', pbc=False)
# Molecule: Atoms(symbols='C3H12N2O2', pbc=False)
# Molecule: Atoms(symbols='C6H16', pbc=False)
# Molecule: Atoms(symbols='C4H11NO', pbc=False)
# Molecule: Atoms(symbols='C2H8N2O', pbc=False)
# Molecule: Atoms(symbols='C3H12N2O2', pbc=False)
# Molecule: Atoms(symbols='C3H10N2O', pbc=False)
# Molecule: Atoms(symbols='C2H7NO2', pbc=False)
# Molecule: Atoms(symbols='CH7N3O', pbc=False)
# Molecule: Atoms(symbols='C6H17NO', pbc=False)
# Molecule: Atoms(symbols='CH6N2O2', pbc=False)
# Molecule: Atoms(symbols='C5H13NO2', pbc=False)
# Molecule: Atoms(symbols='C4H11N', pbc=False)
# Molecule: Atoms(symbols='C4H11NO2', pbc=False)
# Molecule: Atoms(symbols='C3H12N2O3', pbc=False)
# Molecule: Atoms(symbols='C3H9NO', pbc=False)
# Molecule: Atoms(symbols='C6H19NO', pbc=False)
# Molecule: Atoms(symbols='C6H17N', pbc=False)
# Molecule: Atoms(symbols='C5H14N2O', pbc=False)
# Molecule: Atoms(symbols='C2H8N2O', pbc=False)
# Molecule: Atoms(symbols='C4H13NO2', pbc=False)
# Molecule: Atoms(symbols='C2H7NO2', pbc=False)

# %%
print(len(generated_list))
# Out:
# 100

# %%
print(generated_list[0]["ase_atom"])
# Out:
# Atoms(symbols='C2H7NO2', pbc=False)

# %%
unique_formulas = set()
count_formulas = {}
count_valid = 0
total_atom_count = 0
for item in generated_list:
    if 'formula' in item:
        if item['formula'] not in count_formulas:
            count_formulas[item['formula']] = 1
        else:
            count_formulas[item['formula']] += 1
        unique_formulas.add(item['formula'])
    if 'is_valid' in item:
        if item['is_valid'] == True:
            count_valid += 1
    if 'atom_count' in item:
        total_atom_count += item['atom_count']

# %%
print(unique_formulas)
print("Average Number of atoms: ", total_atom_count / 100)
print("Number of Unique Formulas: ", len(unique_formulas))
print("Number of Valid Formulas: ", count_valid / (num_errors + count_valid))
# Out:
# {'C6H18N2O', 'C2H7NO2', 'C6H17NO', 'CH7N3O', 'C3H8O2', 'C3H10N2O', 'C7H16O2', 'C4H13NO', 'C6H14O', 'C3H11N3', 'C2H7NO', 'C4H11NO2', 'C3H11NO2', 'C5H15NO', 'C5H13NO2', 'C6H15NO', 'C4H11N', 'C4H11NO', 'CH6N2O', 'C3H10N2', 'C2H6O3', 'C3H12N2O', 'C2H9N3', 'CH6N2O2', 'C2H8N2O2', 'C5H13NO', 'C5H15NO2', 'C4H10', 'C5H15N3O', 'C6H17NO2', 'C6H14O2', 'C4H10O2', 'CH5NO2', 'C4H11NO3', 'C5H12O', 'CH4O3', 'C3H12N2O2', 'C5H14N2O', 'C2H8N2', 'C2H8N2O', 'C3H8O', 'C6H16', 'C3H9NO', 'C8H20', 'C4H14N2', 'C6H16O', 'C4H12N2', 'C6H19NO', 'C2H6O2', 'C3H11N3O3', 'C3H9N', 'C4H10O', 'C4H14N2O', 'C3H9NO2', 'C4H13NO2', 'C3H12N2O3', 'C5H16N2O', 'C5H13N', 'C5H14O', 'C6H17N', 'C2H7NO3'}
# Average Number of atoms:  17.29
# Number of Unique Formulas:  61
# Number of Valid Formulas:  1.0

# %%
print(count_formulas)
# Out:
# {'C2H7NO2': 4, 'C4H11NO3': 1, 'C5H16N2O': 2, 'C2H8N2O': 5, 'C2H8N2O2': 3, 'C5H13N': 2, 'C4H11N': 2, 'C3H12N2O2': 5, 'C4H10': 1, 'C2H6O3': 1, 'CH6N2O': 4, 'C6H15NO': 2, 'C5H15NO': 2, 'C4H10O2': 2, 'C3H9N': 2, 'C4H11NO2': 4, 'C4H13NO': 1, 'C3H8O2': 1, 'C3H9NO2': 1, 'C3H10N2': 1, 'CH5NO2': 1, 'C5H14N2O': 2, 'C5H15N3O': 1, 'C2H7NO3': 2, 'C6H18N2O': 1, 'C2H9N3': 1, 'C4H14N2': 1, 'C5H14O': 1, 'C3H9NO': 3, 'CH6N2O2': 2, 'C3H12N2O3': 3, 'C3H8O': 1, 'C3H10N2O': 4, 'C3H12N2O': 1, 'C6H14O2': 1, 'C5H13NO': 2, 'C6H17NO': 3, 'C4H10O': 1, 'C4H14N2O': 1, 'C2H7NO': 1, 'C6H17NO2': 1, 'C6H14O': 1, 'C5H15NO2': 1, 'C8H20': 1, 'C3H11N3O3': 1, 'C3H11NO2': 1, 'C3H11N3': 1, 'C7H16O2': 1, 'C4H12N2': 1, 'C2H6O2': 1, 'C2H8N2': 1, 'C6H16O': 1, 'C5H12O': 1, 'CH4O3': 1, 'C6H16': 1, 'C4H11NO': 1, 'CH7N3O': 1, 'C5H13NO2': 1, 'C6H19NO': 1, 'C6H17N': 1, 'C4H13NO2': 1}

# %% [markdown]
# ### Novelty

# %%
with open("data/og_formulas.pkl", "rb") as file:
    og_formulas = pickle.load(file)

# %%
print(og_formulas)
print(len(og_formulas))
# Out:
# ['C4H10O2S2', 'C17H11BrClFN2O4', 'C7H7Br', 'C7H16BrN', 'C2HBrCl2O2', 'C4H6Br2', 'CBrCl3', 'C6H5F2N', 'C11H20O', 'C6BrF5', 'C10H24N2O4', 'C6H4ClNO2', 'C6H14O3', 'C10H22O5', 'C2H3BrO2', 'C8H18BrN', 'C7H5ClO2', 'C6H3Br3', 'C10H22OS', 'C7H6Br2', 'C14H15N5O6S', 'C10H16Cl3NOS', 'C3H5BrO', 'C2H4Br2', 'C8H14O', 'C6H6N2O', 'C22H25ClN2O9', 'C15H17N5O6S', 'C12H12', 'C6H12S', 'C8H14N4O7', 'C4H5NS', 'C4H10S', 'C3H12NO9P3', 'C6H4BrF', 'C22H24N2O8', 'C4H8BrCl', 'C11H10', 'C6H8N2S', 'C13H27Br', 'C10H12N6', 'C13H21N3O6S2', 'C14H29Br', 'C2H3FO2', 'C2H4N4O2', 'C14H16N2O4S', 'C11H24O6Si', 'C10H20O', 'C7H3Cl2FO', 'C3H5Br2Cl', 'C12H22F6N2O4S2', 'C9H17IN2', 'C8H12N4', 'C27H50O6', 'C2H5NO2', 'C9H6F3N', 'C7H6F3N', 'C11H16N8O8', 'H4N2O3', 'C2H5NO3', 'C4H10O3', 'C7H7ClS', 'C8H15IN2', 'C11H10FNO2S', 'C8H8O3', 'C12H16O7', 'C21H40O5', 'C13H22N4O3S', 'C9H10ClN5O2', 'C4H9NO4', 'C28H46O4', 'C8H5N3O4', 'C14H16ClN5O5S', 'C25H48O4', 'C16H10F3NO', 'C12H13ClF3N3O4', 'C12H8N2O5', 'C13H18N2O4', 'C10H22BrN', 'C6H11ClN2', 'C8H11N3O4', 'C5H6N2O2S', 'C13H16O3', 'C17H25N7O', 'C8H10N2', 'CHF3O3S', 'C37H61BrN2O4', 'C8H12N2O2', 'C5H13NO2', 'C9H10N4O2S2', 'C17H12Cl2N6O4', 'C22H28INO2', 'C5H4ClNO', 'C8H10O2', 'C15H27N3O', 'C10H22IN', 'C3H9O3P', 'C9H17ClN2', 'C3H3NO2', 'C6H12O2', 'C7H14O3', 'C2H3F3O', 'C21H23ClFNO5', 'C6H10', 'C22H42O4', 'C27H46O2', 'C8H17NO3', 'C15H16F5NO2S2', 'C10H14', 'C7H9NO3S', 'C5H7N3O2', 'C5H13N', 'C12H18N2O3S', 'C12H21N2O4P', 'C14H22O8', 'C14H22N2O3', 'C8H19NO', 'C12H19N3O', 'C10H11NO3', 'C9H10', 'C10H12O', 'C13H26O4', 'C7H3ClF3NO2', 'C8H7NO3', 'C7H5NO4', 'C9H19NO4', 'C8H14O3', 'C5H11NOS', 'C10H24N2', 'C34H58O4', 'C7H4F3NO2', 'C9H20S', 'C12H18', 'C5H10O', 'C3H6O', 'C4H6N2O', 'C19H36O2', 'C6H10N2O3', 'C15H21NO4', 'C7H5Cl2NO', 'C11H7NO4', 'C2H5NS', 'C5H8O4', 'C10H21NO', 'C5H12O3', 'C11H20O4', 'C8H10F3NO3S', 'C5H7N', 'C13H16O2', 'C4H8Cl2', 'C6H16N2', 'C9H16O', 'C7H14N2O', 'C4H10O4S', 'C10H6O8', 'C12H18O3', 'C13H19NO9', 'C10H15NO2', 'C13H24O4', 'C10H15F6N3O4S2', 'C12H10O3', 'C14H8Br2O2', 'C4H8O3', 'C17H21IO2', 'C11H15NO2S', 'C22H42O6', 'C14H17N3O3', 'C18H18O5', 'C11H22O2', 'C14H22O6', 'C6H14', 'C14H19ClO', 'C14H30O', 'C10H15N', 'C22H42O2', 'C9H20N2', 'C7H9NO2S', 'C7H10O2', 'C2H3NS', 'C2H3NO', 'C3H4Cl2', 'C12H12N2O2S', 'C5H8O', 'C4H6O2', 'CH2O', 'C16H13ClN2O2', 'C38H72N2O12', 'C22H20O13', 'C8H16O', 'C5H7ClO2', 'C26H47O3P', 'C8H18F6NP', 'C9H18N3OP', 'C9H16N4OS', 'C9H16F6N2O4S2', 'C5H11NO2', 'C5H9NO3S', 'C11H14N2O', 'C15H30N2', 'CH4N2O', 'C10H20O2S', 'C10H18F6N2O4S2', 'C7H14N2O4S', 'C4H12O3Si', 'C32H60O10', 'C9H13N3O3', 'C19H24N4O3', 'C2H7NO2S', 'C2H6OSi', 'C9H13F6N3O4S2', 'C8H24O2Si3', 'C7H22O2Si3', 'C6H7N', 'C12H2Br8O', 'C14H17BrN2O2', 'C12H10', 'C9H16N2', 'C6H14O6', 'C10H12O2', 'C16H14O3', 'C6H12O6', 'C4H8N2O2', 'C7H9N', 'C7H10O4S', 'C2H8N2O', 'C4H12N2O', 'C23H22ClF3O2', 'C7H16O', 'C12H22O11', 'C17H28N4O7S', 'C5H12O5', 'C14H28O2', 'C6H10O4', 'C6H18N4', 'C9H7N', 'C3H4N2', 'C4H4N2', 'C6H12N2', 'C6H6', 'C8H10N2O3S', 'C8H6O', 'C9H11N', 'C3H6O2', 'C10H14S', 'C10H12', 'C24H34N8O4S2', 'C6H7NO3S', 'C4H6O3', 'C3H4N2S', 'C12H14', 'C7H10O3', 'C2H3N3', 'C6H12N4', 'C16H33NO2', 'C4H8S2', 'C2H8O7P2', 'C13H30O6P2', 'C6H12Br2', 'C8H14ClN5', 'C17H26O', 'C11H18O3Si', 'C18H28O2', 'C9H13ClN6', 'C6H10O', 'C8H16', 'C7H12ClN5', 'C9H4Cl6O4', 'C21H25NO2', 'C14H21NO4', 'C7H14N2O3S', 'C24H45NO6S', 'C6H15Cl2NO', 'C8H13NO3S', 'C12H17N5O4S', 'C6H11NO2', 'C10H8N2', 'C12H24', 'C4H7ClO2', 'C8H12', 'C8H19O3PS2', 'C20H26', 'C18H35NO2', 'C8H20O5P2S2', 'C6H15O3P', 'C12H20ClN3O', 'C6H4Cl2', 'C31H52O3', 'C6H3Cl3', 'C12H8', 'C4H4O', 'C12H22', 'C7H6Cl2', 'C12H8O2', 'C10H8O2', 'C11H14N2', 'C10H10O3', 'C17H17N3O3', 'C4H6O', 'C9H8N2', 'C6H9N3O3', 'C13H22O', 'C12H27P', 'C28H52N2O4', 'C12H11NO3', 'C3H8N2O', 'C8H10ClN5O3S', 'C6H14N2O', 'C17H16O4', 'C10H18O3', 'C15H20ClN3O', 'C26H48O4', 'C15H10ClF3N2O6S', 'C9H21O2PS3', 'C16H34O4', 'C8H18O2', 'C17H34O2', 'C4H10O', 'C14H32N2O4', 'C14H6Cl2F4N2O2', 'C4H11N', 'C18H38N4O15S', 'C3H8S', 'C3H5ClO2', 'C8H18O3Si', 'C8H20O3Si', 'C23H31ClN2O', 'C10H11ClN4', 'C8H20ClN ...
# 3208

# %%
og_formulas = set(og_formulas)
print(og_formulas & unique_formulas)
print(len(og_formulas & unique_formulas))
print("Number of Novel Molecules: ", 100 - len(og_formulas & unique_formulas))
# Out:
# {'C3H8O2', 'C7H16O2', 'C2H7NO', 'C4H11NO2', 'C5H13NO2', 'C4H11N', 'C3H10N2', 'CH6N2O2', 'C5H13NO', 'C5H15NO2', 'C4H10', 'C4H11NO3', 'C2H8N2', 'C2H8N2O', 'C3H8O', 'C3H9NO', 'C4H12N2', 'C2H6O2', 'C3H9N', 'C4H10O', 'C3H9NO2', 'C5H13N'}
# 22
# Number of Novel Molecules:  78

# %%
df = pd.DataFrame(list(count_formulas.items()), columns=['Formula', 'Count'])
sorted_df = df.sort_values(by='Count', ascending=False)
sorted_df.head(31)
# Out:
#       Formula  Count
# 3     C2H8N2O      5
# 7   C3H12N2O2      5
# 0     C2H7NO2      4
# 10     CH6N2O      4
# 32   C3H10N2O      4
# 15   C4H11NO2      4
# 36    C6H17NO      3
# 28     C3H9NO      3
# 30  C3H12N2O3      3
# 4    C2H8N2O2      3
# 35    C5H13NO      2
# 6      C4H11N      2
# 23    C2H7NO3      2
# 21   C5H14N2O      2
# 5      C5H13N      2
# 2    C5H16N2O      2
# 14      C3H9N      2
# 13    C4H10O2      2
# 12    C5H15NO      2
# 11    C6H15NO      2
# 29    CH6N2O2      2
# 43      C8H20      1
# 44  C3H11N3O3      1
# 45   C3H11NO2      1
# 46    C3H11N3      1
# 47    C7H16O2      1
# 48    C4H12N2      1
# 49     C2H6O2      1
# 53      CH4O3      1
# 50     C2H8N2      1
# 51     C6H16O      1

# %%
sorted_df.to_csv("vae_generated_count_test.csv", index=False)

# %%
df = pd.DataFrame(generated_list)
df.head()
# Out:
#    atom_count  is_valid                                           ase_atom
# 0          12      True  (Atom('C', [4.2383084985129695, 0.459697409092...  \
# 1          19      True  (Atom('C', [3.8467530906650693, 1.839354043106...
# 2          24      True  (Atom('C', [8.327249785857832, 7.0069955918951...
# 3          13      True  (Atom('C', [9.314405253956453, 6.0930346292837...
# 4          14      True  (Atom('C', [5.365509572474384, 7.6424276908099...
#
#                                                  mol   formula     energy
# 0  <rdkit.Chem.rdchem.RWMol object at 0x2aabc3ceb...   C2H7NO2  -1.000136  \
# 1  <rdkit.Chem.rdchem.RWMol object at 0x2aabc3d2f...  C4H11NO3  -1.000005
# 2  <rdkit.Chem.rdchem.RWMol object at 0x2aabc3d33...  C5H16N2O -10.000348
# 3  <rdkit.Chem.rdchem.RWMol object at 0x2aabc3d18...   C2H8N2O   0.000000
# 4  <rdkit.Chem.rdchem.RWMol object at 0x2aabc3ce7...  C2H8N2O2  -1.000000
#
#          bio
# 0  91.842747
# 1  59.586543
# 2  89.152628
# 3  88.316065
# 4  63.339764

# %%
print(df.columns)
# Out:
# Index(['atom_count', 'is_valid', 'ase_atom', 'mol', 'formula', 'energy',
#        'bio'],
#       dtype='object')

# %%
bio_formula = df[['formula', 'bio']]
sorted_df = bio_formula.sort_values(by='bio', ascending=False)
sorted_df.head(31)
# Out:
#      formula        bio
# 66   C4H10O2  97.869533
# 17    C3H8O2  96.311063
# 74     CH4O3  96.086413
# 50  C6H17NO2  95.552856
# 16   C4H13NO  94.837475
# 9     C2H6O3  94.494379
# 93    C3H9NO  94.070482
# 31    C3H9NO  94.070482
# 75    C3H9NO  94.070482
# 63  C4H11NO2  93.415600
# 89  C5H13NO2  93.389195
# 44    C4H10O  93.074262
# 65    C2H8N2  93.035340
# 29     C3H9N  92.770028
# 27    C5H14O  92.737156
# 68    CH6N2O  92.721021
# 80     C6H16  92.676717
# 90    C4H11N  92.288882
# 34     C3H8O  92.025739
# 8      C4H10  91.965729
# 0    C2H7NO2  91.842747
# 69    C5H13N  91.759855
# 18   C3H9NO2  91.685921
# 70    C6H16O  91.406178
# 87   C6H17NO  91.399944
# 99   C2H7NO2  90.960693
# 72    C5H12O  90.417874
# 37  C3H12N2O  90.369385
# 95    C6H17N  89.934278
# 62    C2H6O2  89.846361
# 10    CH6N2O  89.468360

# %%
print(sorted_df['bio'].sum() / 100)
# Out:
# 72.02529186010361

# %%
df.to_csv('vae_generated_test.csv', index=False)

# %%
sorted_df.to_csv('vae_generated_bio_test.csv', index=False)

# %%
random_mol, random_formula = df[['mol','formula']].sample(n=1).iloc[0]
smiles = Chem.MolToSmiles(random_mol.GetMol())
print(random_formula)
print(smiles)
Chem.MolFromSmiles(smiles)
# Out:
# CH6N2O
# NCNO

# %%
error_count = 0
success_count = 0

for index, row in df.iterrows():
    try:
        mol = row['mol']
        smiles = Chem.MolToSmiles(mol)
        new_mol = Chem.MolFromSmiles(smiles)
        if new_mol is not None:
            num_components = len(Chem.GetMolFrags(new_mol))
            if num_components == 1:
                success_count += 1
            else:
                error_count += 1
        else:
            error_count += 1
    except Exception as e:
        error_count += 1

print("Percentage of Valid Molecules", success_count / (error_count + success_count) * 100)
# Out:
# Percentage of Valid Molecules 70.0
