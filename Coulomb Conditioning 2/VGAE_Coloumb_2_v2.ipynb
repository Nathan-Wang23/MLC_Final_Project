# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import os
import numpy as np
from torch_geometric.nn import global_add_pool, GATConv, CGConv, VGAE,GCNConv, RGCNConv, global_mean_pool
import pickle
from itertools import combinations
from sklearn.model_selection import train_test_split
from torch_geometric.data import DataLoader, Data
from torch.utils.data import Dataset, DataLoader
from torch_geometric.data import Data, Batch
from tqdm import tqdm
import torch.optim as optim
import math
from torch_geometric.data import DataLoader
from torch_geometric.nn import RGCNConv, global_mean_pool
from torch_geometric.data import Data, Batch
from torch.utils.data import Dataset, DataLoader
import pickle
from torch.optim import Adam, RMSprop
from tqdm import tqdm
from rdkit.Chem.rdMolDescriptors import CalcMolFormula

# %%
from contextlib import contextmanager
import sys
import os
import torch
from ase import Atoms
from ase.data import chemical_symbols
from ase.calculators.morse import MorsePotential
from ase.optimize import QuasiNewton
import numpy as np
import pickle
from rdkit.Chem import rdchem

import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from ase import Atoms
from ase.io import read
from torch_geometric.data import Data
from torch_geometric.nn import MessagePassing
from torch_geometric.utils import to_networkx
# from torch_geometric.data import DataLoader, TensorDataset
from torch_geometric.loader import DataLoader
from sklearn.model_selection import train_test_split
from ase.build import molecule
import pandas as pd
from rdkit import Chem
from rdkit.Chem import AllChem
import random
from torch_geometric.nn import global_add_pool, GATConv, CGConv, GCNConv, RGCNConv
from torch_geometric.nn.models.schnet import GaussianSmearing
from sklearn.metrics import roc_auc_score, precision_score, confusion_matrix
import matplotlib.pyplot as plt
import pickle
from collections import Counter
import seaborn as sns
import time
from torch.optim.lr_scheduler import StepLR
import torch
from torch_geometric.data import Data
from dscribe.descriptors import SOAP, ACSF, CoulombMatrix

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %%
def debug_nan(tensor, name="Tensor"):
    if torch.isnan(tensor).any():
        print(f"NaN detected in {name}")
        print(tensor)

# %%
class RGCN_VGAE(nn.Module):
    def __init__(self, in_channels, out_channels, num_relations, num_node_features, max_nodes, bond_dim, atom_dim):
        super(RGCN_VGAE, self).__init__()
        self.num_relations = num_relations
        self.max_nodes = max_nodes
        self.atom_dim = atom_dim
        self.bond_dim = bond_dim

        self.rgcn1 = RGCNConv(in_channels, out_channels, num_relations=num_relations)
        self.rgcn2 = RGCNConv(out_channels, out_channels, num_relations=num_relations)
        self.rgcn3 = RGCNConv(out_channels, out_channels, num_relations=num_relations)
        
        self.fc_mu = nn.Linear(out_channels, out_channels)
        self.fc_logvar = nn.Linear(out_channels, out_channels)
        
        self.adj_decoder = nn.Sequential(
            nn.Linear(out_channels + 252, out_channels),
            nn.ReLU(),
            nn.Linear(out_channels, max_nodes * max_nodes * bond_dim)
        )
        self.feature_decoder = nn.Linear(out_channels + 252, max_nodes * atom_dim)
        
        self.cond_pool1 = nn.AdaptiveAvgPool1d(9901)
        self.cond_linear1 = nn.Linear(9901, 3_808)

    def reparameterize(self, mu, logvar):
        if self.training:
            std = torch.exp(0.5 * logvar)
            eps = torch.randn_like(std)
            return eps.mul(std).add_(mu)
        else:
            return mu

    def forward(self, data):
        x, edge_index, edge_attr, batch = data.x, data.edge_index, data.edge_attr, data.batch
        conditional = data.descriptor
        edge_attr = torch.argmax(edge_attr, dim=1).long()

        # print(x.shape)
        # print(edge_index.shape)
        # print(edge_attr.shape)
        x = F.relu(self.rgcn1(x, edge_index, edge_attr))
        x = F.relu(self.rgcn2(x, edge_index, edge_attr))
        # x = F.relu(self.rgcn3(x, edge_index, edge_attr))
        x = global_mean_pool(x, batch)

        mu = self.fc_mu(x)
        logvar = self.fc_logvar(x)
        conditional = conditional.transpose(0,1)
        conditional = conditional.unsqueeze(1)
        conditional = self.cond_pool1(conditional)
        # conditional = conditional.view(1, -1)
        conditional = self.cond_linear1(conditional)
        conditional = conditional.view(952, -1).squeeze(0)

        z = self.reparameterize(mu, logvar)
        z = torch.cat((z, conditional), dim=1)

        A_pred = self.adj_decoder(z).view(-1, self.max_nodes, self.max_nodes, self.bond_dim)
        A_pred = F.softmax(A_pred, dim=-1)

        features_pred = self.feature_decoder(z).view(-1, self.max_nodes, self.atom_dim)
        features_pred = F.softmax(features_pred, dim=-1)
        
        return A_pred, features_pred, mu, logvar
    
    def decode(self, z):    
        A_pred = self.adj_decoder(z).view(-1, self.max_nodes, self.max_nodes, self.bond_dim)
        A_pred = F.softmax(A_pred, dim=-1)

        features_pred = self.feature_decoder(z).view(-1, self.max_nodes, self.atom_dim)
        features_pred = F.softmax(features_pred, dim=-1)
        
        return A_pred, features_pred

# %%
# with open("../data/combined_data.pkl", "rb") as file:
#     combined_data = pickle.load(file)

atomic_number_tensors = torch.load("data/atomic_number_tensors.pt")
bond_tensors = torch.load("data/bond_tensors.pt")

# %%
NUM_ATOMS = 63
ATOM_DIM = 11
BOND_DIM = 5
LATENT_DIM = 256
HIDDEN_CHANNELS = 128
NUM_RELATION_TYPES = BOND_DIM - 1
NODE_FEATURE_DIM = ATOM_DIM - 1
# NODE_FEATURE_DIM = ATOM_DIM
BATCH_SIZE = 512
NUM_EPOCHS = 300

# %%
model = RGCN_VGAE(NODE_FEATURE_DIM, LATENT_DIM, NUM_RELATION_TYPES, NODE_FEATURE_DIM, NUM_ATOMS, BOND_DIM, ATOM_DIM).to(device)

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=0.0001)

# %%
class GraphDataset(Dataset):
    def __init__(self, adjacency_matrices, atom_features):
        self.adjacency_matrices = adjacency_matrices
        self.atom_features = atom_features

    def __len__(self):
        return self.adjacency_matrices.size(0)

    def __getitem__(self, idx):
        return self.adjacency_matrices[idx], self.atom_features[idx]
    
dataset = GraphDataset(bond_tensors, atomic_number_tensors)

dataloader = DataLoader(dataset, batch_size=BATCH_SIZE, shuffle=True)

# %%
weights_atoms = torch.ones(ATOM_DIM).to(device)
weights_bonds = torch.ones(BOND_DIM).to(device)

weights_atoms[0] = 0.5
weights_atoms[10] = 8
weights_bonds[4] = 0.5

weights_atoms.to(device)
weights_bonds.to(device)

def calculate_kl_divergence(mu, logvar):
    kl_divergence = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp())
    return kl_divergence

# def calculate_uniqueness_loss(bonds_pred, atoms_pred):
#     datapoints = process_graph_data_to_data_objects(bonds_pred, atoms_pred)
#     num_unique = 0
#     seen_set = set()
#     for dp in datapoints:
#         mol, formula = to_chemula(dp)
#         if formula not in seen_set:
#             num_unique += 1
#             seen_set.add(formula)
#     return num_unique

def loss_function(preds, labels, mu, logvar, preds_atomic, atomic_numbers, lambda_kld, device):

    batch_size = preds.shape[0]
    labels = torch.argmax(labels, dim=-1)
    atomic_numbers = torch.argmax(atomic_numbers, dim=-1)
    preds, labels = preds.to(device), labels.to(device)
    preds_atomic, atomic_numbers = preds_atomic.to(device), atomic_numbers.to(device)
    mu, logvar = mu.to(device), logvar.to(device)

    # print(preds.shape)
    # print(labels.shape)
    # print(preds_atomic.shape)
    # print(atomic_numbers.shape)

    ce_bond = F.cross_entropy(preds.view(-1, preds.size(-1)), labels.view(-1), weight=weights_bonds.to(device))
    ce_atomic = F.cross_entropy(preds_atomic.view(-1, preds_atomic.size(-1)), atomic_numbers.view(-1), weight=weights_atoms.to(device))
    
    kld = calculate_kl_divergence(mu, logvar)

    atom_presence_mask = torch.argmax(preds_atomic, dim=-1) != 10
    atom_count = torch.sum(atom_presence_mask)
    atom_count = atom_count / batch_size
    atomic_regulizer = atom_count / batch_size * 3


    bond_presence_mask = torch.argmax(preds, dim=-1) != 4
    bond_count = torch.sum(bond_presence_mask)
    bond_count = bond_count / batch_size

    if int(atom_count) <= 50:
        print(atom_count)
        atomic_regulizer = 2000 - 10 * int(atom_count)

    if bond_count < 100:
        bond_regulizer = 0.0
    elif bond_count <= 50:
        bond_regulizer = 2000 - 5 * bond_count
    else:
        bond_regulizer = 10

    # unique_counts = set()

    # for b in preds_atomic:
    #     atom_counts = np.zeros(11, dtype=int)
    #     for j in range(63):
    #         for k in range(11):
    #             if b[j, k] == 1:
    #                 atom_counts[k] += 1
    #     counts_tuple = tuple(atom_counts)
    #     unique_counts.add(counts_tuple)

    # num_same = len(unique_counts)
    # print(num_same)

    total_loss = 0.7 * ce_bond + lambda_kld * kld + 1.9 * ce_atomic + 0.6 * atomic_regulizer + 0.2 * bond_regulizer

    print(kld, ce_atomic, ce_bond, atomic_regulizer, bond_regulizer)
    return total_loss

# %%
atomic_mapping = {0: 6, 1: 7, 2:8, 3:9, 4:14, 5:15, 6:16, 7:17, 8:35, 9:53}

# %%
def create_feature_descriptor(atomic_nums):
    numbers = torch.argmax(atomic_nums, dim=-1)
    numbers = [atomic_mapping[index.item()] for index in numbers if index < 10]

    positions = np.random.rand(len(numbers), 3) * 10

    atoms = Atoms(numbers=numbers, positions=positions)

    cm = CoulombMatrix(n_atoms_max=len(numbers), permutation="sorted_l2")

    cm_descriptor = cm.create(atoms).reshape(len(numbers), len(numbers))
    if len(numbers) < 63:
        cm_descriptor = np.pad(cm_descriptor, ((0, 63 - len(numbers)), (0, 63 - len(numbers))), mode='constant', constant_values=0)
    return cm_descriptor

# %%
def process_graph_data_to_data_objects(batch_adjacency, batch_atoms, grad = False):
    batch_size = batch_adjacency.shape[0]
    num_nodes = batch_adjacency.shape[1]
    num_bond_types = batch_adjacency.shape[3] - 1 
    num_atom_types = batch_atoms.shape[2] - 1
    # print(num_atom_types)
    
    data_objects = []

    for idx in range(batch_size):
        edge_index = []
        edge_attr = []
        x = []
        node_index_map = {}
        
        adjacency = batch_adjacency[idx]
        atoms = batch_atoms[idx]
        
        new_idx = 0
            
        descriptor = torch.tensor(create_feature_descriptor(atoms), dtype=torch.float32)
        # padded_descriptor = np.pad(descriptor, ((0, 0), (0, 9000 - descriptor.shape[1])), mode='constant', constant_values=0)
        # padded_descriptor = torch.tensor(padded_descriptor)
        # print(padded_descriptor.shape)

        for i in range(num_nodes):
            for j in range(i + 1, num_nodes):
                bond_type = torch.argmax(adjacency[i, j])
                # if adjacency[i,j][num_bond_types] > 0.18:
                #     # print('overwrite')
                    # continue
                if bond_type < num_bond_types:  # Bond exists
                    atom_type_i = torch.argmax(atoms[i])
                    atom_type_j = torch.argmax(atoms[j])
                    if atom_type_i == num_atom_types or atom_type_j == num_atom_types: # Both atoms must exist
                        continue
                    if i not in node_index_map:
                        node_index_map[i] = new_idx
                        new_idx+=1
                        x.append(torch.nn.functional.one_hot(torch.argmax(atoms[i]), num_classes=num_atom_types).float())
                    if j not in node_index_map:
                        node_index_map[j] = new_idx
                        new_idx+=1
                        x.append(torch.nn.functional.one_hot(torch.argmax(atoms[j]), num_classes=num_atom_types).float())
                    edge_index.append([node_index_map[i], node_index_map[j]])
                    bond_one_hot = torch.zeros(num_bond_types)
                    bond_one_hot[bond_type] = 1
                    edge_attr.append(bond_one_hot)
                    # print(bond_type)
                    # edge_attr.append(bond_type/num_bond_types)

        if edge_index:
            edge_index_tensor = torch.tensor(edge_index, dtype=torch.long).t().contiguous()
            edge_attr_tensor = torch.stack(edge_attr, dim=0)

        else:
       
            edge_index_tensor = torch.empty((2, 0), dtype=torch.long)
            edge_attr_tensor = torch.empty((0, num_bond_types), dtype=torch.float)
            

        if x:
            node_features_tensor = torch.stack(x, dim=0)
        else:
           
            node_features_tensor = torch.empty((0, num_atom_types), dtype=torch.float)

   
        # if grad:
        #     node_features_tensor.requires_grad_(True)
        #     edge_attr.requires_grad_(True)
        graph_data = Data(x=node_features_tensor, edge_index=edge_index_tensor, edge_attr=edge_attr_tensor, adj_matrix=adjacency, node_features=atoms, descriptor=descriptor)
        data_objects.append(graph_data)

    return data_objects

# %%
data_dataset = []
for adj_matrix, node_features in dataloader:
    adj_matrix.to(device)
    node_features.to(device)
    data = process_graph_data_to_data_objects(adj_matrix, node_features)
    data_dataset.append(data)

data_object_loader = DataLoader(data_dataset, batch_size=BATCH_SIZE, shuffle=True)

# %%
for b in data_object_loader:
    print(b[2])
    break
# Out:
# DataBatch(x=[134, 10], edge_index=[2, 137], edge_attr=[137, 4], adj_matrix=[441, 63, 5], node_features=[441, 11], descriptor=[441, 63], batch=[134], ptr=[8])

# %%
num_epochs = 700
for epoch in range(num_epochs):
    total_loss = 0
    #lambda_kld = min(1.0, 0.01 +  epoch/ num_epochs)
    lambda_kld = 1.3
    batch_count = 0
    for data in data_object_loader:
        # print(adj_matrix.shape)
        optimizer.zero_grad()

        # adj_matrix.to(device)
        # node_features.to(device)
        
        # data = process_graph_data_to_data_objects(adj_matrix, node_features)
        data = Batch.from_data_list(data).to(device)

        reconstructed, reconstructed_atoms, mu, logvar = model(data)
        
        loss = loss_function(
            reconstructed, data.adj_matrix, 
            mu, logvar, 
            reconstructed_atoms, data.node_features, 
            lambda_kld, device
        )
        total_loss += loss.item()
        
        # Backpropagation
        loss.backward()
        optimizer.step()

        #for name, param in model.named_parameters():
        #    if param.requires_grad:
        #        print(f"Gradients of {name}: {param.grad}")

    # Calculate average loss for reporting
    avg_loss = total_loss / len(dataloader)
    print(f'Epoch {epoch + 1}, Loss: {loss.item()}')
# Out:
# tensor(503.1967, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.4052, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.6176, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.1808, device='cuda:0') 10
# Epoch 1, Loss: 661.9663696289062
# tensor(470.3438, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3978, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.6149, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.1784, device='cuda:0') 10
# Epoch 2, Loss: 619.240234375
# tensor(439.8306, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3831, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.6119, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.1745, device='cuda:0') 10
# Epoch 3, Loss: 579.5406494140625
# tensor(411.4766, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3750, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.6084, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.1721, device='cuda:0') 10
# Epoch 4, Loss: 542.6612548828125
# tensor(385.1368, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3688, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.6045, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.1706, device='cuda:0') 10
# Epoch 5, Loss: 508.40411376953125
# tensor(360.6724, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3551, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.6001, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.1665, device='cuda:0') 10
# Epoch 6, Loss: 476.5688171386719
# tensor(337.9209, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3326, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.5947, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.1612, device='cuda:0') 10
# Epoch 7, Loss: 446.9420166015625
# tensor(50.3508, device='cuda:0')
# tensor(316.7758, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3244, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.5893, device='cuda:0', grad_fn=<NllLossBackward0>) 1500 10
# Epoch 8, Loss: 1319.33740234375
# tensor(49.6922, device='cuda:0')
# tensor(297.1300, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3136, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.5832, device='cuda:0', grad_fn=<NllLossBackward0>) 1510 10
# Epoch 9, Loss: 1299.773193359375
# tensor(47.4307, device='cuda:0')
# tensor(278.8553, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.2858, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.5752, device='cuda:0', grad_fn=<NllLossBackward0>) 1530 10
# Epoch 10, Loss: 1287.95751953125
# tensor(46.5630, device='cuda:0')
# tensor(261.8374, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.2745, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.5675, device='cuda:0', grad_fn=<NllLossBackward0>) 1540 10
# Epoch 11, Loss: 1271.807373046875
# tensor(43.8046, device='cuda:0')
# tensor(245.9677, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.2416, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.5568, device='cuda:0', grad_fn=<NllLossBackward0>) 1570 10
# Epoch 12, Loss: 1269.106689453125
# tensor(42.8908, device='cuda:0')
# tensor(231.1484, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.2281, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.5477, device='cuda:0', grad_fn=<NllLossBackward0>) 1580 10
# Epoch 13, Loss: 1255.809814453125
# tensor(40.8340, device='cuda:0')
# tensor(217.3059, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.2044, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.5361, device='cuda:0', grad_fn=<NllLossBackward0>) 1600 10
# Epoch 14, Loss: 1249.76123046875
# tensor(37.9370, device='cuda:0')
# tensor(204.3473, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.1705, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.5212, device='cuda:0', grad_fn=<NllLossBackward0>) 1630 10
# Epoch 15, Loss: 1250.8402099609375
# tensor(36.5578, device='cuda:0')
# tensor(192.2143, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.1518, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.5092, device='cuda:0', grad_fn=<NllLossBackward0>) 1640 10
# Epoch 16, Loss: 1241.0234375
# tensor(34.0473, device='cuda:0')
# tensor(180.8553, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.1209, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.4924, device='cuda:0', grad_fn=<NllLossBackward0>) 1660 10
# Epoch 17, Loss: 1238.186279296875
# tensor(33.2216, device='cuda:0')
# tensor(170.2090, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.1085, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.4794, device='cuda:0', grad_fn=<NllLossBackward0>) 1670 10
# Epoch 18, Loss: 1230.3134765625
# tensor(32.4181, device='cuda:0')
# tensor(160.2277, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.0924, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.4644, device='cuda:0', grad_fn=<NllLossBackward0>) 1680 10
# Epoch 19, Loss: 1223.296630859375
# tensor(29.1397, device='cuda:0')
# tensor(150.8664, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.0494, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.4388, device='cuda:0', grad_fn=<NllLossBackward0>) 1710 10
# Epoch 20, Loss: 1229.02734375
# tensor(28.0914, device='cuda:0')
# tensor(142.0675, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.0364, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.4224, device='cuda:0', grad_fn=<NllLossBackward0>) 1720 10
# Epoch 21, Loss: 1223.552490234375
# tensor(26.4916, device='cuda:0')
# tensor(133.7944, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.0145, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.4020, device='cuda:0', grad_fn=<NllLossBackward0>) 1740 10
# Epoch 22, Loss: 1224.74169921875
# tensor(25.4748, device='cuda:0')
# tensor(126.0307, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.9974, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.3819, device='cuda:0', grad_fn=<NllLossBackward0>) 1750 10
# Epoch 23, Loss: 1220.6024169921875
# tensor(23.7143, device='cuda:0')
# tensor(118.7356, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.9712, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.3576, device='cuda:0', grad_fn=<NllLossBackward0>) 1770 10
# Epoch 24, Loss: 1223.0517578125
# tensor(22.3813, device='cuda:0')
# tensor(111.8592, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.9518, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.3355, device='cuda:0', grad_fn=<NllLossBackward0>) 1780 10
# Epoch 25, Loss: 1220.06005859375
# tensor(20.5630, device='cuda:0')
# tensor(105.3929, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.9277, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.3115, device='cuda:0', grad_fn=<NllLossBackward0>) 1800 10
# Epoch 26, Loss: 1223.59130859375
# tensor(19.8351, device='cuda:0')
# tensor(99.3079, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.9131, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.2909, device='cuda:0', grad_fn=<NllLossBackward0>) 1810 10
# Epoch 27, Loss: 1221.6387939453125
# tensor(18.4779, device='cuda:0')
# tensor(93.5796, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.8927, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.2673, device='cuda:0', grad_fn=<NllLossBackward0>) 1820 10
# Epoch 28, Loss: 1220.13671875
# tensor(17.3183, device='cuda:0')
# tensor(88.1764, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.8753, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.2458, device='cuda:0', grad_fn=<NllLossBackward0>) 1830 10
# Epoch 29, Loss: 1219.064453125
# tensor(16.5000, device='cuda:0')
# tensor(83.0909, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.8606, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.2251, device='cuda:0', grad_fn=<NllLossBackward0>) 1840 10
# Epoch 30, Loss: 1218.410888671875
# tensor(16.8519, device='cuda:0')
# tensor(78.3056, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.8643, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.2174, device='cuda:0', grad_fn=<NllLossBackward0>) 1840 10
# Epoch 31, Loss: 1212.191650390625
# tensor(16.7269, device='cuda:0')
# tensor(73.8035, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.8663, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.2081, device='cuda:0', grad_fn=<NllLossBackward0>) 1840 10
# Epoch 32, Loss: 1206.3360595703125
# tensor(15.4076, device='cuda:0')
# tensor(69.5689, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.8437, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.1832, device='cuda:0', grad_fn=<NllLossBackward0>) 1850 10
# Epoch 33, Loss: 1206.7708740234375
# tensor(14.8613, device='cuda:0')
# tensor(65.5948, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.8342, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.1669, device='cuda:0', grad_fn=<NllLossBackward0>) 1860 10
# Epoch 34, Loss: 1207.5750732421875
# tensor(14.0546, device='cuda:0')
# tensor(61.8542, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.8140, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.1440, device='cuda:0', grad_fn=<NllLossBackward0>) 1860 10
# Epoch 35, Loss: 1202.65771484375
# tensor(15.0242, device='cuda:0')
# tensor(58.3358, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.8298, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.1463, device='cuda:0', grad_fn=<NllLossBackward0>) 1850 10
# Epoch 36, Loss: 1192.11572265625
# tensor(12.7405, device='cuda:0')
# tensor(55.0309, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.7898, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.1112, device='cuda:0', grad_fn=<NllLossBackward0>) 1880 10
# Epoch 37, Loss: 1205.7186279296875
# tensor(13.1555, device='cuda:0')
# tensor(51.9232, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.7988, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.1135, device='cuda:0', grad_fn=<NllLossBackward0>) 1870 10
# Epoch 38, Loss: 1195.697265625
# tensor(13.2332, device='cuda:0')
# tensor(49.0076, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.7997, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.1092, device='cuda:0', grad_fn=<NllLossBackward0>) 1870 10
# Epoch 39, Loss: 1191.90576171875
# tensor(11.6796, device='cuda:0')
# tensor(46.2740, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.7717, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.0853, device='cuda:0', grad_fn=<NllLossBackward0>) 1890 10
# Epoch 40, Loss: 1200.2821044921875
# tensor(11.2689, device='cuda:0')
# tensor(43.7142, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.7624, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.0758, device='cuda:0', grad_fn=<NllLossBackward0>) 1890 10
# Epoch 41, Loss: 1196.93017578125
# tensor(10.6786, device='cuda:0')
# tensor(41.3182, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.7498, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.0631, device='cuda:0', grad_fn=<NllLossBackward0>) 1900 10
# Epoch 42, Loss: 1199.782470703125
# tensor(11.5431, device='cuda:0')
# tensor(39.0756, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.7680, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.0731, device='cuda:0', grad_fn=<NllLossBackward0>) 1890 10
# Epoch 43, Loss: 1190.90869140625
# tensor(10.4643, device='cuda:0')
# tensor(36.9796, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.7485, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.0556, device='cuda:0', grad_fn=<NllLossBackward0>) 1900 10
# Epoch 44, Loss: 1194.134521484375
# tensor(10.4853, device='cuda:0')
# tensor(35.0175, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.7443, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.0503, device='cuda:0', grad_fn=<NllLossBackward0>) 1900 10
# Epoch 45, Loss: 1191.5721435546875
# tensor(10.5987, device='cuda:0')
# tensor(33.1866, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.7442, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.0473, device='cuda:0', grad_fn=<NllLossBackward0>) 1900 10
# Epoch 46, Loss: 1189.189697265625
# tensor(10.5956, device='cuda:0')
# tensor(31.4783, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.7411, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.0425, device='cuda:0', grad_fn=<NllLossBackward0>) 1900 10
# Epoch 47, Loss: 1186.959716796875
# tensor(9.6050, device='cuda:0')
# tensor(29.8822, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.7225, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.0255, device='cuda:0', grad_fn=<NllLossBackward0>) 1910 0.0
# Epoch 48, Loss: 1188.83740234375
# tensor(10.3099, device='cuda:0')
# tensor(28.3946, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.7373, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.0336, device='cuda:0', grad_fn=<NllLossBackward0>) 1900 0.0
# Epoch 49, Loss: 1180.9375
# tensor(9.9790, device='cuda:0')
# tensor(27.0097, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.7253, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.0235, device='cuda:0', grad_fn=<NllLossBackward0>) 1910 0.0
# Epoch 50, Loss: 1185.1070556640625
# tensor(9.2962, device='cuda:0')
# tensor(25.7193, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.7158, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.0139, device='cuda:0', grad_fn=<NllLossBackward0>) 1910 0.0
# Epoch 51, Loss: 1183.4049072265625
# tensor(9.3529, device='cuda:0')
# tensor(24.5180, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.7154, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.0121, device='cuda:0', grad_fn=<NllLossBackward0>) 1910 0.0
# Epoch 52, Loss: 1181.8411865234375
# tensor(9.1502, device='cuda:0')
# tensor(23.4029, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.7047, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.0044, device='cuda:0', grad_fn=<NllLossBackward0>) 1910 0.0
# Epoch 53, Loss: 1180.3658447265625
# tensor(8.9632, device='cuda:0')
# tensor(22.3682, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6991, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9995, device='cuda:0', grad_fn=<NllLossBackward0>) 1920 0.0
# Epoch 54, Loss: 1185.006591796875
# tensor(8.9118, device='cuda:0')
# tensor(21.4065, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.7010, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9982, device='cuda:0', grad_fn=<NllLossBackward0>) 1920 0.0
# Epoch 55, Loss: 1183.759033203125
# tensor(9.2889, device='cuda:0')
# tensor(20.5142, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.7091, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.0032, device='cuda:0', grad_fn=<NllLossBackward0>) 1910 0.0
# Epoch 56, Loss: 1176.6180419921875
# tensor(8.8466, device='cuda:0')
# tensor(19.6863, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.7000, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9952, device='cuda:0', grad_fn=<NllLossBackward0>) 1920 0.0
# Epoch 57, Loss: 1181.5189208984375
# tensor(8.9086, device='cuda:0')
# tensor(18.9200, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.7016, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9958, device='cuda:0', grad_fn=<NllLossBackward0>) 1920 0.0
# Epoch 58, Loss: 1180.5260009765625
# tensor(8.8204, device='cuda:0')
# tensor(18.2115, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6970, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9915, device='cuda:0', grad_fn=<NllLossBackward0>) 1920 0.0
# Epoch 59, Loss: 1179.59326171875
# tensor(8.7447, device='cuda:0')
# tensor(17.5566, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6980, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9912, device='cuda:0', grad_fn=<NllLossBackward0>) 1920 0.0
# Epoch 60, Loss: 1178.7435302734375
# tensor(8.7416, device='cuda:0')
# tensor(16.9507, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6889, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9859, device='cuda:0', grad_fn=<NllLossBackward0>) 1920 0.0
# Epoch 61, Loss: 1177.9349365234375
# tensor(8.6187, device='cuda:0')
# tensor(16.3902, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6863, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9830, device='cuda:0', grad_fn=<NllLossBackward0>) 1920 0.0
# Epoch 62, Loss: 1177.1993408203125
# tensor(8.4748, device='cuda:0')
# tensor(15.8712, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6853, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9816, device='cuda:0', grad_fn=<NllLossBackward0>) 1920 0.0
# Epoch 63, Loss: 1176.5216064453125
# tensor(8.9853, device='cuda:0')
# tensor(15.3898, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6962, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9886, device='cuda:0', grad_fn=<NllLossBackward0>) 1920 0.0
# Epoch 64, Loss: 1175.9215087890625
# tensor(8.3078, device='cuda:0')
# tensor(14.9426, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6795, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9772, device='cuda:0', grad_fn=<NllLossBackward0>) 1920 0.0
# Epoch 65, Loss: 1175.3004150390625
# tensor(8.3351, device='cuda:0')
# tensor(14.5271, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6783, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9758, device='cuda:0', grad_fn=<NllLossBackward0>) 1920 0.0
# Epoch 66, Loss: 1174.7569580078125
# tensor(8.2763, device='cuda:0')
# tensor(14.1404, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6792, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9757, device='cuda:0', grad_fn=<NllLossBackward0>) 1920 0.0
# Epoch 67, Loss: 1174.256103515625
# tensor(8.2941, device='cuda:0')
# tensor(13.7804, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6772, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9739, device='cuda:0', grad_fn=<NllLossBackward0>) 1920 0.0
# Epoch 68, Loss: 1173.782958984375
# tensor(8.1334, device='cuda:0')
# tensor(13.4446, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6721, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9710, device='cuda:0', grad_fn=<NllLossBackward0>) 1920 0.0
# Epoch 69, Loss: 1173.334716796875
# tensor(8.5053, device='cuda:0')
# tensor(13.1308, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6772, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9741, device='cuda:0', grad_fn=<NllLossBackward0>) 1920 0.0
# Epoch 70, Loss: 1172.9385986328125
# tensor(8.1639, device='cuda:0')
# tensor(12.8370, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6715, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9694, device='cuda:0', grad_fn=<NllLossBackward0>) 1920 0.0
# Epoch 71, Loss: 1172.5426025390625
# tensor(8.6586, device='cuda:0')
# tensor(12.5619, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6850, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9784, device='cuda:0', grad_fn=<NllLossBackward0>) 1920 0.0
# Epoch 72, Loss: 1172.216796875
# tensor(7.8676, device='cuda:0')
# tensor(12.3037, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6611, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9640, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 73, Loss: 1177.82568359375
# tensor(8.0525, device='cuda:0')
# tensor(12.0602, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6653, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9663, device='cuda:0', grad_fn=<NllLossBackward0>) 1920 0.0
# Epoch 74, Loss: 1171.5186767578125
# tensor(8.5315, device='cuda:0')
# tensor(11.8306, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6788, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9740, device='cuda:0', grad_fn=<NllLossBackward0>) 1920 0.0
# Epoch 75, Loss: 1171.251220703125
# tensor(7.8382, device='cuda:0')
# tensor(11.6139, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6599, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9626, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 76, Loss: 1176.925537109375
# tensor(8.4349, device='cuda:0')
# tensor(11.4090, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6766, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9715, device='cuda:0', grad_fn=<NllLossBackward0>) 1920 0.0
# Epoch 77, Loss: 1170.697265625
# tensor(8.4643, device='cuda:0')
# tensor(11.2151, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6775, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9717, device='cuda:0', grad_fn=<NllLossBackward0>) 1920 0.0
# Epoch 78, Loss: 1170.447021484375
# tensor(8.2458, device='cuda:0')
# tensor(11.0311, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6692, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9672, device='cuda:0', grad_fn=<NllLossBackward0>) 1920 0.0
# Epoch 79, Loss: 1170.1890869140625
# tensor(7.8750, device='cuda:0')
# tensor(10.8562, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6564, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9609, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 80, Loss: 1175.9327392578125
# tensor(7.7479, device='cuda:0')
# tensor(10.6896, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6550, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9599, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 81, Loss: 1175.712890625
# tensor(8.0714, device='cuda:0')
# tensor(10.5307, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6624, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9634, device='cuda:0', grad_fn=<NllLossBackward0>) 1920 0.0
# Epoch 82, Loss: 1169.52294921875
# tensor(7.7237, device='cuda:0')
# tensor(10.3789, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6549, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9592, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 83, Loss: 1175.3084716796875
# tensor(7.9538, device='cuda:0')
# tensor(10.2337, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6596, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9620, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 84, Loss: 1175.13037109375
# tensor(7.7563, device='cuda:0')
# tensor(10.0946, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6558, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9585, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 85, Loss: 1174.9398193359375
# tensor(8.0452, device='cuda:0')
# tensor(9.9605, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6634, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9632, device='cuda:0', grad_fn=<NllLossBackward0>) 1920 0.0
# Epoch 86, Loss: 1168.7833251953125
# tensor(7.9202, device='cuda:0')
# tensor(9.8307, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6605, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9613, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 87, Loss: 1174.60791015625
# tensor(8.0903, device='cuda:0')
# tensor(9.7056, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6658, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9639, device='cuda:0', grad_fn=<NllLossBackward0>) 1920 0.0
# Epoch 88, Loss: 1168.45703125
# tensor(8.0095, device='cuda:0')
# tensor(9.5846, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6614, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9616, device='cuda:0', grad_fn=<NllLossBackward0>) 1920 0.0
# Epoch 89, Loss: 1168.2896728515625
# tensor(7.4727, device='cuda:0')
# tensor(9.4680, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6434, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9537, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 90, Loss: 1174.098388671875
# tensor(7.5893, device='cuda:0')
# tensor(9.3555, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6472, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9549, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 91, Loss: 1173.960205078125
# tensor(7.5903, device='cuda:0')
# tensor(9.2469, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6462, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9544, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 92, Loss: 1173.81689453125
# tensor(7.5567, device='cuda:0')
# tensor(9.1418, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6483, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9549, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 93, Loss: 1173.6845703125
# tensor(8.0021, device='cuda:0')
# tensor(9.0400, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6562, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9596, device='cuda:0', grad_fn=<NllLossBackward0>) 1920 0.0
# Epoch 94, Loss: 1167.5704345703125
# tensor(7.7931, device='cuda:0')
# tensor(8.9412, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6502, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9567, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 95, Loss: 1173.4285888671875
# tensor(7.3887, device='cuda:0')
# tensor(8.8452, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6432, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9523, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 96, Loss: 1173.2874755859375
# tensor(7.5042, device='cuda:0')
# tensor(8.7519, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6443, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9532, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 97, Loss: 1173.1689453125
# tensor(7.8382, device='cuda:0')
# tensor(8.6612, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6499, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9562, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 98, Loss: 1173.063720703125
# tensor(7.5683, device='cuda:0')
# tensor(8.5729, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6454, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9536, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 99, Loss: 1172.9385986328125
# tensor(7.3960, device='cuda:0')
# tensor(8.4870, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6397, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9509, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 100, Loss: 1172.814208984375
# tensor(7.8277, device='cuda:0')
# tensor(8.4035, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6508, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9560, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 101, Loss: 1172.7303466796875
# tensor(7.7027, device='cuda:0')
# tensor(8.3222, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6496, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9551, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 102, Loss: 1172.62158203125
# tensor(7.8235, device='cuda:0')
# tensor(8.2428, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6494, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9557, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 103, Loss: 1172.5185546875
# tensor(7.2983, device='cuda:0')
# tensor(8.1652, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6370, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9495, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 104, Loss: 1172.3897705078125
# tensor(7.5903, device='cuda:0')
# tensor(8.0895, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6442, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9535, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 105, Loss: 1172.3077392578125
# tensor(7.6408, device='cuda:0')
# tensor(8.0154, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6476, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9542, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 106, Loss: 1172.218505859375
# tensor(7.5651, device='cuda:0')
# tensor(7.9429, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6436, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9526, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 107, Loss: 1172.115478515625
# tensor(7.4569, device='cuda:0')
# tensor(7.8717, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6388, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9507, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 108, Loss: 1172.012451171875
# tensor(7.2784, device='cuda:0')
# tensor(7.8020, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6362, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9491, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 109, Loss: 1171.9156494140625
# tensor(7.3992, device='cuda:0')
# tensor(7.7336, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6376, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9499, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 110, Loss: 1171.8299560546875
# tensor(7.6092, device='cuda:0')
# tensor(7.6665, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6456, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9528, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 111, Loss: 1171.7601318359375
# tensor(7.1901, device='cuda:0')
# tensor(7.6008, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6298, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9469, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 112, Loss: 1171.640625
# tensor(7.6796, device='cuda:0')
# tensor(7.5364, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6480, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9537, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 113, Loss: 1171.5960693359375
# tensor(7.2763, device='cuda:0')
# tensor(7.4733, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6313, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9473, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 114, Loss: 1171.477783203125
# tensor(7.1723, device='cuda:0')
# tensor(7.4112, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6288, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9462, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 115, Loss: 1171.3917236328125
# tensor(7.2784, device='cuda:0')
# tensor(7.3503, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6319, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9481, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 116, Loss: 1171.3197021484375
# tensor(7.1975, device='cuda:0')
# tensor(7.2904, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6344, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9475, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 117, Loss: 1171.2462158203125
# tensor(7.1849, device='cuda:0')
# tensor(7.2314, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6312, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9468, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 118, Loss: 1171.1629638671875
# tensor(7.2395, device='cuda:0')
# tensor(7.1733, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6317, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9472, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 119, Loss: 1171.088623046875
# tensor(7.1691, device='cuda:0')
# tensor(7.1162, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6315, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9468, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 120, Loss: 1171.0135498046875
# tensor(7.1492, device='cuda:0')
# tensor(7.0599, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6293, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9463, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 121, Loss: 1170.93603515625
# tensor(7.1901, device='cuda:0')
# tensor(7.0044, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6316, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9469, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 122, Loss: 1170.86865234375
# tensor(7.1366, device='cuda:0')
# tensor(6.9498, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6292, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9458, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 123, Loss: 1170.792236328125
# tensor(7.4296, device='cuda:0')
# tensor(6.8960, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6394, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9497, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 124, Loss: 1170.744384765625
# tensor(7.0641, device='cuda:0')
# tensor(6.8430, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6282, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9446, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 125, Loss: 1170.650634765625
# tensor(7.0399, device='cuda:0')
# tensor(6.7908, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6246, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9441, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 126, Loss: 1170.5755615234375
# tensor(7.5336, device='cuda:0')
# tensor(6.7393, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6380, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9495, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 127, Loss: 1170.5380859375
# tensor(7.2416, device='cuda:0')
# tensor(6.6886, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6333, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9471, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 128, Loss: 1170.46142578125
# tensor(7.0147, device='cuda:0')
# tensor(6.6385, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6293, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9442, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 129, Loss: 1170.3865966796875
# tensor(7.0693, device='cuda:0')
# tensor(6.5891, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6295, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9450, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 130, Loss: 1170.3233642578125
# tensor(7.1670, device='cuda:0')
# tensor(6.5404, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6300, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9460, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 131, Loss: 1170.26171875
# tensor(7.4107, device='cuda:0')
# tensor(6.4922, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6389, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9497, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 132, Loss: 1170.218505859375
# tensor(7.0536, device='cuda:0')
# tensor(6.4447, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6276, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9444, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 133, Loss: 1170.131591796875
# tensor(7.3676, device='cuda:0')
# tensor(6.3979, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6336, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9475, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 134, Loss: 1170.0843505859375
# tensor(7.2111, device='cuda:0')
# tensor(6.3516, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6346, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9468, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 135, Loss: 1170.0255126953125
# tensor(7.0273, device='cuda:0')
# tensor(6.3060, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6238, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9431, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 136, Loss: 1169.943115234375
# tensor(6.9338, device='cuda:0')
# tensor(6.2610, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6235, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9424, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 137, Loss: 1175.8836669921875
# tensor(7.0011, device='cuda:0')
# tensor(6.2166, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6254, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9432, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 138, Loss: 1169.830078125
# tensor(6.9380, device='cuda:0')
# tensor(6.1727, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6213, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9418, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 139, Loss: 1175.7642822265625
# tensor(6.9758, device='cuda:0')
# tensor(6.1295, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6248, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9427, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 140, Loss: 1175.7152099609375
# tensor(7.0336, device='cuda:0')
# tensor(6.0868, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6252, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9433, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 141, Loss: 1169.660888671875
# tensor(7.1124, device='cuda:0')
# tensor(6.0445, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6270, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9448, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 142, Loss: 1169.6104736328125
# tensor(7.1271, device='cuda:0')
# tensor(6.0029, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6269, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9445, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 143, Loss: 1169.5560302734375
# tensor(6.9097, device='cuda:0')
# tensor(5.9617, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6232, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9419, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 144, Loss: 1175.49365234375
# tensor(6.9307, device='cuda:0')
# tensor(5.9210, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6209, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9414, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 145, Loss: 1175.43603515625
# tensor(7.1880, device='cuda:0')
# tensor(5.8809, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6287, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9453, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 146, Loss: 1169.4013671875
# tensor(6.9307, device='cuda:0')
# tensor(5.8411, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6204, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9416, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 147, Loss: 1175.331298828125
# tensor(6.9055, device='cuda:0')
# tensor(5.8019, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6212, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9408, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 148, Loss: 1175.28125
# tensor(7.0347, device='cuda:0')
# tensor(5.7632, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6274, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9434, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 149, Loss: 1169.2445068359375
# tensor(6.8466, device='cuda:0')
# tensor(5.7249, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6196, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9403, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 150, Loss: 1175.1778564453125
# tensor(6.8571, device='cuda:0')
# tensor(5.6870, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6196, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9406, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 151, Loss: 1175.1285400390625
# tensor(7.0851, device='cuda:0')
# tensor(5.6495, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6281, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9443, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 152, Loss: 1169.098876953125
# tensor(6.7857, device='cuda:0')
# tensor(5.6125, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6185, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9399, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 153, Loss: 1175.029296875
# tensor(6.9611, device='cuda:0')
# tensor(5.5759, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6284, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9440, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 154, Loss: 1175.00341796875
# tensor(6.8550, device='cuda:0')
# tensor(5.5397, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6250, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9434, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 155, Loss: 1174.9495849609375
# tensor(6.5200, device='cuda:0')
# tensor(5.5040, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6214, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9417, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 156, Loss: 1174.8948974609375
# tensor(6.3015, device='cuda:0')
# tensor(5.4686, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6165, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9392, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 157, Loss: 1174.837890625
# tensor(6.1870, device='cuda:0')
# tensor(5.4336, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6181, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9394, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 158, Loss: 1174.795654296875
# tensor(6.2847, device='cuda:0')
# tensor(5.3990, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6239, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9427, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 159, Loss: 1174.7640380859375
# tensor(6.1481, device='cuda:0')
# tensor(5.3647, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6184, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9399, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 160, Loss: 1174.7069091796875
# tensor(6.3183, device='cuda:0')
# tensor(5.3308, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6244, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9422, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 161, Loss: 1174.6759033203125
# tensor(6.1324, device='cuda:0')
# tensor(5.2972, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6153, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9385, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 162, Loss: 1174.6124267578125
# tensor(6.3120, device='cuda:0')
# tensor(5.2640, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6202, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9402, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 163, Loss: 1174.579833984375
# tensor(6.4023, device='cuda:0')
# tensor(5.2312, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6207, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9406, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 164, Loss: 1174.5382080078125
# tensor(6.4937, device='cuda:0')
# tensor(5.1986, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6194, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9400, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 165, Loss: 1174.492919921875
# tensor(6.5609, device='cuda:0')
# tensor(5.1664, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6168, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9394, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 166, Loss: 1174.4456787109375
# tensor(6.7206, device='cuda:0')
# tensor(5.1345, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6188, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9401, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 167, Loss: 1174.40869140625
# tensor(6.6880, device='cuda:0')
# tensor(5.1029, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6153, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9382, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 168, Loss: 1174.359619140625
# tensor(6.7647, device='cuda:0')
# tensor(5.0718, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6165, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9392, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 169, Loss: 1174.3221435546875
# tensor(6.7973, device='cuda:0')
# tensor(5.0408, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6205, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9404, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 170, Loss: 1174.2901611328125
# tensor(6.8088, device='cuda:0')
# tensor(5.0102, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6208, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9405, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 171, Loss: 1174.2510986328125
# tensor(6.7090, device='cuda:0')
# tensor(4.9798, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6148, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9376, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 172, Loss: 1174.1981201171875
# tensor(6.7384, device='cuda:0')
# tensor(4.9497, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6156, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9388, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 173, Loss: 1174.161376953125
# tensor(6.7500, device='cuda:0')
# tensor(4.9200, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6131, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9374, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 174, Loss: 1174.1170654296875
# tensor(6.7059, device='cuda:0')
# tensor(4.8905, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6154, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9385, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 175, Loss: 1174.0838623046875
# tensor(6.7206, device='cuda:0')
# tensor(4.8613, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6193, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9395, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 176, Loss: 1174.053955078125
# tensor(6.5315, device='cuda:0')
# tensor(4.8323, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6131, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9368, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 177, Loss: 1174.002685546875
# tensor(6.4779, device='cuda:0')
# tensor(4.8035, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6185, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9394, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 178, Loss: 1173.9774169921875
# tensor(6.4118, device='cuda:0')
# tensor(4.7750, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6149, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9379, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 179, Loss: 1173.9324951171875
# tensor(6.4118, device='cuda:0')
# tensor(4.7467, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6138, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9378, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 180, Loss: 1173.8934326171875
# tensor(6.3708, device='cuda:0')
# tensor(4.7186, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6120, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9370, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 181, Loss: 1173.85302734375
# tensor(6.4118, device='cuda:0')
# tensor(4.6908, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6139, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9376, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 182, Loss: 1173.8206787109375
# tensor(6.4905, device='cuda:0')
# tensor(4.6633, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6137, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9376, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 183, Loss: 1173.78466796875
# tensor(6.5588, device='cuda:0')
# tensor(4.6360, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6170, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9385, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 184, Loss: 1173.756103515625
# tensor(6.5977, device='cuda:0')
# tensor(4.6090, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6126, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9370, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 185, Loss: 1173.7115478515625
# tensor(6.5494, device='cuda:0')
# tensor(4.5823, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6114, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9363, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 186, Loss: 1173.674072265625
# tensor(6.5767, device='cuda:0')
# tensor(4.5557, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6113, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9360, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 187, Loss: 1173.63916015625
# tensor(6.6166, device='cuda:0')
# tensor(4.5294, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6119, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9369, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 188, Loss: 1173.6065673828125
# tensor(6.6124, device='cuda:0')
# tensor(4.5032, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6106, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9357, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 189, Loss: 1173.5693359375
# tensor(6.6313, device='cuda:0')
# tensor(4.4772, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6121, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9367, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 190, Loss: 1173.5390625
# tensor(6.6429, device='cuda:0')
# ...
# Epoch 637, Loss: 1168.654296875
# tensor(6.4128, device='cuda:0')
# tensor(0.7590, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5868, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9299, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 638, Loss: 1168.652587890625
# tensor(6.3792, device='cuda:0')
# tensor(0.7569, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5861, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9300, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 639, Loss: 1168.6485595703125
# tensor(6.4212, device='cuda:0')
# tensor(0.7548, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5858, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9300, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 640, Loss: 1168.6451416015625
# tensor(6.4055, device='cuda:0')
# tensor(0.7527, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5865, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9299, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 641, Loss: 1168.6436767578125
# tensor(6.4118, device='cuda:0')
# tensor(0.7506, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5860, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9300, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 642, Loss: 1168.64013671875
# tensor(6.3813, device='cuda:0')
# tensor(0.7485, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5866, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9299, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 643, Loss: 1168.6385498046875
# tensor(6.4160, device='cuda:0')
# tensor(0.7464, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5866, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9302, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 644, Loss: 1168.635986328125
# tensor(6.4328, device='cuda:0')
# tensor(0.7443, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5864, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9300, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 645, Loss: 1168.6326904296875
# tensor(6.4296, device='cuda:0')
# tensor(0.7422, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5864, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9300, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 646, Loss: 1168.630126953125
# tensor(6.4002, device='cuda:0')
# tensor(0.7402, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5864, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9299, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 647, Loss: 1168.62744140625
# tensor(6.4338, device='cuda:0')
# tensor(0.7381, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5861, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9298, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 648, Loss: 1168.6240234375
# tensor(6.4023, device='cuda:0')
# tensor(0.7361, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5863, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9297, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 649, Loss: 1168.6217041015625
# tensor(6.4149, device='cuda:0')
# tensor(0.7341, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5864, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9300, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 650, Loss: 1168.6195068359375
# tensor(6.4202, device='cuda:0')
# tensor(0.7321, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5857, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9299, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 651, Loss: 1168.615478515625
# tensor(6.3960, device='cuda:0')
# tensor(0.7300, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5864, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9301, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 652, Loss: 1168.6142578125
# tensor(6.4265, device='cuda:0')
# tensor(0.7280, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5860, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9299, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 653, Loss: 1168.61083984375
# tensor(6.4076, device='cuda:0')
# tensor(0.7260, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5863, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9298, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 654, Loss: 1168.608642578125
# tensor(6.4254, device='cuda:0')
# tensor(0.7240, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5866, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9300, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 655, Loss: 1168.6068115234375
# tensor(6.4359, device='cuda:0')
# tensor(0.7221, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5862, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9302, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 656, Loss: 1168.6036376953125
# tensor(6.3813, device='cuda:0')
# tensor(0.7201, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5862, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9296, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 657, Loss: 1168.6007080078125
# tensor(6.3866, device='cuda:0')
# tensor(0.7182, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5856, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9298, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 658, Loss: 1168.59716796875
# tensor(6.4118, device='cuda:0')
# tensor(0.7162, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5861, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9299, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 659, Loss: 1168.5955810546875
# tensor(6.3908, device='cuda:0')
# tensor(0.7143, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5862, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9299, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 660, Loss: 1168.59326171875
# tensor(6.4191, device='cuda:0')
# tensor(0.7123, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5859, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9297, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 661, Loss: 1168.5899658203125
# tensor(6.4296, device='cuda:0')
# tensor(0.7104, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5861, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9299, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 662, Loss: 1168.5880126953125
# tensor(6.4244, device='cuda:0')
# tensor(0.7085, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5865, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9298, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 663, Loss: 1168.586181640625
# tensor(6.3750, device='cuda:0')
# tensor(0.7066, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5859, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9298, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 664, Loss: 1168.5826416015625
# tensor(6.4212, device='cuda:0')
# tensor(0.7047, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5859, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9299, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 665, Loss: 1168.580078125
# tensor(6.4034, device='cuda:0')
# tensor(0.7028, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5861, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9299, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 666, Loss: 1168.5780029296875
# tensor(6.3834, device='cuda:0')
# tensor(0.7009, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5861, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9295, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 667, Loss: 1168.5753173828125
# tensor(6.3981, device='cuda:0')
# tensor(0.6990, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5859, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9300, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 668, Loss: 1168.572998046875
# tensor(6.4034, device='cuda:0')
# tensor(0.6971, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5857, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9300, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 669, Loss: 1168.570068359375
# tensor(6.3571, device='cuda:0')
# tensor(0.6953, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5857, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9296, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 670, Loss: 1168.5675048828125
# tensor(6.3929, device='cuda:0')
# tensor(0.6934, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5865, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9297, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 671, Loss: 1168.5665283203125
# tensor(6.3866, device='cuda:0')
# tensor(0.6916, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5862, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9298, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 672, Loss: 1168.5635986328125
# tensor(6.4065, device='cuda:0')
# tensor(0.6897, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5861, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9300, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 673, Loss: 1168.561279296875
# tensor(6.4433, device='cuda:0')
# tensor(0.6879, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5862, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9299, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 674, Loss: 1168.5589599609375
# tensor(6.4191, device='cuda:0')
# tensor(0.6860, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5865, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9297, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 675, Loss: 1168.5570068359375
# tensor(6.4181, device='cuda:0')
# tensor(0.6843, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5861, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9299, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 676, Loss: 1168.553955078125
# tensor(6.4223, device='cuda:0')
# tensor(0.6824, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5859, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9299, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 677, Loss: 1168.5513916015625
# tensor(6.3981, device='cuda:0')
# tensor(0.6806, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5859, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9297, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 678, Loss: 1168.5489501953125
# tensor(6.3540, device='cuda:0')
# tensor(0.6788, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5857, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9297, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 679, Loss: 1168.546142578125
# tensor(6.4107, device='cuda:0')
# tensor(0.6770, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5855, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9298, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 680, Loss: 1168.5435791015625
# tensor(6.3950, device='cuda:0')
# tensor(0.6752, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5861, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9298, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 681, Loss: 1168.542236328125
# tensor(6.3718, device='cuda:0')
# tensor(0.6735, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5854, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9297, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 682, Loss: 1168.53857421875
# tensor(6.3897, device='cuda:0')
# tensor(0.6717, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5861, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9296, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 683, Loss: 1168.5374755859375
# tensor(6.4139, device='cuda:0')
# tensor(0.6699, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5857, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9297, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 684, Loss: 1168.534423828125
# tensor(6.3561, device='cuda:0')
# tensor(0.6681, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5856, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9295, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 685, Loss: 1168.5318603515625
# tensor(6.3866, device='cuda:0')
# tensor(0.6664, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5857, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9295, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 686, Loss: 1168.52978515625
# tensor(6.4065, device='cuda:0')
# tensor(0.6646, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5862, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9297, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 687, Loss: 1168.5284423828125
# tensor(6.3950, device='cuda:0')
# tensor(0.6629, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5857, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9298, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 688, Loss: 1168.525390625
# tensor(6.4139, device='cuda:0')
# tensor(0.6612, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5857, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9300, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 689, Loss: 1168.5233154296875
# tensor(6.4338, device='cuda:0')
# tensor(0.6594, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5863, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9296, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 690, Loss: 1168.52197265625
# tensor(6.4296, device='cuda:0')
# tensor(0.6577, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5859, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9299, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 691, Loss: 1168.5191650390625
# tensor(6.4139, device='cuda:0')
# tensor(0.6560, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5861, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9297, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 692, Loss: 1168.5172119140625
# tensor(6.4097, device='cuda:0')
# tensor(0.6543, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5863, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9299, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 693, Loss: 1168.5155029296875
# tensor(6.3845, device='cuda:0')
# tensor(0.6526, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5863, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9295, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 694, Loss: 1168.512939453125
# tensor(6.3824, device='cuda:0')
# tensor(0.6509, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5860, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9298, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 695, Loss: 1168.5103759765625
# tensor(6.4286, device='cuda:0')
# tensor(0.6492, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5859, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9298, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 696, Loss: 1168.508056640625
# tensor(6.3750, device='cuda:0')
# tensor(0.6475, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5860, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9293, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 697, Loss: 1168.5057373046875
# tensor(6.3697, device='cuda:0')
# tensor(0.6458, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5857, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9295, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 698, Loss: 1168.5030517578125
# tensor(6.3834, device='cuda:0')
# tensor(0.6442, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5859, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9295, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 699, Loss: 1168.501220703125
# tensor(6.3782, device='cuda:0')
# tensor(0.6425, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5858, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9294, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 700, Loss: 1168.498779296875

# %% [markdown]
# ### Use if Sampling with Conditioning

# %%
def sample_latent_space(mu, logvar, num_samples=1):
    std = torch.exp(0.5 * logvar)
    eps = torch.randn_like(std)  # Random noise
    return mu + eps * std

# %% [markdown]
# ### Use if Sampling without Conditioning

# %%
def sample_z(latent_dim, num_samples=1, device="cuda"):
    return torch.randn(num_samples, latent_dim).to(device)

# %%
def generate_graph(model, num_samples=1, latent_dim=LATENT_DIM+252, device="cuda"):
    z = sample_z(latent_dim, num_samples, device)
    
    with torch.no_grad(): 
        A_pred, features_pred = model.decode(z)
    
    return A_pred, features_pred

# %%
atomic_mapping = {0: 6, 1: 7, 2:8, 3:9, 4:14, 5:15, 6:16, 7:17, 8:35, 9:53}

# %%
def get_bond_type(bond_type):
    bond_type = torch.argmax(bond_type, dim=-1).item()
    if bond_type == 0:
        return rdchem.BondType.SINGLE
    elif bond_type == 1:
        return rdchem.BondType.DOUBLE
    elif bond_type == 2:
        return rdchem.BondType.TRIPLE
    elif bond_type == 3:
        return rdchem.BondType.AROMATIC
    else:
        return None

# %%
def is_valid(data):
    node_features = data.x
    edge_index = data.edge_index
    edge_attr = data.edge_attr

    atomic_numbers = []
    for num in node_features.argmax(dim=-1).tolist():
        atomic_numbers.append(atomic_mapping[num])

    mol = Chem.RWMol()
    for atomic_num in atomic_numbers:
        atom = Chem.Atom(atomic_num)
        mol.AddAtom(atom)

    for i, (bond_start, bond_end) in enumerate(edge_index.t().tolist()):
        bond_val = edge_attr[i]
        bond_type = get_bond_type(bond_val)
        mol.AddBond(bond_start, bond_end, bond_type)

    validity = Chem.SanitizeMol(mol, catchErrors=True)

    return validity == Chem.SanitizeFlags.SANITIZE_NONE

# %%
unique_molecules = set()
def is_unique(data):
    node_features = data.x
    edge_index = data.edge_index
    edge_attr = data.edge_attr

    atomic_numbers = []
    for num in node_features.argmax(dim=-1).tolist():
        atomic_numbers.append(atomic_mapping[num])

    mol = Chem.RWMol()
    for atomic_num in atomic_numbers:
        atom = Chem.Atom(atomic_num)
        mol.AddAtom(atom)

    for i, (bond_start, bond_end) in enumerate(edge_index.t().tolist()):
        bond_val = edge_attr[i]
        bond_type = get_bond_type(bond_val)
        mol.AddBond(bond_start, bond_end, bond_type)

    canonical_smiles = Chem.MolToSmiles(mol, isomericSmiles=True)
    if canonical_smiles not in unique_molecules:
        unique_molecules.add(canonical_smiles)
        return True
    else:
        return False

# %%
# torch.save(model.state_dict(), "models/vae_model_conditioning.pt")

# %%
print(model)
# Out:
# RGCN_VGAE(
#   (rgcn1): RGCNConv(10, 256, num_relations=4)
#   (rgcn2): RGCNConv(256, 256, num_relations=4)
#   (rgcn3): RGCNConv(256, 256, num_relations=4)
#   (fc_mu): Linear(in_features=256, out_features=256, bias=True)
#   (fc_logvar): Linear(in_features=256, out_features=256, bias=True)
#   (adj_decoder): Sequential(
#     (0): Linear(in_features=508, out_features=256, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=256, out_features=19845, bias=True)
#   )
#   (feature_decoder): Linear(in_features=508, out_features=693, bias=True)
#   (cond_pool1): AdaptiveAvgPool1d(output_size=9901)
#   (cond_linear1): Linear(in_features=9901, out_features=3808, bias=True)
# )

# %%
import re
def expand_formula(formula):
    pattern = r'([A-Z][a-z]?)(\d*)'
    expanded_list = []
    total_atoms = 0

    matches = re.findall(pattern, formula)
    for element, count in matches:
        count = int(count) if count else 1
        expanded_list.extend([element] * count)
        total_atoms += count

    return expanded_list, total_atoms

# %%
def get_molecule(datapoint):
    _, formula = to_chemula(datapoint)
    l, total_atoms = expand_formula(formula)

    # #atomic_numbers = datapoint.x.argmax(dim=1).tolist()
    # atomic_numbers_unmapped = datapoint.x.argmax(dim=1).tolist()
    # atomic_numbers = []
    # for at in atomic_numbers_unmapped:
    #     atomic_numbers.append(atomic_mapping[at])
    # positions = datapoint.positions.numpy()
    positions = np.random.rand(len(l), 3) * 10  

    # molecule = Atoms(numbers=atomic_numbers, positions=positions)
    molecule = Atoms(symbols=l, positions=positions)

    return molecule, total_atoms

@contextmanager
def suppress_stdout():
    with open(os.devnull, "w") as devnull:
        old_stdout = sys.stdout
        sys.stdout = devnull
        try:
            yield
        finally:
            sys.stdout = old_stdout

def get_dft(datapoint, De=0.242, re=0.74, alpha=1.5):
    molecule, _ = get_molecule(datapoint)
    print('Molecule:', molecule)
    dft_calculator = MorsePotential(De=De, r0=re, alpha=alpha)
    molecule.set_calculator(dft_calculator)
    # energy = molecule.get_potential_energy()
    with suppress_stdout():
        opt = QuasiNewton(molecule)
        opt.run(fmax=0.02)
    optimized_energy = molecule.get_potential_energy()
    return optimized_energy

# energy = get_dft(datapoint)

# print(f'DFT Energy: {energy} eV')

# %%
def to_chemula(data):
    node_features = data.x
    edge_index = data.edge_index
    edge_attr = data.edge_attr

    atomic_numbers = []
    for num in node_features.argmax(dim=-1).tolist():
        atomic_numbers.append(atomic_mapping[num])

    mol = Chem.RWMol()
    for atomic_num in atomic_numbers:
        atom = Chem.Atom(atomic_num)
        mol.AddAtom(atom)

    for i, (bond_start, bond_end) in enumerate(edge_index.t().tolist()):
        bond_val = edge_attr[i]
        bond_type = get_bond_type(bond_val)
        mol.AddBond(bond_start, bond_end, bond_type)
        
    for atom in mol.GetAtoms():
        atom.UpdatePropertyCache(strict=False)
    # Chem.SanitizeMol(mol)
    return mol, CalcMolFormula(mol)

# %%
Chem.MolFromSmiles('NN')

# %%
class GraphEncoder(nn.Module):
    def __init__(self, input_dim, num_relations):
        super(GraphEncoder, self).__init__()
        self.rgcnconv1 = RGCNConv(input_dim, 512, num_relations=num_relations)
        self.rgcnconv2 = RGCNConv(512, 256, num_relations=num_relations)
        self.rgcnconv3 = RGCNConv(256, 128, num_relations=num_relations)

    def forward(self, x, edge_index, edge_attr):
        x = self.rgcnconv1(x, edge_index, edge_attr)
        x = nn.ReLU()(x)
        x = self.rgcnconv2(x, edge_index, edge_attr)
        x = nn.ReLU()(x)
        x = self.rgcnconv3(x, edge_index, edge_attr)
        x = nn.ReLU()(x)
        return x

class BioClassifier(nn.Module):
    def __init__(self, input_dim, num_heads):
        super(BioClassifier, self).__init__()

        self.encoder = GraphEncoder(input_dim, num_heads)
        self.fc1 = nn.Linear(128, 64)
        self.bn1 = nn.BatchNorm1d(64)
        self.fc2 = nn.Linear(64, 1)
        self.dropout = nn.Dropout(0.4)

    def forward(self, data):
        x, edge_index, edge_attr = data.x, data.edge_index, data.edge_attr
        x = x.float()

        x = self.encoder(x, edge_index, edge_attr)
        x = global_add_pool(x, data.batch)
        x = self.dropout(x)
        x = self.fc1(x)
        x = nn.ReLU()(x)
        x = self.bn1(x)
        x = self.dropout(x)
        x = self.fc2(x)
        x = torch.sigmoid(x)
        return x.squeeze(dim=1)

# %%
model_bio_eval = BioClassifier(10, 4).to(device)

state_dict = torch.load('models/rcgn_model_7428.pt')
model_bio_eval.load_state_dict(state_dict)

model_bio_eval.eval()
def get_model_prediction(datapoint):
    pred = model_bio_eval(datapoint)
    return pred.item()

# %%
# print(datapoint)
# datapoint.edge_attr = torch.argmax(datapoint.edge_attr, dim=1).to(device)
# datapoint.edge_index = datapoint.edge_index.to(device)
# datapoint.x = datapoint.x.to(device)

# %%
# print(datapoint.edge_attr)

# %%
# dft = get_dft(datapoint)
# y = get_model_prediction(datapoint) * 100

# print(f'DFT (remember negative is good): {dft}')
# print(f'Chance of Biodgradability: {y:.2f}%')

# %% [markdown]
# ## Generating from Our Latent Space

# %%
# generated_list_ours = []
# list_len = 100
# for i in tqdm(range(list_len)):
#     bonds_pred_ours, atoms_pred_ours = generate_graph_ours(model)
#     datapoints = process_graph_data_to_data_objects(bonds_pred_ours, atoms_pred_ours)
#     datapoint = datapoints[0]
#     validity = is_valid(datapoint)
#     mol, formula = to_chemula(datapoint)
#     ase_atoms = get_molecule(datapoint)
#     energy = get_dft(datapoint)
#     datapoint.edge_attr = torch.argmax(datapoint.edge_attr, dim=1).to(device)
#     datapoint.edge_index = datapoint.edge_index.to(device)
#     datapoint.x = datapoint.x.to(device)
#     y = get_model_prediction(datapoint) * 100
#     generated_list_ours.append({"bond_preds": bonds_pred, "atom_preds": atoms_pred, "is_valid": validity, "ase_atom": ase_atoms, "mol": mol, "formula": formula, "energy":energy, "bio":y})

# %% [markdown]
# ## Generating from Rand Normal Distribution

# %%
generated_list = []

num_errors = 0

while len(generated_list) < 100:
    try:
        bonds_pred, atoms_pred = generate_graph(model)
        datapoints = process_graph_data_to_data_objects(bonds_pred, atoms_pred)
        datapoint = datapoints[0]
        validity = is_valid(datapoint)
        mol, formula = to_chemula(datapoint)
        ase_atoms, total_atoms = get_molecule(datapoint)
        energy = get_dft(datapoint)
        datapoint.edge_attr = torch.argmax(datapoint.edge_attr, dim=1).to(device)
        datapoint.edge_index = datapoint.edge_index.to(device)
        datapoint.x = datapoint.x.to(device)
        y = get_model_prediction(datapoint) * 100
        generated_list.append({"atom_count": total_atoms, "is_valid": validity, "ase_atom": ase_atoms, "mol": mol, "formula": formula, "energy":energy, "bio":y})
    except Exception as e:
        num_errors += 1
        print("ERROR!!!!!!")
        # print(e)
print(num_errors)
# Out:
# [03:10:40] Explicit valence for atom # 0 Cl, 2, is greater than permitted
# Molecule: Atoms(symbols='C3H26Br3ClF3I4N2OP4S2Si4', pbc=False)
# [03:10:41] Explicit valence for atom # 5 Cl, 3, is greater than permitted
# Molecule: Atoms(symbols='C5H24Br3Cl3FI4NP3SSi4', pbc=False)
# [03:10:43] Explicit valence for atom # 1 F, 2, is greater than permitted
# Molecule: Atoms(symbols='C5H13BrClF2O2S', pbc=False)
# [03:10:43] Explicit valence for atom # 2 Si, 7, is greater than permitted
# Molecule: Atoms(symbols='C6H22Br2Cl3FI3N2O5P3S4Si4', pbc=False)
# Molecule: Atoms(symbols='C2H11FI2NPS', pbc=False)
# Molecule: Atoms(symbols='H10Br4F2N2OPSSi2', pbc=False)
# [03:10:45] non-ring atom 0 marked aromatic
# [03:10:45] non-ring atom 3 marked aromatic
# Molecule: Atoms(symbols='CH11Br2Cl2F3I3N2OSSi2', pbc=False)
# [03:10:45] Explicit valence for atom # 2 Cl, 2, is greater than permitted
# Molecule: Atoms(symbols='CH11Cl2IOP2SSi2', pbc=False)
# Molecule: Atoms(symbols='C5H15BrFN', pbc=False)
# Molecule: Atoms(symbols='C4H16Br4Cl4F4I6N4O4PSSi3', pbc=False)
# [03:10:46] Explicit valence for atom # 7 Br, 2, is greater than permitted
# [03:10:48] Explicit valence for atom # 2 Cl, 4, is greater than permitted
# Molecule: Atoms(symbols='C4H24Br6Cl7F3I3O4P9S4Si6', pbc=False)
# [03:10:51] non-ring atom 1 marked aromatic
# [03:10:51] Explicit valence for atom # 4 Br, 3, is greater than permitted
# Molecule: Atoms(symbols='CH3BrF2NOS', pbc=False)
# Molecule: Atoms(symbols='C5H13Br2ClF2NP2', pbc=False)
# [03:10:52] Explicit valence for atom # 1 Br, 3, is greater than permitted
# [03:10:52] Explicit valence for atom # 1 Br, 6, is greater than permitted
# Molecule: Atoms(symbols='CH10Br2F3N3O2S', pbc=False)
# Molecule: Atoms(symbols='C4H14Br7Cl3FI6N5O6P4S4Si9', pbc=False)
# [03:10:55] Explicit valence for atom # 1 Br, 2, is greater than permitted
# Molecule: Atoms(symbols='C6H20Br4Cl4F4I4N4O4PS3Si8', pbc=False)
# [03:10:58] Explicit valence for atom # 1 F, 2, is greater than permitted
# Molecule: Atoms(symbols='H16Br4Cl2F3IN4O3P4SSi3', pbc=False)
# [03:10:58] Explicit valence for atom # 11 O, 5, is greater than permitted
# Molecule: Atoms(symbols='C4H14Cl3FI3NO5P7Si3', pbc=False)
# [03:10:59] Explicit valence for atom # 1 Br, 2, is greater than permitted
# [03:10:59] Explicit valence for atom # 2 Cl, 2, is greater than permitted
# Molecule: Atoms(symbols='HBr2FNOPS', pbc=False)
# Molecule: Atoms(symbols='CH12Br2Cl2F6IN2O2P2Si2', pbc=False)
# [03:11:00] Explicit valence for atom # 3 O, 5, is greater than permitted
# [03:11:00] Explicit valence for atom # 6 F, 2, is greater than permitted
# Molecule: Atoms(symbols='CH15BrCl3FN2O2PSSi3', pbc=False)
# Molecule: Atoms(symbols='C4H19Br3Cl4F4I3NOP2S7Si', pbc=False)
# [03:11:01] Explicit valence for atom # 9 Br, 2, is greater than permitted
# Molecule: Atoms(symbols='CH6Br4Cl2F6IO3P3S2Si2', pbc=False)
# [03:11:01] Explicit valence for atom # 8 Br, 2, is greater than permitted
# Molecule: Atoms(symbols='C2H9Br5Cl2IN2OPSSi', pbc=False)
# [03:11:02] non-ring atom 1 marked aromatic
# [03:11:02] Explicit valence for atom # 0 Cl, 2, is greater than permitted
# Molecule: Atoms(symbols='CH7Cl2FIPS2Si2', pbc=False)
# Molecule: Atoms(symbols='CH12Cl2FINO2P2S3Si2', pbc=False)
# [03:11:02] non-ring atom 1 marked aromatic
# Molecule: Atoms(symbols='C2H17BrN3PSSi3', pbc=False)
# [03:11:02] non-ring atom 1 marked aromatic
# Molecule: Atoms(symbols='C2H14BrClFIN2OPSSi2', pbc=False)
# [03:11:03] Explicit valence for atom # 0 Cl, 4, is greater than permitted
# Molecule: Atoms(symbols='C2H18Br2Cl3F3IN3O4P5SSi4', pbc=False)
# [03:11:03] Explicit valence for atom # 2 Br, 2, is greater than permitted
# [03:11:03] non-ring atom 1 marked aromatic
# Molecule: Atoms(symbols='H2BrFPS', pbc=False)
# Molecule: Atoms(symbols='C2H12BrFIN2OPSi', pbc=False)
# Molecule: Atoms(symbols='C2H7N', pbc=False)
# Molecule: Atoms(symbols='C4H11Br10Cl4F6I6N6O2P2S2Si2', pbc=False)
# [03:11:04] Explicit valence for atom # 4 Br, 5, is greater than permitted
# [03:11:05] Explicit valence for atom # 14 Cl, 2, is greater than permitted
# Molecule: Atoms(symbols='C3H12Cl2FOP2S3Si3', pbc=False)
# [03:11:05] Explicit valence for atom # 7 F, 4, is greater than permitted
# Molecule: Atoms(symbols='C4H17F3INPSi', pbc=False)
# [03:11:06] non-ring atom 3 marked aromatic
# [03:11:06] Explicit valence for atom # 2 Br, 5, is greater than permitted
# Molecule: Atoms(symbols='C2H11BrINSSi', pbc=False)
# Molecule: Atoms(symbols='C4H19BrClF3I2N2O4P2S2Si3', pbc=False)
# [03:11:07] Explicit valence for atom # 1 F, 2, is greater than permitted
# [03:11:07] non-ring atom 1 marked aromatic
# Molecule: Atoms(symbols='C2H9ClFN2O3', pbc=False)
# Molecule: Atoms(symbols='C3H7Cl2IN2', pbc=False)
# [03:11:07] non-ring atom 3 marked aromatic
# Molecule: Atoms(symbols='C2H12ClO3PSSi', pbc=False)
# [03:11:07] Explicit valence for atom # 5 Br, 2, is greater than permitted
# Molecule: Atoms(symbols='C2H12BrF2I2NOSSi', pbc=False)
# [03:11:08] non-ring atom 4 marked aromatic
# [03:11:08] non-ring atom 3 marked aromatic
# Molecule: Atoms(symbols='C4H14ClNO2P2S', pbc=False)
# Molecule: Atoms(symbols='CH4Cl2I2NO', pbc=False)
# [03:11:08] non-ring atom 2 marked aromatic
# Molecule: Atoms(symbols='C2H13IN4O3Si', pbc=False)
# [03:11:08] non-ring atom 3 marked aromatic
# [03:11:09] non-ring atom 1 marked aromatic
# Molecule: Atoms(symbols='CH10ClFNO2Si2', pbc=False)
# Molecule: Atoms(symbols='C4H19Cl2FNP3S', pbc=False)
# [03:11:09] Explicit valence for atom # 14 Br, 3, is greater than permitted
# Molecule: Atoms(symbols='CH13Br3FI4N4PS4Si', pbc=False)
# [03:11:09] Explicit valence for atom # 2 F, 4, is greater than permitted
# Molecule: Atoms(symbols='CH14F2N3OSSi3', pbc=False)
# [03:11:10] Explicit valence for atom # 1 Cl, 2, is greater than permitted
# [03:11:10] Explicit valence for atom # 1 F, 2, is greater than permitted
# Molecule: Atoms(symbols='C2H7Br2Cl2S4Si', pbc=False)
# Molecule: Atoms(symbols='CH8BrCl3F2P2S2', pbc=False)
# [03:11:10] non-ring atom 1 marked aromatic
# Molecule: Atoms(symbols='CH9Br2ClI3OSi3', pbc=False)
# [03:11:10] Explicit valence for atom # 1 F, 2, is greater than permitted
# Molecule: Atoms(symbols='C3H14BrF2IN2O3P3S2Si', pbc=False)
# [03:11:11] Explicit valence for atom # 1 Br, 2, is greater than permitted
# [03:11:11] non-ring atom 1 marked aromatic
# Molecule: Atoms(symbols='C2H7Br2Cl2F4PS3', pbc=False)
# Molecule: Atoms(symbols='C2H10Br3Cl4NO2S2Si', pbc=False)
# [03:11:11] Explicit valence for atom # 5 Cl, 4, is greater than permitted
# Molecule: Atoms(symbols='C3H19Br3Cl4F3I2O2P2S3Si4', pbc=False)
# Molecule: Atoms(symbols='CH3O3S2', pbc=False)
# Molecule: Atoms(symbols='CH8BrCl3F2I4N3O3P2Si', pbc=False)
# [03:11:12] Explicit valence for atom # 1 I, 6, is greater than permitted
# [03:11:12] Explicit valence for atom # 5 F, 4, is greater than permitted
# Molecule: Atoms(symbols='CH5Br2FI3N2PSSi', pbc=False)
# [03:11:13] Explicit valence for atom # 3 Br, 4, is greater than permitted
# Molecule: Atoms(symbols='C3H16Br3Cl3F2I3O3P3S2Si3', pbc=False)
# [03:11:15] Explicit valence for atom # 6 Br, 3, is greater than permitted
# Molecule: Atoms(symbols='H7Br2IN2OPSi', pbc=False)
# [03:11:15] non-ring atom 1 marked aromatic
# Molecule: Atoms(symbols='H6Br3F2INOP5', pbc=False)
# [03:11:15] Explicit valence for atom # 1 Cl, 2, is greater than permitted
# [03:11:15] Explicit valence for atom # 2 Br, 3, is greater than permitted
# Molecule: Atoms(symbols='CH4BrCl2FINO2PS3', pbc=False)
# Molecule: Atoms(symbols='C2H4Br2F3O3PS2', pbc=False)
# [03:11:15] Explicit valence for atom # 2 Cl, 4, is greater than permitted
# Molecule: Atoms(symbols='C4H20Br3Cl2F4I2N2OP2SSi2', pbc=False)
# [03:11:16] Explicit valence for atom # 1 Cl, 2, is greater than permitted
# Molecule: Atoms(symbols='H19Br4Cl5F2IN2O3P2S4Si4', pbc=False)
# [03:11:17] Explicit valence for atom # 8 O, 3, is greater than permitted
# Molecule: Atoms(symbols='CH11Br2Cl3IN2O3P2SSi', pbc=False)
# [03:11:17] non-ring atom 4 marked aromatic
# Molecule: Atoms(symbols='C4H14FINO2P', pbc=False)
# [03:11:18] Explicit valence for atom # 2 F, 2, is greater than permitted
# [03:11:18] Explicit valence for atom # 1 Cl, 2, is greater than permitted
# Molecule: Atoms(symbols='C2H9F2N2S2', pbc=False)
# Molecule: Atoms(symbols='C2H11Cl3NO2PS2', pbc=False)
# [03:11:18] non-ring atom 4 marked aromatic
# Molecule: Atoms(symbols='CH11BrClFI3NP4SSi3', pbc=False)
# [03:11:18] non-ring atom 1 marked aromatic
# [03:11:18] Explicit valence for atom # 11 Br, 3, is greater than permitted
# Molecule: Atoms(symbols='CH9INOPS2Si', pbc=False)
# Molecule: Atoms(symbols='CH13BrClF4I2N2O4P3SSi', pbc=False)
# [03:11:19] Explicit valence for atom # 0 O, 3, is greater than permitted
# Molecule: Atoms(symbols='C8H9Br2Cl8F2I11N5O7P5S4Si4', pbc=False)
# [03:11:22] non-ring atom 4 marked aromatic
# [03:11:22] Explicit valence for atom # 1 Cl, 2, is greater than permitted
# Molecule: Atoms(symbols='CH11ClFIPSSi2', pbc=False)
# Molecule: Atoms(symbols='CH8Cl3FISSi', pbc=False)
# [03:11:22] Explicit valence for atom # 1 Cl, 2, is greater than permitted
# Molecule: Atoms(symbols='C5H23ClINO2PSSi', pbc=False)
# [03:11:22] Explicit valence for atom # 5 Cl, 2, is greater than permitted
# [03:11:22] Explicit valence for atom # 14 Br, 3, is greater than permitted
# Molecule: Atoms(symbols='H3Cl7I2OP2', pbc=False)
# Molecule: Atoms(symbols='CH10Br3Cl2F2I2NO2Si2', pbc=False)
# [03:11:23] non-ring atom 4 marked aromatic
# [03:11:23] Explicit valence for atom # 1 Br, 2, is greater than permitted
# Molecule: Atoms(symbols='C3H9Cl2OSi', pbc=False)
# Molecule: Atoms(symbols='CH7Br4FI2O2PS', pbc=False)
# [03:11:23] Explicit valence for atom # 2 Cl, 2, is greater than permitted
# Molecule: Atoms(symbols='C3H20Cl3INO3PSi2', pbc=False)
# [03:11:23] Explicit valence for atom # 1 N, 8, is greater than permitted
# Molecule: Atoms(symbols='C3H20BrClF4I5N4O5P4Si2', pbc=False)
# [03:11:24] Explicit valence for atom # 7 F, 2, is greater than permitted
# Molecule: Atoms(symbols='H7Br2Cl4FOPSSi2', pbc=False)
# [03:11:25] Explicit valence for atom # 1 Br, 2, is greater than permitted
# Molecule: Atoms(symbols='H5BrN4O2Si', pbc=False)
# Molecule: Atoms(symbols='C2H9ClNO2PS', pbc=False)
# [03:11:25] Explicit valence for atom # 10 F, 2, is greater than permitted
# Molecule: Atoms(symbols='C5H13Br2FN2O3PSi', pbc=False)
# Molecule: Atoms(symbols='C3H10INO', pbc=False)
# Molecule: Atoms(symbols='CH5NS2', pbc=False)
# [03:11:26] non-ring atom 3 marked aromatic
# [03:11:26] Explicit valence for atom # 1 F, 2, is greater than permitted
# Molecule: Atoms(symbols='CH11P3SSi2', pbc=False)
# Molecule: Atoms(symbols='C2H10BrClF2I2N2OSi', pbc=False)
# [03:11:26] Explicit valence for atom # 1 F, 3, is greater than permitted
# Molecule: Atoms(symbols='CH12BrF2NPSi3', pbc=False)
# [03:11:27] non-ring atom 0 marked aromatic
# [03:11:27] Explicit valence for atom # 0 Cl, 4, is greater than permitted
# Molecule: Atoms(symbols='C2H9Br3Cl3IOPS', pbc=False)
# Molecule: Atoms(symbols='H15BrCl2F2I2NO2SSi4', pbc=False)
# [03:11:27] Explicit valence for atom # 4 F, 2, is greater than permitted
# [03:11:27] non-ring atom 0 marked aromatic
# Molecule: Atoms(symbols='CH9ClFIN2OSi', pbc=False)
# Molecule: Atoms(symbols='CH5ClOSi', pbc=False)
# [03:11:27] Explicit valence for atom # 8 O, 3, is greater than permitted
# Molecule: Atoms(symbols='C2H10BrClF6INO3PS3', pbc=False)
# [03:11:27] Explicit valence for atom # 1 Br, 2, is greater than permitted
# Molecule: Atoms(symbols='CH12Br2ClFI2N2O2PSSi2', pbc=False)
# [03:11:28] Explicit valence for atom # 2 O, 3, is greater than permitted
# Molecule: Atoms(symbols='C2H23Br2Cl2F2I3N5OP3SSi2', pbc=False)
# Molecule: Atoms(symbols='C2H10BrClIOP4S3', pbc=False)
# Molecule: Atoms(symbols='H4BrCl2F2INOPSSi', pbc=False)
# 0
# [03:11:29] non-ring atom 3 marked aromatic
# [03:11:29] Explicit valence for atom # 1 Br, 2, is greater than permitted

# %%
print(len(generated_list))
# Out:
# 100

# %%
print(generated_list[0]["ase_atom"])
# Out:
# Atoms(symbols='C3H26Br3ClF3I4N2OP4S2Si4', pbc=False)

# %%
unique_formulas = set()
count_formulas = {}
count_valid = 0
total_atom_count = 0
for item in generated_list:
    if 'formula' in item:
        if item['formula'] not in count_formulas:
            count_formulas[item['formula']] = 1
        else:
            count_formulas[item['formula']] += 1
        unique_formulas.add(item['formula'])
    if 'is_valid' in item:
        if item['is_valid'] == True:
            count_valid += 1
    if 'atom_count' in item:
        total_atom_count += item['atom_count']

# %%
print(unique_formulas)
print("Average Number of atoms: ", total_atom_count / 100)
print("Number of Unique Formulas: ", len(unique_formulas))
print("Number of Valid Formulas: ", count_valid)
# Out:
# {'C2H23Br2Cl2F2I3N5OP3SSi2', 'C6H20Br4Cl4F4I4N4O4PS3Si8', 'C2H14BrClFIN2OPSSi2', 'CH3O3S2', 'C2H9Br5Cl2IN2OPSSi', 'C2H7Br2Cl2F4PS3', 'CH13Br3FI4N4PS4Si', 'H3Cl7I2OP2', 'C3H20BrClF4I5N4O5P4Si2', 'C8H9Br2Cl8F2I11N5O7P5S4Si4', 'CH15BrCl3FN2O2PSSi3', 'C2H9ClNO2PS', 'CH11BrClFI3NP4SSi3', 'C5H13BrClF2O2S', 'C3H10INO', 'C4H19Cl2FNP3S', 'CH6Br4Cl2F6IO3P3S2Si2', 'C4H14Br7Cl3FI6N5O6P4S4Si9', 'C2H12BrFIN2OPSi', 'C2H7Br2Cl2S4Si', 'C2H4Br2F3O3PS2', 'C2H9F2N2S2', 'CH8BrCl3F2I4N3O3P2Si', 'C4H14ClNO2P2S', 'CH11ClFIPSSi2', 'C2H9Br3Cl3IOPS', 'C5H24Br3Cl3FI4NP3SSi4', 'C6H22Br2Cl3FI3N2O5P3S4Si4', 'CH4BrCl2FINO2PS3', 'C2H7N', 'C4H16Br4Cl4F4I6N4O4PSSi3', 'C2H9ClFN2O3', 'CH11Br2Cl2F3I3N2OSSi2', 'C2H11BrINSSi', 'CH13BrClF4I2N2O4P3SSi', 'CH8BrCl3F2P2S2', 'C2H17BrN3PSSi3', 'H10Br4F2N2OPSSi2', 'C2H10BrClF6INO3PS3', 'CH9Br2ClI3OSi3', 'CH10Br3Cl2F2I2NO2Si2', 'C3H12Cl2FOP2S3Si3', 'H7Br2IN2OPSi', 'CH12Br2ClFI2N2O2PSSi2', 'CH7Br4FI2O2PS', 'C2H10BrClIOP4S3', 'CH9INOPS2Si', 'C5H23ClINO2PSSi', 'CH11Br2Cl3IN2O3P2SSi', 'CH10ClFNO2Si2', 'C3H19Br3Cl4F3I2O2P2S3Si4', 'H19Br4Cl5F2IN2O3P2S4Si4', 'C4H19BrClF3I2N2O4P2S2Si3', 'C3H16Br3Cl3F2I3O3P3S2Si3', 'CH11Cl2IOP2SSi2', 'C4H24Br6Cl7F3I3O4P9S4Si6', 'CH4Cl2I2NO', 'C4H20Br3Cl2F4I2N2OP2SSi2', 'C3H14BrF2IN2O3P3S2Si', 'C4H19Br3Cl4F4I3NOP2S7Si', 'C4H14Cl3FI3NO5P7Si3', 'H5BrN4O2Si', 'H4BrCl2F2INOPSSi', 'CH7Cl2FIPS2Si2', 'C2H11FI2NPS', 'C2H12ClO3PSSi', 'CH3BrF2NOS', 'C4H14FINO2P', 'C2H11Cl3NO2PS2', 'C3H7Cl2IN2', 'CH10Br2F3N3O2S', 'C3H26Br3ClF3I4N2OP4S2Si4', 'C2H13IN4O3Si', 'CH12BrF2NPSi3', 'C2H10Br3Cl4NO2S2Si', 'CH12Br2Cl2F6IN2O2P2Si2', 'C4H17F3INPSi', 'H2BrFPS', 'C5H13Br2ClF2NP2', 'C2H12BrF2I2NOSSi', 'C5H15BrFN', 'H16Br4Cl2F3IN4O3P4SSi3', 'H6Br3F2INOP5', 'H7Br2Cl4FOPSSi2', 'CH9ClFIN2OSi', 'C2H10BrClF2I2N2OSi', 'CH12Cl2FINO2P2S3Si2', 'C2H18Br2Cl3F3IN3O4P5SSi4', 'CH5ClOSi', 'CH5NS2', 'C4H11Br10Cl4F6I6N6O2P2S2Si2', 'C3H20Cl3INO3PSi2', 'CH11P3SSi2', 'CH5Br2FI3N2PSSi', 'H15BrCl2F2I2NO2SSi4', 'C3H9Cl2OSi', 'HBr2FNOPS', 'C5H13Br2FN2O3PSi', 'CH14F2N3OSSi3', 'CH8Cl3FISSi'}
# Average Number of atoms:  27.26
# Number of Unique Formulas:  100
# Number of Valid Formulas:  7

# %%
print(count_formulas)
# Out:
# {'C3H26Br3ClF3I4N2OP4S2Si4': 1, 'C5H24Br3Cl3FI4NP3SSi4': 1, 'C5H13BrClF2O2S': 1, 'C6H22Br2Cl3FI3N2O5P3S4Si4': 1, 'C2H11FI2NPS': 1, 'H10Br4F2N2OPSSi2': 1, 'CH11Br2Cl2F3I3N2OSSi2': 1, 'CH11Cl2IOP2SSi2': 1, 'C5H15BrFN': 1, 'C4H16Br4Cl4F4I6N4O4PSSi3': 1, 'C4H24Br6Cl7F3I3O4P9S4Si6': 1, 'CH3BrF2NOS': 1, 'C5H13Br2ClF2NP2': 1, 'CH10Br2F3N3O2S': 1, 'C4H14Br7Cl3FI6N5O6P4S4Si9': 1, 'C6H20Br4Cl4F4I4N4O4PS3Si8': 1, 'H16Br4Cl2F3IN4O3P4SSi3': 1, 'C4H14Cl3FI3NO5P7Si3': 1, 'HBr2FNOPS': 1, 'CH12Br2Cl2F6IN2O2P2Si2': 1, 'CH15BrCl3FN2O2PSSi3': 1, 'C4H19Br3Cl4F4I3NOP2S7Si': 1, 'CH6Br4Cl2F6IO3P3S2Si2': 1, 'C2H9Br5Cl2IN2OPSSi': 1, 'CH7Cl2FIPS2Si2': 1, 'CH12Cl2FINO2P2S3Si2': 1, 'C2H17BrN3PSSi3': 1, 'C2H14BrClFIN2OPSSi2': 1, 'C2H18Br2Cl3F3IN3O4P5SSi4': 1, 'H2BrFPS': 1, 'C2H12BrFIN2OPSi': 1, 'C2H7N': 1, 'C4H11Br10Cl4F6I6N6O2P2S2Si2': 1, 'C3H12Cl2FOP2S3Si3': 1, 'C4H17F3INPSi': 1, 'C2H11BrINSSi': 1, 'C4H19BrClF3I2N2O4P2S2Si3': 1, 'C2H9ClFN2O3': 1, 'C3H7Cl2IN2': 1, 'C2H12ClO3PSSi': 1, 'C2H12BrF2I2NOSSi': 1, 'C4H14ClNO2P2S': 1, 'CH4Cl2I2NO': 1, 'C2H13IN4O3Si': 1, 'CH10ClFNO2Si2': 1, 'C4H19Cl2FNP3S': 1, 'CH13Br3FI4N4PS4Si': 1, 'CH14F2N3OSSi3': 1, 'C2H7Br2Cl2S4Si': 1, 'CH8BrCl3F2P2S2': 1, 'CH9Br2ClI3OSi3': 1, 'C3H14BrF2IN2O3P3S2Si': 1, 'C2H7Br2Cl2F4PS3': 1, 'C2H10Br3Cl4NO2S2Si': 1, 'C3H19Br3Cl4F3I2O2P2S3Si4': 1, 'CH3O3S2': 1, 'CH8BrCl3F2I4N3O3P2Si': 1, 'CH5Br2FI3N2PSSi': 1, 'C3H16Br3Cl3F2I3O3P3S2Si3': 1, 'H7Br2IN2OPSi': 1, 'H6Br3F2INOP5': 1, 'CH4BrCl2FINO2PS3': 1, 'C2H4Br2F3O3PS2': 1, 'C4H20Br3Cl2F4I2N2OP2SSi2': 1, 'H19Br4Cl5F2IN2O3P2S4Si4': 1, 'CH11Br2Cl3IN2O3P2SSi': 1, 'C4H14FINO2P': 1, 'C2H9F2N2S2': 1, 'C2H11Cl3NO2PS2': 1, 'CH11BrClFI3NP4SSi3': 1, 'CH9INOPS2Si': 1, 'CH13BrClF4I2N2O4P3SSi': 1, 'C8H9Br2Cl8F2I11N5O7P5S4Si4': 1, 'CH11ClFIPSSi2': 1, 'CH8Cl3FISSi': 1, 'C5H23ClINO2PSSi': 1, 'H3Cl7I2OP2': 1, 'CH10Br3Cl2F2I2NO2Si2': 1, 'C3H9Cl2OSi': 1, 'CH7Br4FI2O2PS': 1, 'C3H20Cl3INO3PSi2': 1, 'C3H20BrClF4I5N4O5P4Si2': 1, 'H7Br2Cl4FOPSSi2': 1, 'H5BrN4O2Si': 1, 'C2H9ClNO2PS': 1, 'C5H13Br2FN2O3PSi': 1, 'C3H10INO': 1, 'CH5NS2': 1, 'CH11P3SSi2': 1, 'C2H10BrClF2I2N2OSi': 1, 'CH12BrF2NPSi3': 1, 'C2H9Br3Cl3IOPS': 1, 'H15BrCl2F2I2NO2SSi4': 1, 'CH9ClFIN2OSi': 1, 'CH5ClOSi': 1, 'C2H10BrClF6INO3PS3': 1, 'CH12Br2ClFI2N2O2PSSi2': 1, 'C2H23Br2Cl2F2I3N5OP3SSi2': 1, 'C2H10BrClIOP4S3': 1, 'H4BrCl2F2INOPSSi': 1}

# %% [markdown]
# ### Novelty

# %%
with open("data/og_formulas.pkl", "rb") as file:
    og_formulas = pickle.load(file)

# %%
print(og_formulas)
print(len(og_formulas))
# Out:
# ['C4H10O2S2', 'C17H11BrClFN2O4', 'C7H7Br', 'C7H16BrN', 'C2HBrCl2O2', 'C4H6Br2', 'CBrCl3', 'C6H5F2N', 'C11H20O', 'C6BrF5', 'C10H24N2O4', 'C6H4ClNO2', 'C6H14O3', 'C10H22O5', 'C2H3BrO2', 'C8H18BrN', 'C7H5ClO2', 'C6H3Br3', 'C10H22OS', 'C7H6Br2', 'C14H15N5O6S', 'C10H16Cl3NOS', 'C3H5BrO', 'C2H4Br2', 'C8H14O', 'C6H6N2O', 'C22H25ClN2O9', 'C15H17N5O6S', 'C12H12', 'C6H12S', 'C8H14N4O7', 'C4H5NS', 'C4H10S', 'C3H12NO9P3', 'C6H4BrF', 'C22H24N2O8', 'C4H8BrCl', 'C11H10', 'C6H8N2S', 'C13H27Br', 'C10H12N6', 'C13H21N3O6S2', 'C14H29Br', 'C2H3FO2', 'C2H4N4O2', 'C14H16N2O4S', 'C11H24O6Si', 'C10H20O', 'C7H3Cl2FO', 'C3H5Br2Cl', 'C12H22F6N2O4S2', 'C9H17IN2', 'C8H12N4', 'C27H50O6', 'C2H5NO2', 'C9H6F3N', 'C7H6F3N', 'C11H16N8O8', 'H4N2O3', 'C2H5NO3', 'C4H10O3', 'C7H7ClS', 'C8H15IN2', 'C11H10FNO2S', 'C8H8O3', 'C12H16O7', 'C21H40O5', 'C13H22N4O3S', 'C9H10ClN5O2', 'C4H9NO4', 'C28H46O4', 'C8H5N3O4', 'C14H16ClN5O5S', 'C25H48O4', 'C16H10F3NO', 'C12H13ClF3N3O4', 'C12H8N2O5', 'C13H18N2O4', 'C10H22BrN', 'C6H11ClN2', 'C8H11N3O4', 'C5H6N2O2S', 'C13H16O3', 'C17H25N7O', 'C8H10N2', 'CHF3O3S', 'C37H61BrN2O4', 'C8H12N2O2', 'C5H13NO2', 'C9H10N4O2S2', 'C17H12Cl2N6O4', 'C22H28INO2', 'C5H4ClNO', 'C8H10O2', 'C15H27N3O', 'C10H22IN', 'C3H9O3P', 'C9H17ClN2', 'C3H3NO2', 'C6H12O2', 'C7H14O3', 'C2H3F3O', 'C21H23ClFNO5', 'C6H10', 'C22H42O4', 'C27H46O2', 'C8H17NO3', 'C15H16F5NO2S2', 'C10H14', 'C7H9NO3S', 'C5H7N3O2', 'C5H13N', 'C12H18N2O3S', 'C12H21N2O4P', 'C14H22O8', 'C14H22N2O3', 'C8H19NO', 'C12H19N3O', 'C10H11NO3', 'C9H10', 'C10H12O', 'C13H26O4', 'C7H3ClF3NO2', 'C8H7NO3', 'C7H5NO4', 'C9H19NO4', 'C8H14O3', 'C5H11NOS', 'C10H24N2', 'C34H58O4', 'C7H4F3NO2', 'C9H20S', 'C12H18', 'C5H10O', 'C3H6O', 'C4H6N2O', 'C19H36O2', 'C6H10N2O3', 'C15H21NO4', 'C7H5Cl2NO', 'C11H7NO4', 'C2H5NS', 'C5H8O4', 'C10H21NO', 'C5H12O3', 'C11H20O4', 'C8H10F3NO3S', 'C5H7N', 'C13H16O2', 'C4H8Cl2', 'C6H16N2', 'C9H16O', 'C7H14N2O', 'C4H10O4S', 'C10H6O8', 'C12H18O3', 'C13H19NO9', 'C10H15NO2', 'C13H24O4', 'C10H15F6N3O4S2', 'C12H10O3', 'C14H8Br2O2', 'C4H8O3', 'C17H21IO2', 'C11H15NO2S', 'C22H42O6', 'C14H17N3O3', 'C18H18O5', 'C11H22O2', 'C14H22O6', 'C6H14', 'C14H19ClO', 'C14H30O', 'C10H15N', 'C22H42O2', 'C9H20N2', 'C7H9NO2S', 'C7H10O2', 'C2H3NS', 'C2H3NO', 'C3H4Cl2', 'C12H12N2O2S', 'C5H8O', 'C4H6O2', 'CH2O', 'C16H13ClN2O2', 'C38H72N2O12', 'C22H20O13', 'C8H16O', 'C5H7ClO2', 'C26H47O3P', 'C8H18F6NP', 'C9H18N3OP', 'C9H16N4OS', 'C9H16F6N2O4S2', 'C5H11NO2', 'C5H9NO3S', 'C11H14N2O', 'C15H30N2', 'CH4N2O', 'C10H20O2S', 'C10H18F6N2O4S2', 'C7H14N2O4S', 'C4H12O3Si', 'C32H60O10', 'C9H13N3O3', 'C19H24N4O3', 'C2H7NO2S', 'C2H6OSi', 'C9H13F6N3O4S2', 'C8H24O2Si3', 'C7H22O2Si3', 'C6H7N', 'C12H2Br8O', 'C14H17BrN2O2', 'C12H10', 'C9H16N2', 'C6H14O6', 'C10H12O2', 'C16H14O3', 'C6H12O6', 'C4H8N2O2', 'C7H9N', 'C7H10O4S', 'C2H8N2O', 'C4H12N2O', 'C23H22ClF3O2', 'C7H16O', 'C12H22O11', 'C17H28N4O7S', 'C5H12O5', 'C14H28O2', 'C6H10O4', 'C6H18N4', 'C9H7N', 'C3H4N2', 'C4H4N2', 'C6H12N2', 'C6H6', 'C8H10N2O3S', 'C8H6O', 'C9H11N', 'C3H6O2', 'C10H14S', 'C10H12', 'C24H34N8O4S2', 'C6H7NO3S', 'C4H6O3', 'C3H4N2S', 'C12H14', 'C7H10O3', 'C2H3N3', 'C6H12N4', 'C16H33NO2', 'C4H8S2', 'C2H8O7P2', 'C13H30O6P2', 'C6H12Br2', 'C8H14ClN5', 'C17H26O', 'C11H18O3Si', 'C18H28O2', 'C9H13ClN6', 'C6H10O', 'C8H16', 'C7H12ClN5', 'C9H4Cl6O4', 'C21H25NO2', 'C14H21NO4', 'C7H14N2O3S', 'C24H45NO6S', 'C6H15Cl2NO', 'C8H13NO3S', 'C12H17N5O4S', 'C6H11NO2', 'C10H8N2', 'C12H24', 'C4H7ClO2', 'C8H12', 'C8H19O3PS2', 'C20H26', 'C18H35NO2', 'C8H20O5P2S2', 'C6H15O3P', 'C12H20ClN3O', 'C6H4Cl2', 'C31H52O3', 'C6H3Cl3', 'C12H8', 'C4H4O', 'C12H22', 'C7H6Cl2', 'C12H8O2', 'C10H8O2', 'C11H14N2', 'C10H10O3', 'C17H17N3O3', 'C4H6O', 'C9H8N2', 'C6H9N3O3', 'C13H22O', 'C12H27P', 'C28H52N2O4', 'C12H11NO3', 'C3H8N2O', 'C8H10ClN5O3S', 'C6H14N2O', 'C17H16O4', 'C10H18O3', 'C15H20ClN3O', 'C26H48O4', 'C15H10ClF3N2O6S', 'C9H21O2PS3', 'C16H34O4', 'C8H18O2', 'C17H34O2', 'C4H10O', 'C14H32N2O4', 'C14H6Cl2F4N2O2', 'C4H11N', 'C18H38N4O15S', 'C3H8S', 'C3H5ClO2', 'C8H18O3Si', 'C8H20O3Si', 'C23H31ClN2O', 'C10H11ClN4', 'C8H20ClN ...
# 3208

# %%
og_formulas = set(og_formulas)
print(og_formulas & unique_formulas)
print(len(og_formulas & unique_formulas))
print("Number of Novel Molecules: ", 100 - len(og_formulas & unique_formulas))
# Out:
# {'C2H7N'}
# 1
# Number of Novel Molecules:  99

# %%
df = pd.DataFrame(list(count_formulas.items()), columns=['Formula', 'Count'])
sorted_df = df.sort_values(by='Count', ascending=False)
sorted_df.head(31)
# Out:
#                        Formula  Count
# 0     C3H26Br3ClF3I4N2OP4S2Si4      1
# 63    C4H20Br3Cl2F4I2N2OP2SSi2      1
# 73               CH11ClFIPSSi2      1
# 72  C8H9Br2Cl8F2I11N5O7P5S4Si4      1
# 71       CH13BrClF4I2N2O4P3SSi      1
# 70                 CH9INOPS2Si      1
# 69          CH11BrClFI3NP4SSi3      1
# 68              C2H11Cl3NO2PS2      1
# 67                  C2H9F2N2S2      1
# 66                 C4H14FINO2P      1
# 65        CH11Br2Cl3IN2O3P2SSi      1
# 64     H19Br4Cl5F2IN2O3P2S4Si4      1
# 62              C2H4Br2F3O3PS2      1
# 1        C5H24Br3Cl3FI4NP3SSi4      1
# 61            CH4BrCl2FINO2PS3      1
# 60                H6Br3F2INOP5      1
# 59                H7Br2IN2OPSi      1
# 58    C3H16Br3Cl3F2I3O3P3S2Si3      1
# 57             CH5Br2FI3N2PSSi      1
# 56        CH8BrCl3F2I4N3O3P2Si      1
# 55                     CH3O3S2      1
# 54    C3H19Br3Cl4F3I2O2P2S3Si4      1
# 53          C2H10Br3Cl4NO2S2Si      1
# 52             C2H7Br2Cl2F4PS3      1
# 74                 CH8Cl3FISSi      1
# 75             C5H23ClINO2PSSi      1
# 76                  H3Cl7I2OP2      1
# 77        CH10Br3Cl2F2I2NO2Si2      1
# 98             C2H10BrClIOP4S3      1
# 97    C2H23Br2Cl2F2I3N5OP3SSi2      1
# 96       CH12Br2ClFI2N2O2PSSi2      1

# %%
sorted_df.to_csv("vae_generated_count_test.csv", index=False)

# %%
df = pd.DataFrame(generated_list)
df.head()
# Out:
#    atom_count  is_valid                                           ase_atom
# 0          53     False  (Atom('C', [7.6373429289382235, 1.171886588000...  \
# 1          49     False  (Atom('C', [3.2449626774790596, 8.395825747101...
# 2          25     False  (Atom('C', [8.508334771367347, 7.4598222130328...
# 3          55     False  (Atom('C', [6.982758827710105, 8.6351287242342...
# 4          19      True  (Atom('C', [0.27119684160168633, 4.92827316440...
#
#                                                  mol
# 0  <rdkit.Chem.rdchem.RWMol object at 0x2aabb1258...  \
# 1  <rdkit.Chem.rdchem.RWMol object at 0x2aabb12b1...
# 2  <rdkit.Chem.rdchem.RWMol object at 0x2aabb1332...
# 3  <rdkit.Chem.rdchem.RWMol object at 0x2aabb1330...
# 4  <rdkit.Chem.rdchem.RWMol object at 0x2aabb125a...
#
#                      formula     energy        bio
# 0   C3H26Br3ClF3I4N2OP4S2Si4 -43.218110   0.003690
# 1      C5H24Br3Cl3FI4NP3SSi4 -37.044930   0.007101
# 2             C5H13BrClF2O2S  -7.000159   4.727182
# 3  C6H22Br2Cl3FI3N2O5P3S4Si4 -33.044948   0.000012
# 4                C2H11FI2NPS  -0.000064  21.469204

# %%
print(df.columns)
# Out:
# Index(['atom_count', 'is_valid', 'ase_atom', 'mol', 'formula', 'energy',
#        'bio'],
#       dtype='object')

# %%
bio_formula = df[['formula', 'bio']]
sorted_df = bio_formula.sort_values(by='bio', ascending=False)
sorted_df.head(31)
# Out:
#                formula        bio
# 86            C3H10INO  95.533168
# 31               C2H7N  94.244057
# 94            CH5ClOSi  44.233882
# 38          C3H7Cl2IN2  36.715776
# 39       C2H12ClO3PSSi  29.002002
# 66         C4H14FINO2P  28.884506
# 42          CH4Cl2I2NO  23.361813
# 55             CH3O3S2  21.911630
# 4          C2H11FI2NPS  21.469204
# 8            C5H15BrFN  19.339967
# 87              CH5NS2  16.872466
# 29             H2BrFPS  16.303225
# 93        CH9ClFIN2OSi  15.427363
# 34        C4H17F3INPSi  14.555684
# 73       CH11ClFIPSSi2  13.403118
# 44       CH10ClFNO2Si2  12.326865
# 35        C2H11BrINSSi  10.687231
# 37         C2H9ClFN2O3  10.065373
# 30     C2H12BrFIN2OPSi   8.163001
# 84         C2H9ClNO2PS   7.695104
# 43        C2H13IN4O3Si   7.247755
# 78          C3H9Cl2OSi   6.670915
# 89  C2H10BrClF2I2N2OSi   6.639441
# 75     C5H23ClINO2PSSi   6.063102
# 88          CH11P3SSi2   5.570051
# 80    C3H20Cl3INO3PSi2   5.187748
# 2       C5H13BrClF2O2S   4.727182
# 7      CH11Cl2IOP2SSi2   4.575984
# 74         CH8Cl3FISSi   3.881903
# 11          CH3BrF2NOS   2.904106
# 41       C4H14ClNO2P2S   2.482465

# %%
print(sorted_df['bio'].sum() / 100)
# Out:
# 6.2530310041453765

# %%
df.to_csv('vae_generated_test.csv', index=False)

# %%
sorted_df.to_csv('vae_generated_bio_test.csv', index=False)

# %%
random_mol, random_formula = df[['mol','formula']].sample(n=1).iloc[0]
smiles = Chem.MolToSmiles(random_mol)
print(random_formula)
print(smiles)
Chem.MolFromSmiles(smiles)
# Out:
# C2H7N
# CCN

# %%
error_count = 0
success_count = 0

for index, row in df.iterrows():
    try:
        mol = row['mol']
        smiles = Chem.MolToSmiles(mol)
        new_mol = Chem.MolFromSmiles(smiles)
        if new_mol is not None:
            success_count += 1
        else:
            error_count += 1
    except Exception as e:
        error_count += 1
# Out:
# [03:18:52] SMILES Parse Error: syntax error while parsing: C[SiH3].Cf(i)PS.Cn(O)[siH2].I#I.N#Br.PBr.PClFsi.[SiH2]=[SiH]P.fbr
# [03:18:52] SMILES Parse Error: Failed parsing SMILES 'C[SiH3].Cf(i)PS.Cn(O)[siH2].I#I.N#Br.PBr.PClFsi.[SiH2]=[SiH]P.fbr' for input: 'C[SiH3].Cf(i)PS.Cn(O)[siH2].I#I.N#Br.PBr.PClFsi.[SiH2]=[SiH]P.fbr'
# [03:18:52] SMILES Parse Error: syntax error while parsing: Br#I.CI.C[SiH3].ClCI(Br)Br.F=P#I.N=P.PCl.ccls-c([siH2])[SiH2][SiH3]
# [03:18:52] SMILES Parse Error: Failed parsing SMILES 'Br#I.CI.C[SiH3].ClCI(Br)Br.F=P#I.N=P.PCl.ccls-c([siH2])[SiH2][SiH3]' for input: 'Br#I.CI.C[SiH3].ClCI(Br)Br.F=P#I.N=P.PCl.ccls-c([siH2])[SiH2][SiH3]'
# [03:18:52] Explicit valence for atom # 10 F, 2, is greater than permitted
# [03:18:52] SMILES Parse Error: syntax error while parsing: C=OO[Si]1(#N)=s(=P)(CCl=fc)clBr1.C=S.CBr.CS[IH]S.N=[SiH2].O#[PH]#O.O#[Si]#ipi(#[SiH])#Cl
# [03:18:52] SMILES Parse Error: Failed parsing SMILES 'C=OO[Si]1(#N)=s(=P)(CCl=fc)clBr1.C=S.CBr.CS[IH]S.N=[SiH2].O#[PH]#O.O#[Si]#ipi(#[SiH])#Cl' for input: 'C=OO[Si]1(#N)=s(=P)(CCl=fc)clBr1.C=S.CBr.CS[IH]S.N=[SiH2].O#[PH]#O.O#[Si]#ipi(#[SiH])#Cl'
# [03:18:52] SMILES Parse Error: syntax error while parsing: NF.ONf[siH2].SBr.[SiH3]pbr.brbr
# [03:18:52] SMILES Parse Error: Failed parsing SMILES 'NF.ONf[siH2].SBr.[SiH3]pbr.brbr' for input: 'NF.ONf[siH2].SBr.[SiH3]pbr.brbr'
# [03:18:52] SMILES Parse Error: syntax error while parsing: FBr.FfibrNCCl.NiclI.O[SiH3].[siH2]s
# [03:18:52] SMILES Parse Error: Failed parsing SMILES 'FBr.FfibrNCCl.NiclI.O[SiH3].[siH2]s' for input: 'FBr.FfibrNCCl.NiclI.O[SiH3].[siH2]s'
# [03:18:52] Explicit valence for atom # 7 Cl, 2, is greater than permitted
# [03:18:52] SMILES Parse Error: syntax error while parsing: Br=[SiH]cli.Coi.FF.Fni.Ici.N#clf.N=CCl.N=[SiH2].O#P.O=Br.SBr.[SiH3]Cl.bri.co
# [03:18:52] SMILES Parse Error: Failed parsing SMILES 'Br=[SiH]cli.Coi.FF.Fni.Ici.N#clf.N=CCl.N=[SiH2].O#P.O=Br.SBr.[SiH3]Cl.bri.co' for input: 'Br=[SiH]cli.Coi.FF.Fni.Ici.N#clf.N=CCl.N=[SiH2].O#P.O=Br.SBr.[SiH3]Cl.bri.co'
# [03:18:52] SMILES Parse Error: syntax error while parsing: C=P.CBr.Cl=F=Br.OPClf(br)[si](#P)-cl(f)[IH]S.Sp(=[IH])c1i=o([siH]Br)=Br#C=1.[SiH2]=P#cl(P)cl=Cl.[SiH3][si](P)(Cl#P)o(br)s-[siH]p.os
# [03:18:52] SMILES Parse Error: Failed parsing SMILES 'C=P.CBr.Cl=F=Br.OPClf(br)[si](#P)-cl(f)[IH]S.Sp(=[IH])c1i=o([siH]Br)=Br#C=1.[SiH2]=P#cl(P)cl=Cl.[SiH3][si](P)(Cl#P)o(br)s-[siH]p.os' for input: 'C=P.CBr.Cl=F=Br.OPClf(br)[si](#P)-cl(f)[IH]S.Sp(=[IH])c1i=o([siH]Br)=Br#C=1.[SiH2]=P#cl(P)cl=Cl.[SiH3][si](P)(Cl#P)o(br)s-[siH]p.os'
# [03:18:52] non-ring atom 2 marked aromatic
# [03:18:52] SMILES Parse Error: syntax error while parsing: C=C.CNPcbrcCl.FF.PBr
# [03:18:52] SMILES Parse Error: Failed parsing SMILES 'C=C.CNPcbrcCl.FF.PBr' for input: 'C=C.CNPcbrcCl.FF.PBr'
# [03:18:52] Explicit valence for atom # 3 F, 3, is greater than permitted
# [03:18:52] SMILES Parse Error: syntax error while parsing: C#N(Br)N1#S23#ic=Nc(br)p(br(=oi#[Si]#O)([siH]br(S)=Cl)S1)#[Si]=2n(i)(=[si](i-so)i[si]=P)#p3o(=[Si]=F)Cl#Br.C=P.OI([SiH3])N[Si]1=Br#Cl1.[siH2]o#Br
# [03:18:52] SMILES Parse Error: Failed parsing SMILES 'C#N(Br)N1#S23#ic=Nc(br)p(br(=oi#[Si]#O)([siH]br(S)=Cl)S1)#[Si]=2n(i)(=[si](i-so)i[si]=P)#p3o(=[Si]=F)Cl#Br.C=P.OI([SiH3])N[Si]1=Br#Cl1.[siH2]o#Br' for input: 'C#N(Br)N1#S23#ic=Nc(br)p(br(=oi#[Si]#O)([siH]br(S)=Cl)S1)#[Si]=2n(i)(=[si](i-so)i[si]=P)#p3o(=[Si]=F)Cl#Br.C=P.OI([SiH3])N[Si]1=Br#Cl1.[siH2]o#Br'
# [03:18:52] SMILES Parse Error: syntax error while parsing: C=Br[SiH3].CO.F=N#[SiH].FI.N#Fc1(cl)s2(=Clo[siH]-2)-c2([siH]fBr#s(=P)c#[si]-2(i)BrC=O)=cl1(=S)I.NO.[SiH2]=Cl.ni[si]=[Si]=Br
# [03:18:52] SMILES Parse Error: Failed parsing SMILES 'C=Br[SiH3].CO.F=N#[SiH].FI.N#Fc1(cl)s2(=Clo[siH]-2)-c2([siH]fBr#s(=P)c#[si]-2(i)BrC=O)=cl1(=S)I.NO.[SiH2]=Cl.ni[si]=[Si]=Br' for input: 'C=Br[SiH3].CO.F=N#[SiH].FI.N#Fc1(cl)s2(=Clo[siH]-2)-c2([siH]fBr#s(=P)c#[si]-2(i)BrC=O)=cl1(=S)I.NO.[SiH2]=Cl.ni[si]=[Si]=Br'
# [03:18:52] SMILES Parse Error: syntax error while parsing: N#Br=f(o)p.N1OF1.N[IH][PH](=[PH]=Br)[SiH]([SiH3])#Br.OS.fcl.p[siH]clNBr
# [03:18:52] SMILES Parse Error: Failed parsing SMILES 'N#Br=f(o)p.N1OF1.N[IH][PH](=[PH]=Br)[SiH]([SiH3])#Br.OS.fcl.p[siH]clNBr' for input: 'N#Br=f(o)p.N1OF1.N[IH][PH](=[PH]=Br)[SiH]([SiH3])#Br.OS.fcl.p[siH]clNBr'
# [03:18:52] SMILES Parse Error: syntax error while parsing: C=o(p)-oi.Ip1p[siH]-1.P#Cci.P#Cl.[SiH2]=P.[siH2]cl.cf-clo.no.op
# [03:18:52] SMILES Parse Error: Failed parsing SMILES 'C=o(p)-oi.Ip1p[siH]-1.P#Cci.P#Cl.[SiH2]=P.[siH2]cl.cf-clo.no.op' for input: 'C=o(p)-oi.Ip1p[siH]-1.P#Cci.P#Cl.[SiH2]=P.[siH2]cl.cf-clo.no.op'
# [03:18:52] Explicit valence for atom # 1 Br, 2, is greater than permitted
# [03:18:52] SMILES Parse Error: syntax error while parsing: FF.NN.PFpi.[siH2]brFClCCl.[siH2]o=Br.ofF
# [03:18:52] SMILES Parse Error: Failed parsing SMILES 'FF.NN.PFpi.[siH2]brFClCCl.[siH2]o=Br.ofF' for input: 'FF.NN.PFpi.[siH2]brFClCCl.[siH2]o=Br.ofF'
# [03:18:52] SMILES Parse Error: syntax error while parsing: CBr.NF.O[siH]o([siH2])cl.PCl.SCl.n[siH2]
# [03:18:52] SMILES Parse Error: Failed parsing SMILES 'CBr.NF.O[siH]o([siH2])cl.PCl.SCl.n[siH2]' for input: 'CBr.NF.O[siH]o([siH2])cl.PCl.SCl.n[siH2]'
# [03:18:52] SMILES Parse Error: syntax error while parsing: C#Cl.CI.CSS.Cl=[SiH]Br.CssCl.F#Br#ClBr#[SH].F=n(f)[PH]#[SH].FI.OI.PS
# [03:18:52] SMILES Parse Error: Failed parsing SMILES 'C#Cl.CI.CSS.Cl=[SiH]Br.CssCl.F#Br#ClBr#[SH].F=n(f)[PH]#[SH].FI.OI.PS' for input: 'C#Cl.CI.CSS.Cl=[SiH]Br.CssCl.F#Br#ClBr#[SH].F=n(f)[PH]#[SH].FI.OI.PS'
# [03:18:52] SMILES Parse Error: syntax error while parsing: BrP=Br.C=O.ClBr.F#P.F#[SiH].FF.S[siH]cl.fp.fs.obr.oi
# [03:18:52] SMILES Parse Error: Failed parsing SMILES 'BrP=Br.C=O.ClBr.F#P.F#[SiH].FF.S[siH]cl.fp.fs.obr.oi' for input: 'BrP=Br.C=O.ClBr.F#P.F#[SiH].FF.S[siH]cl.fp.fs.obr.oi'
# [03:18:52] SMILES Parse Error: syntax error while parsing: C#[SiH].P[IH]BrBr.SBr.clbrOBr.ncNCl
# [03:18:52] SMILES Parse Error: Failed parsing SMILES 'C#[SiH].P[IH]BrBr.SBr.clbrOBr.ncNCl' for input: 'C#[SiH].P[IH]BrBr.SBr.clbrOBr.ncNCl'
# [03:18:52] SMILES Parse Error: syntax error while parsing: FclpI.[SiH3]csclS[SiH3]
# [03:18:52] SMILES Parse Error: Failed parsing SMILES 'FclpI.[SiH3]csclS[SiH3]' for input: 'FclpI.[SiH3]csclS[SiH3]'
# [03:18:52] SMILES Parse Error: syntax error while parsing: NI.O=[PH](#O)f1(s)SCl1.PS.[siH2]cl.c[siH2]
# [03:18:52] SMILES Parse Error: Failed parsing SMILES 'NI.O=[PH](#O)f1(s)SCl1.PS.[siH2]cl.c[siH2]' for input: 'NI.O=[PH](#O)f1(s)SCl1.PS.[siH2]cl.c[siH2]'
# [03:18:52] non-ring atom 9 marked aromatic
# [03:18:52] SMILES Parse Error: syntax error while parsing: FI.NPO.Ncbr.[SiH3]S.c[siH]Cl
# [03:18:52] SMILES Parse Error: Failed parsing SMILES 'FI.NPO.Ncbr.[SiH3]S.c[siH]Cl' for input: 'FI.NPO.Ncbr.[SiH3]S.c[siH]Cl'
# [03:18:52] SMILES Parse Error: syntax error while parsing: C#[si](=[SiH2])p(br)#Cl#O.F#SPCl#[SiH].FP.N#fco.N=O.NBr.OP.P=[IH].[siH2]cl
# [03:18:52] SMILES Parse Error: Failed parsing SMILES 'C#[si](=[SiH2])p(br)#Cl#O.F#SPCl#[SiH].FP.N#fco.N=O.NBr.OP.P=[IH].[siH2]cl' for input: 'C#[si](=[SiH2])p(br)#Cl#O.F#SPCl#[SiH].FP.N#fco.N=O.NBr.OP.P=[IH].[siH2]cl'
# [03:18:52] Explicit valence for atom # 1 Br, 2, is greater than permitted
# [03:18:52] SMILES Parse Error: syntax error while parsing: CPCN.F[SiH3].Oinbr
# [03:18:52] SMILES Parse Error: Failed parsing SMILES 'CPCN.F[SiH3].Oinbr' for input: 'CPCN.F[SiH3].Oinbr'
# [03:18:52] SMILES Parse Error: syntax error while parsing: Br=fcO#N#I.F=[IH].N#Cl.NBrbrbr.P#[SH].cli.ncl.ni.no1c(P)(=Ibr(f)#FBr)[SiH](SBr(#[si]br)Br(#Cl)c(#F)i)#CBr1=F
# [03:18:52] SMILES Parse Error: Failed parsing SMILES 'Br=fcO#N#I.F=[IH].N#Cl.NBrbrbr.P#[SH].cli.ncl.ni.no1c(P)(=Ibr(f)#FBr)[SiH](SBr(#[si]br)Br(#Cl)c(#F)i)#CBr1=F' for input: 'Br=fcO#N#I.F=[IH].N#Cl.NBrbrbr.P#[SH].cli.ncl.ni.no1c(P)(=Ibr(f)#FBr)[SiH](SBr(#[si]br)Br(#Cl)c(#F)i)#CBr1=F'
# [03:18:52] SMILES Parse Error: syntax error while parsing: C#SF.C#[Si]C[SiH2][SiH2]clo.PSP.S=Cl
# [03:18:52] SMILES Parse Error: Failed parsing SMILES 'C#SF.C#[Si]C[SiH2][SiH2]clo.PSP.S=Cl' for input: 'C#SF.C#[Si]C[SiH2][SiH2]clo.PSP.S=Cl'
# [03:18:52] Explicit valence for atom # 5 F, 4, is greater than permitted
# [03:18:52] non-ring atom 5 marked aromatic
# [03:18:52] SMILES Parse Error: syntax error while parsing: C#[SiH].C=O.ONbr(=[IH])sc(=F)f.Ops.[SiH3]I.[SiH3]P.co.ncl#F
# [03:18:52] SMILES Parse Error: Failed parsing SMILES 'C#[SiH].C=O.ONbr(=[IH])sc(=F)f.Ops.[SiH3]I.[SiH3]P.co.ncl#F' for input: 'C#[SiH].C=O.ONbr(=[IH])sc(=F)f.Ops.[SiH3]I.[SiH3]P.co.ncl#F'
# [03:18:52] Explicit valence for atom # 1 F, 2, is greater than permitted
# [03:18:52] SMILES Parse Error: syntax error while parsing: Cnci.clcl.cn
# [03:18:52] SMILES Parse Error: Failed parsing SMILES 'Cnci.clcl.cn' for input: 'Cnci.clcl.cn'
# [03:18:52] non-ring atom 7 marked aromatic
# [03:18:52] SMILES Parse Error: syntax error while parsing: CS[SiH3].C[IH]I.nfBrFO
# [03:18:52] SMILES Parse Error: Failed parsing SMILES 'CS[SiH3].C[IH]I.nfBrFO' for input: 'CS[SiH3].C[IH]I.nfBrFO'
# [03:18:52] non-ring atom 6 marked aromatic
# [03:18:52] SMILES Parse Error: syntax error while parsing: ClI.NOI.ccl
# [03:18:52] SMILES Parse Error: Failed parsing SMILES 'ClI.NOI.ccl' for input: 'ClI.NOI.ccl'
# [03:18:52] non-ring atom 5 marked aromatic
# [03:18:52] SMILES Parse Error: syntax error while parsing: OCF.[SiH3]N[SiH3].ocl
# [03:18:52] SMILES Parse Error: Failed parsing SMILES 'OCF.[SiH3]N[SiH3].ocl' for input: 'OCF.[SiH3]N[SiH3].ocl'
# [03:18:52] SMILES Parse Error: syntax error while parsing: CC.CF.CPP.Nclp.SCl
# [03:18:52] SMILES Parse Error: Failed parsing SMILES 'CC.CF.CPP.Nclp.SCl' for input: 'CC.CF.CPP.Nclp.SCl'
# [03:18:52] SMILES Parse Error: syntax error while parsing: FssN[IH]S.N#Br.NBr.S[IH]#Br.ci.n[siH2].pi
# [03:18:52] SMILES Parse Error: Failed parsing SMILES 'FssN[IH]S.N#Br.NBr.S[IH]#Br.ci.n[siH2].pi' for input: 'FssN[IH]S.N#Br.NBr.S[IH]#Br.ci.n[siH2].pi'
# [03:18:52] SMILES Parse Error: syntax error while parsing: CONf1[siH][SiH2]1.NS.N[SiH2]F
# [03:18:52] SMILES Parse Error: Failed parsing SMILES 'CONf1[siH][SiH2]1.NS.N[SiH2]F' for input: 'CONf1[siH][SiH2]1.NS.N[SiH2]F'
# [03:18:52] Explicit valence for atom # 4 Cl, 2, is greater than permitted
# [03:18:52] SMILES Parse Error: syntax error while parsing: CClCl.FClP.SFS.pbr
# [03:18:52] SMILES Parse Error: Failed parsing SMILES 'CClCl.FClP.SFS.pbr' for input: 'CClCl.FClP.SFS.pbr'
# [03:18:52] SMILES Parse Error: syntax error while parsing: BrI.O[SiH3].[SiH]#I.c[siH2].cliBr
# [03:18:52] SMILES Parse Error: Failed parsing SMILES 'BrI.O[SiH3].[SiH]#I.c[siH2].cliBr' for input: 'BrI.O[SiH3].[SiH]#I.c[siH2].cliBr'
# [03:18:52] SMILES Parse Error: syntax error while parsing: CF[IH]#N.Ofs.PBr.c[si](#N)P.ocS.op
# [03:18:52] SMILES Parse Error: Failed parsing SMILES 'CF[IH]#N.Ofs.PBr.c[si](#N)P.ocS.op' for input: 'CF[IH]#N.Ofs.PBr.c[si](#N)P.ocS.op'
# [03:18:52] SMILES Parse Error: syntax error while parsing: FBrCS.FBrCl.FS.cp.fcls
# [03:18:52] SMILES Parse Error: Failed parsing SMILES 'FBrCS.FBrCl.FS.cp.fcls' for input: 'FBrCS.FBrCl.FS.cp.fcls'
# [03:18:52] SMILES Parse Error: syntax error while parsing: Clooc-brclBr.NCl.SBr.[SiH3]S.ccl
# [03:18:52] SMILES Parse Error: Failed parsing SMILES 'Clooc-brclBr.NCl.SBr.[SiH3]S.ccl' for input: 'Clooc-brclBr.NCl.SBr.[SiH3]S.ccl'
# [03:18:52] SMILES Parse Error: syntax error while parsing: BrCl#I.C#Br.CP.C[Si]#[SH].FP1[SiH2]sclcl2[IH][SH]12.F[SiH3].OBrF#[SiH].ocl
# [03:18:52] SMILES Parse Error: Failed parsing SMILES 'BrCl#I.C#Br.CP.C[Si]#[SH].FP1[SiH2]sclcl2[IH][SH]12.F[SiH3].OBrF#[SiH].ocl' for input: 'BrCl#I.C#Br.CP.C[Si]#[SH].FP1[SiH2]sclcl2[IH][SH]12.F[SiH3].OBrF#[SiH].ocl'
# [03:18:52] SMILES Parse Error: syntax error while parsing: Br#I.FCl.O#ClFP.npC1NI2(#OO)cl(i2n)-[siH]i1
# [03:18:52] SMILES Parse Error: Failed parsing SMILES 'Br#I.FCl.O#ClFP.npC1NI2(#OO)cl(i2n)-[siH]i1' for input: 'Br#I.FCl.O#ClFP.npC1NI2(#OO)cl(i2n)-[siH]i1'
# [03:18:52] SMILES Parse Error: syntax error while parsing: N=[IH].N=fsbr.[siH2]p#ci.bri
# [03:18:52] SMILES Parse Error: Failed parsing SMILES 'N=[IH].N=fsbr.[siH2]p#ci.bri' for input: 'N=[IH].N=fsbr.[siH2]p#ci.bri'
# [03:18:52] SMILES Parse Error: syntax error while parsing: C#O.C[SiH3].Cicl.F#[SH].FP[Si](#P)=I#Cl.O#[SH].O=[SiH2].bri.pbr(Cl)br
# [03:18:52] SMILES Parse Error: Failed parsing SMILES 'C#O.C[SiH3].Cicl.F#[SH].FP[Si](#P)=I#Cl.O#[SH].O=[SiH2].bri.pbr(Cl)br' for input: 'C#O.C[SiH3].Cicl.F#[SH].FP[Si](#P)=I#Cl.O#[SH].O=[SiH2].bri.pbr(Cl)br'
# [03:18:52] Explicit valence for atom # 0 Br, 3, is greater than permitted
# [03:18:52] SMILES Parse Error: syntax error while parsing: FPPBr.Pbrbr.PnpI.of
# [03:18:52] SMILES Parse Error: Failed parsing SMILES 'FPPBr.Pbrbr.PnpI.of' for input: 'FPPBr.Pbrbr.PnpI.of'
# [03:18:52] SMILES Parse Error: syntax error while parsing: FClClCss.N#P.OI.Osbr
# [03:18:52] SMILES Parse Error: Failed parsing SMILES 'FClClCss.N#P.OI.Osbr' for input: 'FClClCss.N#P.OI.Osbr'
# [03:18:52] SMILES Parse Error: syntax error while parsing: F=F.O#obrcO.cpSBr.fs
# [03:18:52] SMILES Parse Error: Failed parsing SMILES 'F=F.O#obrcO.cpSBr.fs' for input: 'F=F.O#obrcO.cpSBr.fs'
# [03:18:52] SMILES Parse Error: syntax error while parsing: C#ClF.F=S.F[IH]I.N[SiH3].P=Br.PBr.cc.ccl(Br)ON.f[siH2]
# [03:18:52] SMILES Parse Error: Failed parsing SMILES 'C#ClF.F=S.F[IH]I.N[SiH3].P=Br.PBr.cc.ccl(Br)ON.f[siH2]' for input: 'C#ClF.F=S.F[IH]I.N[SiH3].P=Br.PBr.cc.ccl(Br)ON.f[siH2]'
# [03:18:52] SMILES Parse Error: syntax error while parsing: F=[SiH2].FClS.NP.OCl#Br.OP.SCl[SiH2][SH](ClBr)#I=Cl.[siH2]n[siH2].brbr.os
# [03:18:52] SMILES Parse Error: Failed parsing SMILES 'F=[SiH2].FClS.NP.OCl#Br.OP.SCl[SiH2][SH](ClBr)#I=Cl.[siH2]n[siH2].brbr.os' for input: 'F=[SiH2].FClS.NP.OCl#Br.OP.SCl[SiH2][SH](ClBr)#I=Cl.[siH2]n[siH2].brbr.os'
# [03:18:52] SMILES Parse Error: syntax error while parsing: CCl.Cl#Br.O#Cl.OBr.PNpo-ni.[SiH3]S
# [03:18:52] SMILES Parse Error: Failed parsing SMILES 'CCl.Cl#Br.O#Cl.OBr.PNpo-ni.[SiH3]S' for input: 'CCl.Cl#Br.O#Cl.OBr.PNpo-ni.[SiH3]S'
# [03:18:52] SMILES Parse Error: syntax error while parsing: CN.CPCCoi.OF
# [03:18:52] SMILES Parse Error: Failed parsing SMILES 'CN.CPCCoi.OF' for input: 'CN.CPCCoi.OF'
# [03:18:52] Explicit valence for atom # 3 F, 2, is greater than permitted
# [03:18:52] SMILES Parse Error: syntax error while parsing: CPOClC.SS.nclClO
# [03:18:52] SMILES Parse Error: Failed parsing SMILES 'CPOClC.SS.nclClO' for input: 'CPOClC.SS.nclClO'
# [03:18:52] SMILES Parse Error: syntax error while parsing: C#P.F[IH]I.NI.[SiH3][siH]pP.[SiH]#P.sbrCl
# [03:18:52] SMILES Parse Error: Failed parsing SMILES 'C#P.F[IH]I.NI.[SiH3][siH]pP.[SiH]#P.sbrCl' for input: 'C#P.F[IH]I.NI.[SiH3][siH]pP.[SiH]#P.sbrCl'
# [03:18:52] SMILES Parse Error: syntax error while parsing: Nsc-siO.[SiH3]P
# [03:18:52] SMILES Parse Error: Failed parsing SMILES 'Nsc-siO.[SiH3]P' for input: 'Nsc-siO.[SiH3]P'
# [03:18:52] SMILES Parse Error: syntax error while parsing: F#F.NS.O=F.ONo[siH2].P#Br.PCl.PI.ci.of
# [03:18:52] SMILES Parse Error: Failed parsing SMILES 'F#F.NS.O=F.ONo[siH2].P#Br.PCl.PI.ci.of' for input: 'F#F.NS.O=F.ONo[siH2].P#Br.PCl.PI.ci.of'
# [03:18:52] SMILES Parse Error: syntax error while parsing: C#i1cln2cl3#p45(i)i6(Cl)(o(#N)S[IH]P)#o7n#C#C8#br([si]#4#C(#P)#[si]c4ni1I(#P)(O=S)=i#6f-o(o4=[IH]=o(cl)clC#7#N#Br#I)cl=8i#S#I)P=f([si](c)Cl)o=[si](cl=3-2c)#S#5
# [03:18:52] SMILES Parse Error: Failed parsing SMILES 'C#i1cln2cl3#p45(i)i6(Cl)(o(#N)S[IH]P)#o7n#C#C8#br([si]#4#C(#P)#[si]c4ni1I(#P)(O=S)=i#6f-o(o4=[IH]=o(cl)clC#7#N#Br#I)cl=8i#S#I)P=f([si](c)Cl)o=[si](cl=3-2c)#S#5' for input: 'C#i1cln2cl3#p45(i)i6(Cl)(o(#N)S[IH]P)#o7n#C#C8#br([si]#4#C(#P)#[si]c4ni1I(#P)(O=S)=i#6f-o(o4=[IH]=o(cl)clC#7#N#Br#I)cl=8i#S#I)P=f([si](c)Cl)o=[si](cl=3-2c)#S#5'
# [03:18:52] SMILES Parse Error: syntax error while parsing: C[SiH3].SI.[SiH3]Cl.fp
# [03:18:52] SMILES Parse Error: Failed parsing SMILES 'C[SiH3].SI.[SiH3]Cl.fp' for input: 'C[SiH3].SI.[SiH3]Cl.fp'
# [03:18:52] Explicit valence for atom # 6 Cl, 2, is greater than permitted
# [03:18:52] Explicit valence for atom # 4 Cl, 2, is greater than permitted
# [03:18:52] SMILES Parse Error: syntax error while parsing: ClClCl.ClOPCl.PClI.cli
# [03:18:52] SMILES Parse Error: Failed parsing SMILES 'ClClCl.ClOPCl.PClI.cli' for input: 'ClClCl.ClOPCl.PClI.cli'
# [03:18:52] SMILES Parse Error: syntax error while parsing: Br#I.CF.ClclnBr.OO[SiH3].[SiH3]I.fbr
# [03:18:52] SMILES Parse Error: Failed parsing SMILES 'Br#I.CF.ClclnBr.OO[SiH3].[SiH3]I.fbr' for input: 'Br#I.CF.ClclnBr.OO[SiH3].[SiH3]I.fbr'
# [03:18:52] non-ring atom 4 marked aromatic
# [03:18:52] SMILES Parse Error: syntax error while parsing: BrI.CBrO.PS.fiObrbr
# [03:18:52] SMILES Parse Error: Failed parsing SMILES 'BrI.CBrO.PS.fiObrbr' for input: 'BrI.CBrO.PS.fiObrbr'
# [03:18:52] Explicit valence for atom # 2 Cl, 2, is greater than permitted
# [03:18:52] SMILES Parse Error: syntax error while parsing: C#N(O)(P)#I#N.C=F.F#F=Br.F=P.N=i(n)c=[IH].OO.O[SiH2]I.POPCl.[siH2]i
# [03:18:52] SMILES Parse Error: Failed parsing SMILES 'C#N(O)(P)#I#N.C=F.F#F=Br.F=P.N=i(n)c=[IH].OO.O[SiH2]I.POPCl.[siH2]i' for input: 'C#N(O)(P)#I#N.C=F.F#F=Br.F=P.N=i(n)c=[IH].OO.O[SiH2]I.POPCl.[siH2]i'
# [03:18:52] SMILES Parse Error: syntax error while parsing: Cl#Br.F=Cl.Obrp.[SiH3][SiH](Cl)#[SH]=Cl
# [03:18:52] SMILES Parse Error: Failed parsing SMILES 'Cl#Br.F=Cl.Obrp.[SiH3][SiH](Cl)#[SH]=Cl' for input: 'Cl#Br.F=Cl.Obrp.[SiH3][SiH](Cl)#[SH]=Cl'
# [03:18:52] Explicit valence for atom # 6 Br, 2, is greater than permitted
# [03:18:52] SMILES Parse Error: syntax error while parsing: CFO.O#Br.ccObrc=PN.cn[siH2]
# [03:18:52] SMILES Parse Error: Failed parsing SMILES 'CFO.O#Br.ccObrc=PN.cn[siH2]' for input: 'CFO.O#Br.ccObrc=PN.cn[siH2]'
# [03:18:52] non-ring atom 3 marked aromatic
# [03:18:52] SMILES Parse Error: syntax error while parsing: CF[SiH2]F.CO.clnI.niBr
# [03:18:52] SMILES Parse Error: Failed parsing SMILES 'CF[SiH2]F.CO.clnI.niBr' for input: 'CF[SiH2]F.CO.clnI.niBr'
# [03:18:52] Explicit valence for atom # 3 F, 3, is greater than permitted
# [03:18:52] SMILES Parse Error: syntax error while parsing: BrI.CBr.ClBr.OS.PCl.ccl
# [03:18:52] SMILES Parse Error: Failed parsing SMILES 'BrI.CBr.ClBr.OS.PCl.ccl' for input: 'BrI.CBr.ClBr.OS.PCl.ccl'
# [03:18:52] SMILES Parse Error: syntax error while parsing: FCl.N[SiH3].OBr.[SiH3]OCl#I.[siH2]sf[IH][SiH3]
# [03:18:52] SMILES Parse Error: Failed parsing SMILES 'FCl.N[SiH3].OBr.[SiH3]OCl#I.[siH2]sf[IH][SiH3]' for input: 'FCl.N[SiH3].OBr.[SiH3]OCl#I.[siH2]sf[IH][SiH3]'
# [03:18:52] SMILES Parse Error: syntax error while parsing: CON.NFCl.[siH2]i
# [03:18:52] SMILES Parse Error: Failed parsing SMILES 'CON.NFCl.[siH2]i' for input: 'CON.NFCl.[siH2]i'
# [03:18:52] non-ring atom 2 marked aromatic
# [03:18:52] SMILES Parse Error: syntax error while parsing: C=Cl.COS.FO(F)nf.FS.FbriP.ofS
# [03:18:52] SMILES Parse Error: Failed parsing SMILES 'C=Cl.COS.FO(F)nf.FS.FbriP.ofS' for input: 'C=Cl.COS.FO(F)nf.FS.FbriP.ofS'
# [03:18:52] SMILES Parse Error: syntax error while parsing: CBr[siH]o.F#[SH].N=[IH].PNBr.[siH2]i.ocl
# [03:18:52] SMILES Parse Error: Failed parsing SMILES 'CBr[siH]o.F#[SH].N=[IH].PNBr.[siH2]i.ocl' for input: 'CBr[siH]o.F#[SH].N=[IH].PNBr.[siH2]i.ocl'
# [03:18:52] SMILES Parse Error: syntax error while parsing: C=N.N=Cl#Br.NN.NP.O#Spcl.[SiH3]P.[SiH3][IH]fbr.ci.fi
# [03:18:52] SMILES Parse Error: Failed parsing SMILES 'C=N.N=Cl#Br.NN.NP.O#Spcl.[SiH3]P.[SiH3][IH]fbr.ci.fi' for input: 'C=N.N=Cl#Br.NN.NP.O#Spcl.[SiH3]P.[SiH3][IH]fbr.ci.fi'
# [03:18:52] SMILES Parse Error: syntax error while parsing: SCS.SbrpPCl.coPip
# [03:18:52] SMILES Parse Error: Failed parsing SMILES 'SCS.SbrpPCl.coPip' for input: 'SCS.SbrpPCl.coPip'
# [03:18:52] SMILES Parse Error: syntax error while parsing: SOFBrCl.[SiH3]pnI.fcl
# [03:18:52] SMILES Parse Error: Failed parsing SMILES 'SOFBrCl.[SiH3]pnI.fcl' for input: 'SOFBrCl.[SiH3]pnI.fcl'

# %%
print("Percentage of Valid Molecules With Bonds: ", success_count / (error_count + success_count)* 100)
# Out:
# Percentage of Valid Molecules With Bonds:  7.000000000000001
