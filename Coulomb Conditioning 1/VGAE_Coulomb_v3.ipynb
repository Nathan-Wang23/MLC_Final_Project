# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import os
import numpy as np
from torch_geometric.nn import global_add_pool, GATConv, CGConv, VGAE,GCNConv, RGCNConv, global_mean_pool
import pickle
from itertools import combinations
from sklearn.model_selection import train_test_split
from torch_geometric.data import DataLoader, Data
from torch.utils.data import Dataset, DataLoader
from torch_geometric.data import Data, Batch
from tqdm import tqdm
import torch.optim as optim
import math
from torch_geometric.data import DataLoader
from torch_geometric.nn import RGCNConv, global_mean_pool
from torch_geometric.data import Data, Batch
from torch.utils.data import Dataset, DataLoader
import pickle
from torch.optim import Adam, RMSprop
from tqdm import tqdm
from rdkit.Chem.rdMolDescriptors import CalcMolFormula

# %%
from contextlib import contextmanager
import sys
import os
import torch
from ase import Atoms
from ase.data import chemical_symbols
from ase.calculators.morse import MorsePotential
from ase.optimize import QuasiNewton
import numpy as np
import pickle
from rdkit.Chem import rdchem

import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from ase import Atoms
from ase.io import read
from torch_geometric.data import Data
from torch_geometric.nn import MessagePassing
from torch_geometric.utils import to_networkx
# from torch_geometric.data import DataLoader, TensorDataset
from torch_geometric.loader import DataLoader
from sklearn.model_selection import train_test_split
from ase.build import molecule
import pandas as pd
from rdkit import Chem
from rdkit.Chem import AllChem
import random
from torch_geometric.nn import global_add_pool, GATConv, CGConv, GCNConv, RGCNConv
from torch_geometric.nn.models.schnet import GaussianSmearing
from sklearn.metrics import roc_auc_score, precision_score, confusion_matrix
import matplotlib.pyplot as plt
import pickle
from collections import Counter
import seaborn as sns
import time
from torch.optim.lr_scheduler import StepLR
import torch
from torch_geometric.data import Data
from dscribe.descriptors import SOAP, ACSF, CoulombMatrix

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %%
def debug_nan(tensor, name="Tensor"):
    if torch.isnan(tensor).any():
        print(f"NaN detected in {name}")
        print(tensor)

# %%
class RGCN_VGAE(nn.Module):
    def __init__(self, in_channels, out_channels, num_relations, num_node_features, max_nodes, bond_dim, atom_dim):
        super(RGCN_VGAE, self).__init__()
        self.num_relations = num_relations
        self.max_nodes = max_nodes
        self.atom_dim = atom_dim
        self.bond_dim = bond_dim

        self.rgcn1 = RGCNConv(in_channels, out_channels, num_relations=num_relations)
        self.rgcn2 = RGCNConv(out_channels, out_channels, num_relations=num_relations)
        self.rgcn3 = RGCNConv(out_channels, out_channels, num_relations=num_relations)

        self.fc_mu = nn.Linear(out_channels, out_channels)
        self.fc_logvar = nn.Linear(out_channels, out_channels)

        self.adj_decoder = nn.Sequential(
            nn.Linear(out_channels + 252, out_channels),
            nn.ReLU(),
            nn.Linear(out_channels, max_nodes * max_nodes * bond_dim)
        )
        self.feature_decoder = nn.Linear(out_channels + 252, max_nodes * atom_dim)

        self.cond_pool1 = nn.AdaptiveAvgPool1d(9901)
        self.cond_linear1 = nn.Linear(9901, 3_808)

    def reparameterize(self, mu, logvar):
        if self.training:
            std = torch.exp(0.5 * logvar)
            eps = torch.randn_like(std)
            return eps.mul(std).add_(mu)
        else:
            return mu

    def forward(self, data):
        x, edge_index, edge_attr, batch = data.x, data.edge_index, data.edge_attr, data.batch
        conditional = data.descriptor
        edge_attr = torch.argmax(edge_attr, dim=1).long()

        # print(x.shape)
        # print(edge_index.shape)
        # print(edge_attr.shape)
        x = F.relu(self.rgcn1(x, edge_index, edge_attr))
        x = F.relu(self.rgcn2(x, edge_index, edge_attr))
        # x = F.relu(self.rgcn3(x, edge_index, edge_attr))
        x = global_mean_pool(x, batch)

        mu = self.fc_mu(x)
        logvar = self.fc_logvar(x)
        conditional = conditional.transpose(0,1)
        conditional = conditional.unsqueeze(1)
        conditional = self.cond_pool1(conditional)
        # conditional = conditional.view(1, -1)
        conditional = self.cond_linear1(conditional)
        conditional = conditional.view(952, -1).squeeze(0)

        z = self.reparameterize(mu, logvar)
        z = torch.cat((z, conditional), dim=1)

        A_pred = self.adj_decoder(z).view(-1, self.max_nodes, self.max_nodes, self.bond_dim)
        A_pred = F.softmax(A_pred, dim=-1)

        features_pred = self.feature_decoder(z).view(-1, self.max_nodes, self.atom_dim)
        features_pred = F.softmax(features_pred, dim=-1)

        return A_pred, features_pred, mu, logvar

    def decode(self, z):
        A_pred = self.adj_decoder(z).view(-1, self.max_nodes, self.max_nodes, self.bond_dim)
        A_pred = F.softmax(A_pred, dim=-1)

        features_pred = self.feature_decoder(z).view(-1, self.max_nodes, self.atom_dim)
        features_pred = F.softmax(features_pred, dim=-1)

        return A_pred, features_pred

# %%
# with open("../data/combined_data.pkl", "rb") as file:
#     combined_data = pickle.load(file)

atomic_number_tensors = torch.load("data/atomic_number_tensors.pt")
bond_tensors = torch.load("data/bond_tensors.pt")

# %%
NUM_ATOMS = 63
ATOM_DIM = 11
BOND_DIM = 5
LATENT_DIM = 512
HIDDEN_CHANNELS = 128
NUM_RELATION_TYPES = BOND_DIM - 1
NODE_FEATURE_DIM = ATOM_DIM - 1
# NODE_FEATURE_DIM = ATOM_DIM
BATCH_SIZE = 512
NUM_EPOCHS = 300

# %%
model = RGCN_VGAE(NODE_FEATURE_DIM, LATENT_DIM, NUM_RELATION_TYPES, NODE_FEATURE_DIM, NUM_ATOMS, BOND_DIM, ATOM_DIM).to(device)

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=0.0001)

# %%
class GraphDataset(Dataset):
    def __init__(self, adjacency_matrices, atom_features):
        self.adjacency_matrices = adjacency_matrices
        self.atom_features = atom_features

    def __len__(self):
        return self.adjacency_matrices.size(0)

    def __getitem__(self, idx):
        return self.adjacency_matrices[idx], self.atom_features[idx]

dataset = GraphDataset(bond_tensors, atomic_number_tensors)

dataloader = DataLoader(dataset, batch_size=BATCH_SIZE, shuffle=True)

# %%
weights_atoms = torch.ones(ATOM_DIM).to(device)
weights_bonds = torch.ones(BOND_DIM).to(device)

weights_atoms[0] = 0.5
weights_atoms[10] = 8
weights_bonds[4] = 0.5

weights_atoms.to(device)
weights_bonds.to(device)

def calculate_kl_divergence(mu, logvar):
    kl_divergence = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp())
    return kl_divergence

# def calculate_uniqueness_loss(bonds_pred, atoms_pred):
#     datapoints = process_graph_data_to_data_objects(bonds_pred, atoms_pred)
#     num_unique = 0
#     seen_set = set()
#     for dp in datapoints:
#         mol, formula = to_chemula(dp)
#         if formula not in seen_set:
#             num_unique += 1
#             seen_set.add(formula)
#     return num_unique

def loss_function(preds, labels, mu, logvar, preds_atomic, atomic_numbers, lambda_kld, device):

    batch_size = preds.shape[0]
    labels = torch.argmax(labels, dim=-1)
    atomic_numbers = torch.argmax(atomic_numbers, dim=-1)
    preds, labels = preds.to(device), labels.to(device)
    preds_atomic, atomic_numbers = preds_atomic.to(device), atomic_numbers.to(device)
    mu, logvar = mu.to(device), logvar.to(device)

    # print(preds.shape)
    # print(labels.shape)
    # print(preds_atomic.shape)
    # print(atomic_numbers.shape)

    ce_bond = F.cross_entropy(preds.view(-1, preds.size(-1)), labels.view(-1), weight=weights_bonds.to(device))
    ce_atomic = F.cross_entropy(preds_atomic.view(-1, preds_atomic.size(-1)), atomic_numbers.view(-1), weight=weights_atoms.to(device))

    kld = calculate_kl_divergence(mu, logvar)

    atom_presence_mask = torch.argmax(preds_atomic, dim=-1) != 10
    atom_count = torch.sum(atom_presence_mask)
    atom_count = atom_count / batch_size
    atomic_regulizer = atom_count / batch_size * 3


    bond_presence_mask = torch.argmax(preds, dim=-1) != 4
    bond_count = torch.sum(bond_presence_mask)
    bond_count = bond_count / batch_size

    if int(atom_count) <= 50:
        # print(atom_count)
        atomic_regulizer = 2000 - 10 * int(atom_count)

    if bond_count < 100:
        bond_regulizer = 0.0
    elif bond_count <= 50:
        bond_regulizer = 2000 - 5 * bond_count
    else:
        bond_regulizer = 10

    # unique_counts = set()

    # for b in preds_atomic:
    #     atom_counts = np.zeros(11, dtype=int)
    #     for j in range(63):
    #         for k in range(11):
    #             if b[j, k] == 1:
    #                 atom_counts[k] += 1
    #     counts_tuple = tuple(atom_counts)
    #     unique_counts.add(counts_tuple)

    # num_same = len(unique_counts)
    # print(num_same)

    total_loss = 0.4 * ce_bond + lambda_kld * kld + 1.9 * ce_atomic + 0.6 * atomic_regulizer + 0.2 * bond_regulizer

    print(kld, ce_atomic, ce_bond, atomic_regulizer, bond_regulizer)
    return total_loss

# %%
atomic_mapping = {0: 6, 1: 7, 2:8, 3:9, 4:14, 5:15, 6:16, 7:17, 8:35, 9:53}

# %%
def create_feature_descriptor(atomic_nums):
    numbers = torch.argmax(atomic_nums, dim=-1)
    numbers = [atomic_mapping[index.item()] for index in numbers if index < 10]

    positions = np.random.rand(len(numbers), 3) * 10

    atoms = Atoms(numbers=numbers, positions=positions)

    cm = CoulombMatrix(n_atoms_max=len(numbers), permutation="sorted_l2")

    cm_descriptor = cm.create(atoms).reshape(len(numbers), len(numbers))
    if len(numbers) < 63:
        cm_descriptor = np.pad(cm_descriptor, ((0, 63 - len(numbers)), (0, 63 - len(numbers))), mode='constant', constant_values=0)
    return cm_descriptor

# %%
def process_graph_data_to_data_objects(batch_adjacency, batch_atoms, grad = False):
    batch_size = batch_adjacency.shape[0]
    num_nodes = batch_adjacency.shape[1]
    num_bond_types = batch_adjacency.shape[3] - 1
    num_atom_types = batch_atoms.shape[2] - 1
    # print(num_atom_types)

    data_objects = []

    for idx in range(batch_size):
        edge_index = []
        edge_attr = []
        x = []
        node_index_map = {}

        adjacency = batch_adjacency[idx]
        atoms = batch_atoms[idx]

        new_idx = 0

        descriptor = torch.tensor(create_feature_descriptor(atoms), dtype=torch.float32)
        # padded_descriptor = np.pad(descriptor, ((0, 0), (0, 9000 - descriptor.shape[1])), mode='constant', constant_values=0)
        # padded_descriptor = torch.tensor(padded_descriptor)
        # print(padded_descriptor.shape)

        for i in range(num_nodes):
            for j in range(i + 1, num_nodes):
                bond_type = torch.argmax(adjacency[i, j])
                # if adjacency[i,j][num_bond_types] > 0.18:
                #     # print('overwrite')
                    # continue
                if bond_type < num_bond_types:  # Bond exists
                    atom_type_i = torch.argmax(atoms[i])
                    atom_type_j = torch.argmax(atoms[j])
                    if atom_type_i == num_atom_types or atom_type_j == num_atom_types: # Both atoms must exist
                        continue
                    if i not in node_index_map:
                        node_index_map[i] = new_idx
                        new_idx+=1
                        x.append(torch.nn.functional.one_hot(torch.argmax(atoms[i]), num_classes=num_atom_types).float())
                    if j not in node_index_map:
                        node_index_map[j] = new_idx
                        new_idx+=1
                        x.append(torch.nn.functional.one_hot(torch.argmax(atoms[j]), num_classes=num_atom_types).float())
                    edge_index.append([node_index_map[i], node_index_map[j]])
                    bond_one_hot = torch.zeros(num_bond_types)
                    bond_one_hot[bond_type] = 1
                    edge_attr.append(bond_one_hot)
                    # print(bond_type)
                    # edge_attr.append(bond_type/num_bond_types)

        if edge_index:
            edge_index_tensor = torch.tensor(edge_index, dtype=torch.long).t().contiguous()
            edge_attr_tensor = torch.stack(edge_attr, dim=0)

        else:

            edge_index_tensor = torch.empty((2, 0), dtype=torch.long)
            edge_attr_tensor = torch.empty((0, num_bond_types), dtype=torch.float)


        if x:
            node_features_tensor = torch.stack(x, dim=0)
        else:

            node_features_tensor = torch.empty((0, num_atom_types), dtype=torch.float)


        # if grad:
        #     node_features_tensor.requires_grad_(True)
        #     edge_attr.requires_grad_(True)
        graph_data = Data(x=node_features_tensor, edge_index=edge_index_tensor, edge_attr=edge_attr_tensor, adj_matrix=adjacency, node_features=atoms, descriptor=descriptor)
        data_objects.append(graph_data)

    return data_objects

# %%
data_dataset = []
for adj_matrix, node_features in dataloader:
    adj_matrix.to(device)
    node_features.to(device)
    data = process_graph_data_to_data_objects(adj_matrix, node_features)
    data_dataset.append(data)

data_object_loader = DataLoader(data_dataset, batch_size=BATCH_SIZE, shuffle=True)

# %%
for b in data_object_loader:
    print(b[2])
    break
# Out:
# DataBatch(x=[203, 10], edge_index=[2, 212], edge_attr=[212, 4], adj_matrix=[441, 63, 5], node_features=[441, 11], descriptor=[441, 63], batch=[203], ptr=[8])

# %%
num_epochs = 700
for epoch in range(num_epochs):
    total_loss = 0
    #lambda_kld = min(1.0, 0.01 +  epoch/ num_epochs)
    lambda_kld = 1.1
    batch_count = 0
    for data in data_object_loader:
        # print(adj_matrix.shape)
        optimizer.zero_grad()

        # adj_matrix.to(device)
        # node_features.to(device)

        # data = process_graph_data_to_data_objects(adj_matrix, node_features)
        data = Batch.from_data_list(data).to(device)

        reconstructed, reconstructed_atoms, mu, logvar = model(data)

        loss = loss_function(
            reconstructed, data.adj_matrix,
            mu, logvar,
            reconstructed_atoms, data.node_features,
            lambda_kld, device
        )
        total_loss += loss.item()

        # Backpropagation
        loss.backward()
        optimizer.step()

        #for name, param in model.named_parameters():
        #    if param.requires_grad:
        #        print(f"Gradients of {name}: {param.grad}")

    # Calculate average loss for reporting
    avg_loss = total_loss / len(dataloader)
    print(f'Epoch {epoch + 1}, Loss: {loss.item()}')
# Out:
# tensor(497.4270, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.4042, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.6148, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.1805, device='cuda:0') 10
# Epoch 1, Loss: 554.4920654296875
# tensor(437.2658, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3963, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.6086, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.1781, device='cuda:0') 10
# Epoch 2, Loss: 488.295654296875
# tensor(385.1198, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3838, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.6018, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.1744, device='cuda:0') 10
# Epoch 3, Loss: 430.90643310546875
# tensor(339.9640, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3752, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.5940, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.1714, device='cuda:0') 10
# Epoch 4, Loss: 381.2137451171875
# tensor(300.7870, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3585, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.5846, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.1674, device='cuda:0') 10
# Epoch 5, Loss: 338.0810852050781
# tensor(266.6902, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3376, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.5732, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.1625, device='cuda:0') 10
# Epoch 6, Loss: 300.5275573730469
# tensor(236.9179, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3302, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.5617, device='cuda:0', grad_fn=<NllLossBackward0>) 1500 10
# Epoch 7, Loss: 1167.6617431640625
# tensor(210.8251, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.3082, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.5465, device='cuda:0', grad_fn=<NllLossBackward0>) 1510 10
# Epoch 8, Loss: 1144.911865234375
# tensor(187.8902, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.2806, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.5276, device='cuda:0', grad_fn=<NllLossBackward0>) 1530 10
# Epoch 9, Loss: 1131.6234130859375
# tensor(167.6579, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.2588, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.5087, device='cuda:0', grad_fn=<NllLossBackward0>) 1550 10
# Epoch 10, Loss: 1121.3189697265625
# tensor(149.7582, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.2404, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.4878, device='cuda:0', grad_fn=<NllLossBackward0>) 1570 10
# Epoch 11, Loss: 1113.5859375
# tensor(133.8695, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.2184, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.4654, device='cuda:0', grad_fn=<NllLossBackward0>) 1580 10
# Epoch 12, Loss: 1102.0574951171875
# tensor(119.7293, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.1863, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.4373, device='cuda:0', grad_fn=<NllLossBackward0>) 1610 10
# Epoch 13, Loss: 1104.4310302734375
# tensor(107.1734, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.1517, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.4056, device='cuda:0', grad_fn=<NllLossBackward0>) 1630 10
# Epoch 14, Loss: 1102.541259765625
# tensor(95.9965, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.1279, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.3777, device='cuda:0', grad_fn=<NllLossBackward0>) 1650 10
# Epoch 15, Loss: 1102.1900634765625
# tensor(86.0291, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.1004, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.3460, device='cuda:0', grad_fn=<NllLossBackward0>) 1670 10
# Epoch 16, Loss: 1103.1611328125
# tensor(77.1674, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.0734, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.3151, device='cuda:0', grad_fn=<NllLossBackward0>) 1690 10
# Epoch 17, Loss: 1105.349609375
# tensor(69.2895, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.0392, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.2801, device='cuda:0', grad_fn=<NllLossBackward0>) 1710 10
# Epoch 18, Loss: 1108.60498046875
# tensor(62.3010, device='cuda:0', grad_fn=<MulBackward0>) tensor(2.0128, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.2499, device='cuda:0', grad_fn=<NllLossBackward0>) 1740 10
# Epoch 19, Loss: 1118.85546875
# tensor(56.1322, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.9890, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.2225, device='cuda:0', grad_fn=<NllLossBackward0>) 1750 10
# Epoch 20, Loss: 1118.013427734375
# tensor(50.7081, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.9560, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.1896, device='cuda:0', grad_fn=<NllLossBackward0>) 1770 10
# Epoch 21, Loss: 1123.97119140625
# tensor(45.9473, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.9377, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.1677, device='cuda:0', grad_fn=<NllLossBackward0>) 1790 10
# Epoch 22, Loss: 1130.690673828125
# tensor(41.7795, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.9117, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.1432, device='cuda:0', grad_fn=<NllLossBackward0>) 1800 10
# Epoch 23, Loss: 1132.0469970703125
# tensor(38.1238, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.8847, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.1200, device='cuda:0', grad_fn=<NllLossBackward0>) 1820 10
# Epoch 24, Loss: 1139.9649658203125
# tensor(34.9129, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.8615, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.1001, device='cuda:0', grad_fn=<NllLossBackward0>) 1830 10
# Epoch 25, Loss: 1142.381103515625
# tensor(32.0822, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.8542, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.0929, device='cuda:0', grad_fn=<NllLossBackward0>) 1840 10
# Epoch 26, Loss: 1145.2506103515625
# tensor(29.5659, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.8497, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.0875, device='cuda:0', grad_fn=<NllLossBackward0>) 1840 0.0
# Epoch 27, Loss: 1140.471923828125
# tensor(27.3095, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.8142, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.0590, device='cuda:0', grad_fn=<NllLossBackward0>) 1860 0.0
# Epoch 28, Loss: 1149.9110107421875
# tensor(25.2765, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.8144, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.0582, device='cuda:0', grad_fn=<NllLossBackward0>) 1860 0.0
# Epoch 29, Loss: 1147.6748046875
# tensor(23.4420, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.7925, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.0409, device='cuda:0', grad_fn=<NllLossBackward0>) 1870 0.0
# Epoch 30, Loss: 1151.6083984375
# tensor(21.7881, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.7748, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.0259, device='cuda:0', grad_fn=<NllLossBackward0>) 1880 0.0
# Epoch 31, Loss: 1155.7493896484375
# tensor(20.3046, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.7658, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.0197, device='cuda:0', grad_fn=<NllLossBackward0>) 1880 0.0
# Epoch 32, Loss: 1154.09814453125
# tensor(18.9825, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.7602, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.0152, device='cuda:0', grad_fn=<NllLossBackward0>) 1890 0.0
# Epoch 33, Loss: 1158.6312255859375
# tensor(17.8124, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.7522, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(1.0085, device='cuda:0', grad_fn=<NllLossBackward0>) 1890 0.0
# Epoch 34, Loss: 1157.326171875
# tensor(16.7861, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.7389, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9985, device='cuda:0', grad_fn=<NllLossBackward0>) 1890 0.0
# Epoch 35, Loss: 1156.16796875
# tensor(15.8907, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.7433, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9987, device='cuda:0', grad_fn=<NllLossBackward0>) 1890 0.0
# Epoch 36, Loss: 1155.1915283203125
# tensor(15.1109, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.7290, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9917, device='cuda:0', grad_fn=<NllLossBackward0>) 1900 0.0
# Epoch 37, Loss: 1160.3037109375
# tensor(14.4294, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.7378, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9938, device='cuda:0', grad_fn=<NllLossBackward0>) 1900 0.0
# Epoch 38, Loss: 1159.57177734375
# tensor(13.8276, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.7193, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9833, device='cuda:0', grad_fn=<NllLossBackward0>) 1900 0.0
# Epoch 39, Loss: 1158.8704833984375
# tensor(13.2901, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.7242, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9829, device='cuda:0', grad_fn=<NllLossBackward0>) 1900 0.0
# Epoch 40, Loss: 1158.288330078125
# tensor(12.8030, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.7264, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9837, device='cuda:0', grad_fn=<NllLossBackward0>) 1900 0.0
# Epoch 41, Loss: 1157.7569580078125
# tensor(12.3557, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.7125, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9768, device='cuda:0', grad_fn=<NllLossBackward0>) 1900 0.0
# Epoch 42, Loss: 1157.2357177734375
# tensor(11.9397, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.7035, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9737, device='cuda:0', grad_fn=<NllLossBackward0>) 1900 0.0
# Epoch 43, Loss: 1156.759765625
# tensor(11.5499, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6985, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9698, device='cuda:0', grad_fn=<NllLossBackward0>) 1910 0.0
# Epoch 44, Loss: 1162.3199462890625
# tensor(11.1825, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6862, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9643, device='cuda:0', grad_fn=<NllLossBackward0>) 1910 0.0
# Epoch 45, Loss: 1161.8902587890625
# tensor(10.8348, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6952, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9680, device='cuda:0', grad_fn=<NllLossBackward0>) 1910 0.0
# Epoch 46, Loss: 1161.5263671875
# tensor(10.5056, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6794, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9617, device='cuda:0', grad_fn=<NllLossBackward0>) 1910 0.0
# Epoch 47, Loss: 1161.131591796875
# tensor(10.1964, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6913, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9637, device='cuda:0', grad_fn=<NllLossBackward0>) 1910 0.0
# Epoch 48, Loss: 1160.8150634765625
# tensor(9.9066, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6860, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9631, device='cuda:0', grad_fn=<NllLossBackward0>) 1920 0.0
# Epoch 49, Loss: 1166.48583984375
# tensor(9.6351, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6772, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9600, device='cuda:0', grad_fn=<NllLossBackward0>) 1920 0.0
# Epoch 50, Loss: 1166.1693115234375
# tensor(9.3808, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6744, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9582, device='cuda:0', grad_fn=<NllLossBackward0>) 1920 0.0
# Epoch 51, Loss: 1165.883544921875
# tensor(9.1423, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6751, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9582, device='cuda:0', grad_fn=<NllLossBackward0>) 1920 0.0
# Epoch 52, Loss: 1165.6224365234375
# tensor(8.9184, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6716, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9568, device='cuda:0', grad_fn=<NllLossBackward0>) 1920 0.0
# Epoch 53, Loss: 1165.3690185546875
# tensor(8.7080, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6642, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9543, device='cuda:0', grad_fn=<NllLossBackward0>) 1920 0.0
# Epoch 54, Loss: 1165.1226806640625
# tensor(8.5101, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6629, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9537, device='cuda:0', grad_fn=<NllLossBackward0>) 1920 0.0
# Epoch 55, Loss: 1164.9019775390625
# tensor(8.3230, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6613, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9528, device='cuda:0', grad_fn=<NllLossBackward0>) 1920 0.0
# Epoch 56, Loss: 1164.69287109375
# tensor(8.1464, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6665, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9541, device='cuda:0', grad_fn=<NllLossBackward0>) 1920 0.0
# Epoch 57, Loss: 1164.509033203125
# tensor(7.9788, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6617, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9524, device='cuda:0', grad_fn=<NllLossBackward0>) 1920 0.0
# Epoch 58, Loss: 1164.3148193359375
# tensor(7.8194, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6648, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9537, device='cuda:0', grad_fn=<NllLossBackward0>) 1920 0.0
# Epoch 59, Loss: 1164.14599609375
# tensor(7.6673, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6550, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9497, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 60, Loss: 1169.9583740234375
# tensor(7.5216, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6631, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9510, device='cuda:0', grad_fn=<NllLossBackward0>) 1920 0.0
# Epoch 61, Loss: 1163.81396484375
# tensor(7.3817, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6593, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9499, device='cuda:0', grad_fn=<NllLossBackward0>) 1920 0.0
# Epoch 62, Loss: 1163.652587890625
# tensor(7.2476, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6622, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9511, device='cuda:0', grad_fn=<NllLossBackward0>) 1920 0.0
# Epoch 63, Loss: 1163.5108642578125
# tensor(7.1187, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6598, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9504, device='cuda:0', grad_fn=<NllLossBackward0>) 1920 0.0
# Epoch 64, Loss: 1163.3643798828125
# tensor(6.9951, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6491, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9478, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 65, Loss: 1169.2071533203125
# tensor(6.8767, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6536, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9481, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 66, Loss: 1169.0855712890625
# tensor(6.7634, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6544, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9482, device='cuda:0', grad_fn=<NllLossBackward0>) 1920 0.0
# Epoch 67, Loss: 1162.9625244140625
# tensor(6.6544, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6471, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9460, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 68, Loss: 1168.8277587890625
# tensor(6.5494, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6505, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9472, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 69, Loss: 1168.7191162109375
# tensor(6.4485, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6460, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9457, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 70, Loss: 1168.59912109375
# tensor(6.3513, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6551, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9484, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 71, Loss: 1168.510498046875
# tensor(6.2577, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6512, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9469, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 72, Loss: 1168.3994140625
# tensor(6.1674, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6509, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9467, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 73, Loss: 1168.299560546875
# tensor(6.0801, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6417, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9439, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 74, Loss: 1168.1849365234375
# tensor(5.9957, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6426, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9436, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 75, Loss: 1168.09375
# tensor(5.9140, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6445, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9444, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 76, Loss: 1168.0076904296875
# tensor(5.8348, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6455, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9448, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 77, Loss: 1167.922607421875
# tensor(5.7580, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6425, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9445, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 78, Loss: 1167.832275390625
# tensor(5.6836, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6363, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9420, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 79, Loss: 1167.7376708984375
# tensor(5.6113, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6344, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9411, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 80, Loss: 1167.654296875
# tensor(5.5410, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6371, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9420, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 81, Loss: 1167.582275390625
# tensor(5.4724, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6382, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9417, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 82, Loss: 1167.5089111328125
# tensor(5.4051, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6349, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9411, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 83, Loss: 1167.4283447265625
# tensor(5.3397, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6375, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9418, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 84, Loss: 1167.3616943359375
# tensor(5.2760, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6345, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9412, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 85, Loss: 1167.28564453125
# tensor(5.2141, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6325, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9399, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 86, Loss: 1167.2132568359375
# tensor(5.1536, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6326, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9399, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 87, Loss: 1167.14697265625
# tensor(5.0946, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6311, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9393, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 88, Loss: 1167.078857421875
# tensor(5.0368, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6329, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9400, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 89, Loss: 1167.01904296875
# tensor(4.9804, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6316, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9393, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 90, Loss: 1166.9542236328125
# tensor(4.9251, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6336, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9401, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 91, Loss: 1166.8974609375
# tensor(4.8711, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6308, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9390, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 92, Loss: 1166.8323974609375
# tensor(4.8182, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6299, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9386, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 93, Loss: 1166.772216796875
# tensor(4.7664, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6331, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9397, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 94, Loss: 1166.721923828125
# tensor(4.7157, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6267, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9375, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 95, Loss: 1166.6529541015625
# tensor(4.6658, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6314, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9390, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 96, Loss: 1166.6077880859375
# tensor(4.6168, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6303, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9388, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 97, Loss: 1166.551513671875
# tensor(4.5686, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6280, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9379, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 98, Loss: 1166.4937744140625
# tensor(4.5212, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6268, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9371, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 99, Loss: 1166.4390869140625
# tensor(4.4748, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6251, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9368, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 100, Loss: 1166.3846435546875
# tensor(4.4292, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6259, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9366, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 101, Loss: 1166.3359375
# tensor(4.3845, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6254, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9363, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 102, Loss: 1166.2857666015625
# tensor(4.3406, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6246, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9360, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 103, Loss: 1166.2357177734375
# tensor(4.2974, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6267, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9373, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 104, Loss: 1166.1927490234375
# tensor(4.2550, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6270, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9361, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 105, Loss: 1166.146240234375
# tensor(4.2134, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6271, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9372, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 106, Loss: 1166.10107421875
# tensor(4.1725, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6263, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9367, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 107, Loss: 1166.054443359375
# tensor(4.1323, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6236, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9352, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 108, Loss: 1166.0045166015625
# tensor(4.0929, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6263, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9366, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 109, Loss: 1165.966796875
# tensor(4.0542, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6228, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9348, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 110, Loss: 1165.9168701171875
# tensor(4.0162, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6244, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9361, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 111, Loss: 1165.878662109375
# tensor(3.9788, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6223, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9356, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 112, Loss: 1165.8333740234375
# tensor(3.9420, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6227, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9350, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 113, Loss: 1165.79345703125
# tensor(3.9058, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6252, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9359, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 114, Loss: 1165.758544921875
# tensor(3.8702, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6227, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9345, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 115, Loss: 1165.7142333984375
# tensor(3.8352, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6212, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9340, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 116, Loss: 1171.6724853515625
# tensor(3.8007, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6223, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9345, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 117, Loss: 1165.636962890625
# tensor(3.7668, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6245, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9353, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 118, Loss: 1165.604248046875
# tensor(3.7334, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6215, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9337, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 119, Loss: 1165.56103515625
# tensor(3.7005, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6213, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9341, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 120, Loss: 1165.5247802734375
# tensor(3.6681, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6191, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9330, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 121, Loss: 1165.484375
# tensor(3.6362, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6203, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9335, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 122, Loss: 1165.4517822265625
# tensor(3.6047, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6201, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9333, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 123, Loss: 1165.416748046875
# tensor(3.5738, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6195, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9332, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 124, Loss: 1165.381591796875
# tensor(3.5432, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6162, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9323, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 125, Loss: 1165.3411865234375
# tensor(3.5131, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6215, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9341, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 126, Loss: 1165.31884765625
# tensor(3.4835, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6196, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9335, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 127, Loss: 1165.2825927734375
# tensor(3.4543, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6169, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9323, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 128, Loss: 1165.2447509765625
# tensor(3.4254, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6151, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9321, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 129, Loss: 1165.20947265625
# tensor(3.3970, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6182, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9320, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 130, Loss: 1165.1842041015625
# tensor(3.3690, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6157, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9318, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 131, Loss: 1165.1483154296875
# tensor(3.3414, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6160, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9317, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 132, Loss: 1165.11865234375
# tensor(3.3141, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6168, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9317, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 133, Loss: 1165.0902099609375
# tensor(3.2873, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6186, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9325, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 134, Loss: 1165.064453125
# tensor(3.2608, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6160, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9312, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 135, Loss: 1165.0296630859375
# tensor(3.2346, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6155, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9313, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 136, Loss: 1165.0001220703125
# tensor(3.2087, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6142, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9311, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 137, Loss: 1164.968994140625
# tensor(3.1833, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6167, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9315, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 138, Loss: 1164.946044921875
# tensor(3.1581, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6166, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9312, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 139, Loss: 1164.91796875
# tensor(3.1333, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6150, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9310, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 140, Loss: 1170.887451171875
# tensor(3.1088, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6152, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9303, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 141, Loss: 1170.8607177734375
# tensor(3.0846, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6118, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9300, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 142, Loss: 1170.8275146484375
# tensor(3.0607, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6156, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9315, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 143, Loss: 1164.80908203125
# tensor(3.0371, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6137, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9311, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 144, Loss: 1164.779296875
# tensor(3.0138, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6151, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9308, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 145, Loss: 1164.756103515625
# tensor(2.9908, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6123, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9295, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 146, Loss: 1164.72509765625
# tensor(2.9680, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6174, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9313, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 147, Loss: 1164.7103271484375
# tensor(2.9456, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6129, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9299, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 148, Loss: 1170.6766357421875
# tensor(2.9234, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6166, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9309, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 149, Loss: 1170.65966796875
# tensor(2.9015, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6149, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9304, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 150, Loss: 1170.6322021484375
# tensor(2.8797, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6155, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9302, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 151, Loss: 1170.6092529296875
# tensor(2.8583, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6126, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9299, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 152, Loss: 1170.580078125
# tensor(2.8371, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6121, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9301, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 153, Loss: 1170.5557861328125
# tensor(2.8162, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6137, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9296, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 154, Loss: 1170.53564453125
# tensor(2.7954, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6107, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9298, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 155, Loss: 1170.50732421875
# tensor(2.7749, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6110, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9290, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 156, Loss: 1170.4849853515625
# tensor(2.7546, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6137, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9293, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 157, Loss: 1164.4678955078125
# tensor(2.7346, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6104, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9290, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 158, Loss: 1164.4395751953125
# tensor(2.7148, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6103, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9287, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 159, Loss: 1164.417236328125
# tensor(2.6952, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6129, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9289, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 160, Loss: 1164.40087890625
# tensor(2.6758, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6110, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9287, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 161, Loss: 1170.375732421875
# tensor(2.6566, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6094, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9281, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 162, Loss: 1170.3514404296875
# tensor(2.6376, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6094, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9284, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 163, Loss: 1170.33056640625
# tensor(2.6189, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6086, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9278, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 164, Loss: 1170.308349609375
# tensor(2.6003, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6107, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9287, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 165, Loss: 1170.292236328125
# tensor(2.5819, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6083, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9278, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 166, Loss: 1170.26708984375
# tensor(2.5638, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6069, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9275, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 167, Loss: 1170.2442626953125
# tensor(2.5458, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6084, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9286, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 168, Loss: 1170.227783203125
# tensor(2.5279, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6078, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9275, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 169, Loss: 1170.20654296875
# tensor(2.5101, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6053, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9271, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 170, Loss: 1170.18212890625
# tensor(2.4925, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6080, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9284, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 171, Loss: 1170.1683349609375
# tensor(2.4752, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6068, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9273, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 172, Loss: 1170.1466064453125
# tensor(2.4580, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6078, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9279, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 173, Loss: 1170.1297607421875
# tensor(2.4410, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6042, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9268, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 174, Loss: 1170.103759765625
# tensor(2.4242, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6066, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9279, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 175, Loss: 1170.0902099609375
# tensor(2.4076, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6054, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9270, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 176, Loss: 1170.0693359375
# tensor(2.3911, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6092, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9278, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 177, Loss: 1170.0589599609375
# tensor(2.3749, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6072, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9279, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 178, Loss: 1170.0372314453125
# tensor(2.3589, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6084, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9279, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 179, Loss: 1170.0218505859375
# tensor(2.3430, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6099, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9282, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 180, Loss: 1170.0074462890625
# tensor(2.3272, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6054, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9270, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 181, Loss: 1169.98095703125
# tensor(2.3117, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6058, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9273, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 182, Loss: 1169.9647216796875
# tensor(2.2963, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6068, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9276, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 183, Loss: 1169.9498291015625
# tensor(2.2810, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6064, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9276, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 184, Loss: 1169.932373046875
# tensor(2.2659, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6053, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9274, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 185, Loss: 1169.9134521484375
# tensor(2.2510, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6044, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9269, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 186, Loss: 1169.895263671875
# tensor(2.2363, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6063, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9268, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 187, Loss: 1169.882568359375
# tensor(2.2217, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6066, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9266, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 188, Loss: 1169.8670654296875
# tensor(2.2073, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6052, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9275, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 189, Loss: 1163.8489990234375
# tensor(2.1930, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6052, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9265, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 190, Loss: 1169.832763671875
# tensor(2.1788, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6072, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9275, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 191, Loss: 1163.8212890625
# tensor(2.1648, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6084, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9275, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 192, Loss: 1163.8082275390625
# tensor(2.1509, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6021, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9261, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 193, Loss: 1169.7803955078125
# tensor(2.1371, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6060, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9273, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 194, Loss: 1169.7730712890625
# tensor(2.1235, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6049, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9262, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 195, Loss: 1169.755615234375
# tensor(2.1100, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6059, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9268, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 196, Loss: 1169.742919921875
# tensor(2.0967, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6003, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9257, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 197, Loss: 1169.7171630859375
# tensor(2.0834, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6054, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9263, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 198, Loss: 1169.7125244140625
# tensor(2.0703, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6030, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9260, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 199, Loss: 1169.6934814453125
# tensor(2.0573, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6034, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9267, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 200, Loss: 1169.68017578125
# tensor(2.0445, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6031, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9262, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 201, Loss: 1169.665283203125
# tensor(2.0318, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6033, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9266, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 202, Loss: 1169.6517333984375
# tensor(2.0192, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6033, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9261, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 203, Loss: 1169.637939453125
# tensor(2.0067, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6013, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9256, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 204, Loss: 1169.6201171875
# tensor(1.9944, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6002, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9255, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 205, Loss: 1169.6044921875
# tensor(1.9822, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6032, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9262, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 206, Loss: 1169.5970458984375
# tensor(1.9701, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6040, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9267, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 207, Loss: 1169.5853271484375
# tensor(1.9581, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6021, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9263, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 208, Loss: 1169.568359375
# tensor(1.9462, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6037, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9261, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 209, Loss: 1169.5582275390625
# tensor(1.9344, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6060, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9267, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 210, Loss: 1169.5498046875
# tensor(1.9228, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6009, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9258, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 211, Loss: 1169.527099609375
# tensor(1.9113, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6024, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9258, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 212, Loss: 1169.5172119140625
# tensor(1.8998, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6056, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9266, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 213, Loss: 1169.5111083984375
# tensor(1.8885, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5987, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9253, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 214, Loss: 1169.48486328125
# tensor(1.8772, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6025, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9260, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 215, Loss: 1169.4801025390625
# tensor(1.8660, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6020, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9255, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 216, Loss: 1169.4666748046875
# tensor(1.8550, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.6040, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9263, device='cuda:0', grad_fn=<NllLossBackward0>) 1940 0.0
# Epoch 217, Loss: 1169.458740234375
# ...
# Epoch 628, Loss: 1161.7437744140625
# tensor(0.3473, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5746, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 629, Loss: 1161.7435302734375
# tensor(0.3462, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5741, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 630, Loss: 1161.741455078125
# tensor(0.3451, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5740, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 631, Loss: 1161.7398681640625
# tensor(0.3440, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5748, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 632, Loss: 1161.740234375
# tensor(0.3430, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5740, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 633, Loss: 1161.737548828125
# tensor(0.3419, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5756, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 634, Loss: 1161.739501953125
# tensor(0.3408, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5744, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 635, Loss: 1161.7359619140625
# tensor(0.3397, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5743, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 636, Loss: 1161.734619140625
# tensor(0.3387, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5741, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 637, Loss: 1161.7330322265625
# tensor(0.3376, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5746, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 638, Loss: 1161.73291015625
# tensor(0.3366, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5745, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 639, Loss: 1161.7314453125
# tensor(0.3355, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5748, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 640, Loss: 1161.7308349609375
# tensor(0.3344, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5742, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 641, Loss: 1161.728515625
# tensor(0.3334, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5739, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 642, Loss: 1161.726806640625
# tensor(0.3323, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5738, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 643, Loss: 1161.7255859375
# tensor(0.3313, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5744, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 644, Loss: 1161.7254638671875
# tensor(0.3302, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5754, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 645, Loss: 1161.726318359375
# tensor(0.3292, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5743, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 646, Loss: 1161.7230224609375
# tensor(0.3282, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5740, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 647, Loss: 1161.7213134765625
# tensor(0.3271, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5742, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 648, Loss: 1161.720458984375
# tensor(0.3261, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5745, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 649, Loss: 1161.7198486328125
# tensor(0.3251, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5741, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 650, Loss: 1161.718017578125
# tensor(0.3240, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5737, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 651, Loss: 1161.7161865234375
# tensor(0.3230, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5739, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 652, Loss: 1161.7154541015625
# tensor(0.3220, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5742, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 653, Loss: 1161.7149658203125
# tensor(0.3210, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5737, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 654, Loss: 1161.712890625
# tensor(0.3200, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5740, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 655, Loss: 1161.71240234375
# tensor(0.3190, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5737, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 656, Loss: 1161.710693359375
# tensor(0.3180, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5736, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 657, Loss: 1161.7093505859375
# tensor(0.3170, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5742, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 658, Loss: 1161.709228515625
# tensor(0.3160, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5741, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 659, Loss: 1161.7081298828125
# tensor(0.3150, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5736, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 660, Loss: 1161.7061767578125
# tensor(0.3140, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5737, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 661, Loss: 1161.7052001953125
# tensor(0.3130, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5739, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 662, Loss: 1161.7044677734375
# tensor(0.3121, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5736, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 663, Loss: 1161.7030029296875
# tensor(0.3111, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5740, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 664, Loss: 1161.7025146484375
# tensor(0.3101, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5741, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 665, Loss: 1161.7015380859375
# tensor(0.3092, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5739, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 666, Loss: 1161.7003173828125
# tensor(0.3082, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5740, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 667, Loss: 1161.6993408203125
# tensor(0.3073, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5750, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 668, Loss: 1161.7003173828125
# tensor(0.3063, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5739, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 669, Loss: 1161.697021484375
# tensor(0.3053, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5737, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 670, Loss: 1161.695556640625
# tensor(0.3044, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5744, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 671, Loss: 1161.6959228515625
# tensor(0.3034, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5737, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 672, Loss: 1161.693603515625
# tensor(0.3025, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5737, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 673, Loss: 1161.6925048828125
# tensor(0.3015, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5737, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 674, Loss: 1161.6915283203125
# tensor(0.3006, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5739, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 675, Loss: 1161.6907958984375
# tensor(0.2997, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5740, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 676, Loss: 1161.68994140625
# tensor(0.2988, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5751, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 677, Loss: 1161.691162109375
# tensor(0.2979, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5751, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 678, Loss: 1161.6900634765625
# tensor(0.2969, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5739, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 679, Loss: 1161.6866455078125
# tensor(0.2960, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5743, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 680, Loss: 1161.6865234375
# tensor(0.2951, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5736, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 681, Loss: 1161.6842041015625
# tensor(0.2942, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5749, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 682, Loss: 1161.6856689453125
# tensor(0.2933, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5737, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 683, Loss: 1161.6824951171875
# tensor(0.2924, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5735, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 684, Loss: 1161.6810302734375
# tensor(0.2915, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5742, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 685, Loss: 1161.681396484375
# tensor(0.2906, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5734, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 686, Loss: 1161.6788330078125
# tensor(0.2898, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5741, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 687, Loss: 1161.6793212890625
# tensor(0.2889, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5747, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 688, Loss: 1161.679443359375
# tensor(0.2880, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5737, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 689, Loss: 1161.676513671875
# tensor(0.2871, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5737, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 690, Loss: 1161.6754150390625
# tensor(0.2862, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5742, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 691, Loss: 1161.6754150390625
# tensor(0.2853, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5736, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 692, Loss: 1161.6734619140625
# tensor(0.2845, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5741, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 693, Loss: 1161.6734619140625
# tensor(0.2836, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5741, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 694, Loss: 1161.6724853515625
# tensor(0.2827, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5737, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 695, Loss: 1161.6707763671875
# tensor(0.2819, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5736, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 696, Loss: 1161.669677734375
# tensor(0.2810, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5747, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 697, Loss: 1161.6707763671875
# tensor(0.2802, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5736, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 698, Loss: 1161.667724609375
# tensor(0.2793, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5736, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 699, Loss: 1161.666748046875
# tensor(0.2785, device='cuda:0', grad_fn=<MulBackward0>) tensor(1.5735, device='cuda:0', grad_fn=<NllLossBackward0>) tensor(0.9243, device='cuda:0', grad_fn=<NllLossBackward0>) 1930 0.0
# Epoch 700, Loss: 1161.665771484375

# %% [markdown]
# ### Use if Sampling with Conditioning

# %%
def sample_latent_space(mu, logvar, num_samples=1):
    std = torch.exp(0.5 * logvar)
    eps = torch.randn_like(std)  # Random noise
    return mu + eps * std

# %% [markdown]
# ### Use if Sampling without Conditioning

# %%
def sample_z(latent_dim, num_samples=1, device="cuda"):
    return torch.randn(num_samples, latent_dim).to(device)

# %%
def generate_graph(model, num_samples=1, latent_dim=LATENT_DIM+252, device="cuda"):
    z = sample_z(latent_dim, num_samples, device)

    with torch.no_grad():
        A_pred, features_pred = model.decode(z)

    return A_pred, features_pred

# %%
atomic_mapping = {0: 6, 1: 7, 2:8, 3:9, 4:14, 5:15, 6:16, 7:17, 8:35, 9:53}

# %%
def get_bond_type(bond_type):
    bond_type = torch.argmax(bond_type, dim=-1).item()
    if bond_type == 0:
        return rdchem.BondType.SINGLE
    elif bond_type == 1:
        return rdchem.BondType.DOUBLE
    elif bond_type == 2:
        return rdchem.BondType.TRIPLE
    elif bond_type == 3:
        return rdchem.BondType.AROMATIC
    else:
        return None

# %%
def is_valid(data):
    node_features = data.x
    edge_index = data.edge_index
    edge_attr = data.edge_attr

    atomic_numbers = []
    for num in node_features.argmax(dim=-1).tolist():
        atomic_numbers.append(atomic_mapping[num])

    mol = Chem.RWMol()
    for atomic_num in atomic_numbers:
        atom = Chem.Atom(atomic_num)
        mol.AddAtom(atom)

    for i, (bond_start, bond_end) in enumerate(edge_index.t().tolist()):
        bond_val = edge_attr[i]
        bond_type = get_bond_type(bond_val)
        mol.AddBond(bond_start, bond_end, bond_type)

    validity = Chem.SanitizeMol(mol, catchErrors=True)

    return validity == Chem.SanitizeFlags.SANITIZE_NONE

# %%
unique_molecules = set()
def is_unique(data):
    node_features = data.x
    edge_index = data.edge_index
    edge_attr = data.edge_attr

    atomic_numbers = []
    for num in node_features.argmax(dim=-1).tolist():
        atomic_numbers.append(atomic_mapping[num])

    mol = Chem.RWMol()
    for atomic_num in atomic_numbers:
        atom = Chem.Atom(atomic_num)
        mol.AddAtom(atom)

    for i, (bond_start, bond_end) in enumerate(edge_index.t().tolist()):
        bond_val = edge_attr[i]
        bond_type = get_bond_type(bond_val)
        mol.AddBond(bond_start, bond_end, bond_type)

    canonical_smiles = Chem.MolToSmiles(mol, isomericSmiles=True)
    if canonical_smiles not in unique_molecules:
        unique_molecules.add(canonical_smiles)
        return True
    else:
        return False

# %%
# torch.save(model.state_dict(), "models/vae_model_conditioning.pt")

# %%
print(model)
# Out:
# RGCN_VGAE(
#   (rgcn1): RGCNConv(10, 512, num_relations=4)
#   (rgcn2): RGCNConv(512, 512, num_relations=4)
#   (rgcn3): RGCNConv(512, 512, num_relations=4)
#   (fc_mu): Linear(in_features=512, out_features=512, bias=True)
#   (fc_logvar): Linear(in_features=512, out_features=512, bias=True)
#   (adj_decoder): Sequential(
#     (0): Linear(in_features=764, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=512, out_features=19845, bias=True)
#   )
#   (feature_decoder): Linear(in_features=764, out_features=693, bias=True)
#   (cond_pool1): AdaptiveAvgPool1d(output_size=9901)
#   (cond_linear1): Linear(in_features=9901, out_features=3808, bias=True)
# )

# %%
import re
def expand_formula(formula):
    pattern = r'([A-Z][a-z]?)(\d*)'
    expanded_list = []
    total_atoms = 0

    matches = re.findall(pattern, formula)
    for element, count in matches:
        count = int(count) if count else 1
        expanded_list.extend([element] * count)
        total_atoms += count

    return expanded_list, total_atoms

# %%
def get_molecule(datapoint):
    _, formula = to_chemula(datapoint)
    l, total_atoms = expand_formula(formula)

    # #atomic_numbers = datapoint.x.argmax(dim=1).tolist()
    # atomic_numbers_unmapped = datapoint.x.argmax(dim=1).tolist()
    # atomic_numbers = []
    # for at in atomic_numbers_unmapped:
    #     atomic_numbers.append(atomic_mapping[at])
    # positions = datapoint.positions.numpy()
    positions = np.random.rand(len(l), 3) * 10

    # molecule = Atoms(numbers=atomic_numbers, positions=positions)
    molecule = Atoms(symbols=l, positions=positions)

    return molecule, total_atoms

@contextmanager
def suppress_stdout():
    with open(os.devnull, "w") as devnull:
        old_stdout = sys.stdout
        sys.stdout = devnull
        try:
            yield
        finally:
            sys.stdout = old_stdout

def get_dft(datapoint, De=0.242, re=0.74, alpha=1.5):
    molecule, _ = get_molecule(datapoint)
    print('Molecule:', molecule)
    dft_calculator = MorsePotential(De=De, r0=re, alpha=alpha)
    molecule.set_calculator(dft_calculator)
    # energy = molecule.get_potential_energy()
    with suppress_stdout():
        opt = QuasiNewton(molecule)
        opt.run(fmax=0.02)
    optimized_energy = molecule.get_potential_energy()
    return optimized_energy

# energy = get_dft(datapoint)

# print(f'DFT Energy: {energy} eV')

# %%
def to_chemula(data):
    node_features = data.x
    edge_index = data.edge_index
    edge_attr = data.edge_attr

    atomic_numbers = []
    for num in node_features.argmax(dim=-1).tolist():
        atomic_numbers.append(atomic_mapping[num])

    mol = Chem.RWMol()
    for atomic_num in atomic_numbers:
        atom = Chem.Atom(atomic_num)
        mol.AddAtom(atom)

    for i, (bond_start, bond_end) in enumerate(edge_index.t().tolist()):
        bond_val = edge_attr[i]
        bond_type = get_bond_type(bond_val)
        mol.AddBond(bond_start, bond_end, bond_type)
    for atom in mol.GetAtoms():
        atom.UpdatePropertyCache(strict=False)
    # Chem.SanitizeMol(mol)
    return mol, CalcMolFormula(mol)

# %%
Chem.MolFromSmiles('NN')

# %%
class GraphEncoder(nn.Module):
    def __init__(self, input_dim, num_relations):
        super(GraphEncoder, self).__init__()
        self.rgcnconv1 = RGCNConv(input_dim, 512, num_relations=num_relations)
        self.rgcnconv2 = RGCNConv(512, 256, num_relations=num_relations)
        self.rgcnconv3 = RGCNConv(256, 128, num_relations=num_relations)

    def forward(self, x, edge_index, edge_attr):
        x = self.rgcnconv1(x, edge_index, edge_attr)
        x = nn.ReLU()(x)
        x = self.rgcnconv2(x, edge_index, edge_attr)
        x = nn.ReLU()(x)
        x = self.rgcnconv3(x, edge_index, edge_attr)
        x = nn.ReLU()(x)
        return x

class BioClassifier(nn.Module):
    def __init__(self, input_dim, num_heads):
        super(BioClassifier, self).__init__()

        self.encoder = GraphEncoder(input_dim, num_heads)
        self.fc1 = nn.Linear(128, 64)
        self.bn1 = nn.BatchNorm1d(64)
        self.fc2 = nn.Linear(64, 1)
        self.dropout = nn.Dropout(0.4)

    def forward(self, data):
        x, edge_index, edge_attr = data.x, data.edge_index, data.edge_attr
        x = x.float()

        x = self.encoder(x, edge_index, edge_attr)
        x = global_add_pool(x, data.batch)
        x = self.dropout(x)
        x = self.fc1(x)
        x = nn.ReLU()(x)
        x = self.bn1(x)
        x = self.dropout(x)
        x = self.fc2(x)
        x = torch.sigmoid(x)
        return x.squeeze(dim=1)

# %%
model_bio_eval = BioClassifier(10, 4).to(device)

state_dict = torch.load('models/rcgn_model_7428.pt')
model_bio_eval.load_state_dict(state_dict)

model_bio_eval.eval()
def get_model_prediction(datapoint):
    pred = model_bio_eval(datapoint)
    return pred.item()

# %%
# print(datapoint)
# datapoint.edge_attr = torch.argmax(datapoint.edge_attr, dim=1).to(device)
# datapoint.edge_index = datapoint.edge_index.to(device)
# datapoint.x = datapoint.x.to(device)

# %%
# print(datapoint.edge_attr)

# %%
# dft = get_dft(datapoint)
# y = get_model_prediction(datapoint) * 100

# print(f'DFT (remember negative is good): {dft}')
# print(f'Chance of Biodgradability: {y:.2f}%')

# %% [markdown]
# ## Generating from Our Latent Space

# %%
# generated_list_ours = []
# list_len = 100
# for i in tqdm(range(list_len)):
#     bonds_pred_ours, atoms_pred_ours = generate_graph_ours(model)
#     datapoints = process_graph_data_to_data_objects(bonds_pred_ours, atoms_pred_ours)
#     datapoint = datapoints[0]
#     validity = is_valid(datapoint)
#     mol, formula = to_chemula(datapoint)
#     ase_atoms = get_molecule(datapoint)
#     energy = get_dft(datapoint)
#     datapoint.edge_attr = torch.argmax(datapoint.edge_attr, dim=1).to(device)
#     datapoint.edge_index = datapoint.edge_index.to(device)
#     datapoint.x = datapoint.x.to(device)
#     y = get_model_prediction(datapoint) * 100
#     generated_list_ours.append({"bond_preds": bonds_pred, "atom_preds": atoms_pred, "is_valid": validity, "ase_atom": ase_atoms, "mol": mol, "formula": formula, "energy":energy, "bio":y})

# %% [markdown]
# ## Generating from Rand Normal Distribution

# %%
generated_list = []

num_errors = 0

while len(generated_list) < 100:
    try:
        bonds_pred, atoms_pred = generate_graph(model)
        datapoints = process_graph_data_to_data_objects(bonds_pred, atoms_pred)
        datapoint = datapoints[0]
        validity = is_valid(datapoint)
        mol, formula = to_chemula(datapoint)
        ase_atoms, total_atoms = get_molecule(datapoint)
        energy = get_dft(datapoint)
        datapoint.edge_attr = torch.argmax(datapoint.edge_attr, dim=1).to(device)
        datapoint.edge_index = datapoint.edge_index.to(device)
        datapoint.x = datapoint.x.to(device)
        y = get_model_prediction(datapoint) * 100
        generated_list.append({"atom_count": total_atoms, "is_valid": validity, "ase_atom": ase_atoms, "mol": mol, "formula": formula, "energy":energy, "bio":y})
    except Exception as e:
        num_errors += 1
        print("ERROR!!!!!!")
        # print(e)
print(num_errors)
# Out:
# [03:41:35] Explicit valence for atom # 4 Cl, 2, is greater than permitted
# [03:41:35] non-ring atom 4 marked aromatic
# Molecule: Atoms(symbols='C2H11BrCl2NSSi', pbc=False)
# Molecule: Atoms(symbols='C3H11BrCl2INOP2S', pbc=False)
# [03:41:36] Explicit valence for atom # 5 Br, 2, is greater than permitted
# Molecule: Atoms(symbols='CH9BrClF2IN2O2PS', pbc=False)
# [03:41:36] non-ring atom 6 marked aromatic
# [03:41:36] Explicit valence for atom # 6 Br, 2, is greater than permitted
# Molecule: Atoms(symbols='H13Cl2N3P2S2Si2', pbc=False)
# Molecule: Atoms(symbols='H12BrF2IN2O3Si3', pbc=False)
# Molecule: Atoms(symbols='CH8BrIN2OS2', pbc=False)
# Molecule: Atoms(symbols='C2H5Br4Cl3F2I2N2OPS', pbc=False)
# [03:41:37] Explicit valence for atom # 1 Br, 2, is greater than permitted
# [03:41:37] Explicit valence for atom # 4 F, 2, is greater than permitted
# Molecule: Atoms(symbols='C4H20FNO2PSi', pbc=False)
# Molecule: Atoms(symbols='C2H9BrCl2F4NPS2', pbc=False)
# Molecule: Atoms(symbols='CH9ClF3OP3', pbc=False)
# Molecule: Atoms(symbols='H7N2O3PSi', pbc=False)
# Molecule: Atoms(symbols='C3H13Br2N2P', pbc=False)
# Molecule: Atoms(symbols='C3H8OS', pbc=False)
# Molecule: Atoms(symbols='C4H15Br2Cl2N2S2', pbc=False)
# [03:41:38] Explicit valence for atom # 8 Cl, 2, is greater than permitted
# [03:41:38] Explicit valence for atom # 1 Cl, 2, is greater than permitted
# [03:41:38] Explicit valence for atom # 3 Br, 2, is greater than permitted
# Molecule: Atoms(symbols='C2H9BrCl4S3', pbc=False)
# Molecule: Atoms(symbols='C2H11BrN3S', pbc=False)
# [03:41:38] Explicit valence for atom # 2 F, 2, is greater than permitted
# Molecule: Atoms(symbols='C2H16F2NO2PS3Si3', pbc=False)
# [03:41:39] Explicit valence for atom # 2 F, 2, is greater than permitted
# [03:41:39] Explicit valence for atom # 2 Br, 2, is greater than permitted
# Molecule: Atoms(symbols='H10BrCl2F2NO5P2S', pbc=False)
# Molecule: Atoms(symbols='C2H13Br2Cl2I3NPS2Si', pbc=False)
# [03:41:39] Explicit valence for atom # 3 F, 2, is greater than permitted
# Molecule: Atoms(symbols='C3H13F4IO2PS', pbc=False)
# [03:41:40] Explicit valence for atom # 6 Br, 2, is greater than permitted
# Molecule: Atoms(symbols='CH16Br2F2IN2OP3S2Si2', pbc=False)
# Molecule: Atoms(symbols='C2H9FIOPSi', pbc=False)
# Molecule: Atoms(symbols='HBr3Cl2FOS', pbc=False)
# [03:41:41] Explicit valence for atom # 1 F, 2, is greater than permitted
# [03:41:41] Explicit valence for atom # 1 Cl, 2, is greater than permitted
# Molecule: Atoms(symbols='CH5Cl2FIN', pbc=False)
# Molecule: Atoms(symbols='C3H21BrINOP3Si2', pbc=False)
# [03:41:41] Explicit valence for atom # 4 Br, 2, is greater than permitted
# [03:41:42] Explicit valence for atom # 1 Br, 2, is greater than permitted
# [03:41:42] non-ring atom 9 marked aromatic
# Molecule: Atoms(symbols='C2H9Br2FNPS', pbc=False)
# Molecule: Atoms(symbols='CH8BrCl2F3IOP2SSi', pbc=False)
# [03:41:42] Explicit valence for atom # 1 Br, 2, is greater than permitted
# [03:41:42] Explicit valence for atom # 3 Br, 2, is greater than permitted
# Molecule: Atoms(symbols='C2H9Br2Cl2F2I2NOP', pbc=False)
# Molecule: Atoms(symbols='CH12Br3ClFPSSi4', pbc=False)
# [03:41:42] Explicit valence for atom # 1 Cl, 2, is greater than permitted
# [03:41:42] Explicit valence for atom # 5 F, 2, is greater than permitted
# Molecule: Atoms(symbols='C2H8Br2ClSi', pbc=False)
# Molecule: Atoms(symbols='C4H11ClF3IP2', pbc=False)
# [03:41:42] Explicit valence for atom # 0 Br, 2, is greater than permitted
# [03:41:43] Explicit valence for atom # 6 Br, 2, is greater than permitted
# Molecule: Atoms(symbols='C2H11Br2Cl2NOP2S2Si', pbc=False)
# Molecule: Atoms(symbols='CH10Br4FIN2OSi2', pbc=False)
# [03:41:43] Explicit valence for atom # 4 Cl, 2, is greater than permitted
# [03:41:43] non-ring atom 7 marked aromatic
# Molecule: Atoms(symbols='CH5Cl2FIO', pbc=False)
# Molecule: Atoms(symbols='H3FINO', pbc=False)
# Molecule: Atoms(symbols='H11BrClF3NO2PSi3', pbc=False)
# Molecule: Atoms(symbols='C3H13Br2FI2NOSi', pbc=False)
# [03:41:43] Explicit valence for atom # 3 F, 2, is greater than permitted
# [03:41:43] Explicit valence for atom # 1 F, 4, is greater than permitted
# Molecule: Atoms(symbols='CH16Br3Cl5F4I3N3O2P2S3Si3', pbc=False)
# [03:41:44] non-ring atom 4 marked aromatic
# Molecule: Atoms(symbols='CH12BrCl2F2I2NO2P3S2Si2', pbc=False)
# Molecule: Atoms(symbols='CH4FOPS', pbc=False)
# Molecule: Atoms(symbols='H6BrCl3F5PSSi2', pbc=False)
# [03:41:45] Explicit valence for atom # 1 F, 2, is greater than permitted
# [03:41:45] Explicit valence for atom # 1 F, 2, is greater than permitted
# [03:41:45] Explicit valence for atom # 1 Cl, 2, is greater than permitted
# Molecule: Atoms(symbols='H4BrF2I2NSi', pbc=False)
# Molecule: Atoms(symbols='CH14Cl2F2N2O2P3S', pbc=False)
# Molecule: Atoms(symbols='H7Br2OP3S', pbc=False)
# Molecule: Atoms(symbols='H4Br2F2NOP', pbc=False)
# [03:41:46] Explicit valence for atom # 1 Cl, 2, is greater than permitted
# Molecule: Atoms(symbols='C6H16Cl3FS', pbc=False)
# Molecule: Atoms(symbols='CH9Cl2F2NOSi', pbc=False)
# Molecule: Atoms(symbols='C2H14Cl2I2NPSSi', pbc=False)
# Molecule: Atoms(symbols='CH11Br3Cl2FI2NO2P2SSi', pbc=False)
# [03:41:46] Explicit valence for atom # 1 Br, 2, is greater than permitted
# [03:41:46] Explicit valence for atom # 0 Br, 2, is greater than permitted
# Molecule: Atoms(symbols='C3H13BrCl2FN2O2PSi', pbc=False)
# [03:41:47] Explicit valence for atom # 6 Br, 2, is greater than permitted
# [03:41:47] Explicit valence for atom # 3 Cl, 2, is greater than permitted
# Molecule: Atoms(symbols='CH8BrClFN2OSi', pbc=False)
# Molecule: Atoms(symbols='CH11ClNO2P2Si', pbc=False)
# Molecule: Atoms(symbols='H11BrClINOP3SSi', pbc=False)
# Molecule: Atoms(symbols='C2H13Br2Cl2FN2OPSSi', pbc=False)
# [03:41:47] Explicit valence for atom # 3 Cl, 2, is greater than permitted
# [03:41:47] Explicit valence for atom # 5 Cl, 2, is greater than permitted
# Molecule: Atoms(symbols='CH13Br2ClI2NSSi2', pbc=False)
# Molecule: Atoms(symbols='CH10ClINPS3Si2', pbc=False)
# Molecule: Atoms(symbols='H5BrI2OSSi', pbc=False)
# Molecule: Atoms(symbols='CH11ClFN2P2SSi', pbc=False)
# [03:41:48] Explicit valence for atom # 1 Cl, 2, is greater than permitted
# [03:41:48] Explicit valence for atom # 6 Br, 2, is greater than permitted
# Molecule: Atoms(symbols='C2H7Br3F2INS', pbc=False)
# Molecule: Atoms(symbols='C3H12Cl2IN2OP', pbc=False)
# [03:41:48] Explicit valence for atom # 4 Cl, 2, is greater than permitted
# [03:41:48] non-ring atom 4 marked aromatic
# [03:41:49] non-ring atom 3 marked aromatic
# Molecule: Atoms(symbols='CH12ClFINO2S2Si2', pbc=False)
# Molecule: Atoms(symbols='H7ClFIN2O3SSi', pbc=False)
# [03:41:49] Explicit valence for atom # 1 Br, 2, is greater than permitted
# [03:41:49] Explicit valence for atom # 12 Br, 3, is greater than permitted
# Molecule: Atoms(symbols='CH8BrClO2PSi', pbc=False)
# Molecule: Atoms(symbols='HBr5Cl3FI3O2', pbc=False)
# [03:41:49] Explicit valence for atom # 1 F, 2, is greater than permitted
# Molecule: Atoms(symbols='CH6Br2Cl2FI2O2SSi', pbc=False)
# Molecule: Atoms(symbols='H14ClNO2P4Si3', pbc=False)
# Molecule: Atoms(symbols='CH8OSSi', pbc=False)
# Molecule: Atoms(symbols='H12ClFI3NP3SSi2', pbc=False)
# [03:41:49] Explicit valence for atom # 5 Cl, 2, is greater than permitted
# Molecule: Atoms(symbols='C4H11BrN2', pbc=False)
# Molecule: Atoms(symbols='CH9ClF2NPSSi', pbc=False)
# [03:41:50] Explicit valence for atom # 1 F, 2, is greater than permitted
# [03:41:50] Explicit valence for atom # 9 Br, 2, is greater than permitted
# Molecule: Atoms(symbols='C3H11BrF2INOSSi', pbc=False)
# Molecule: Atoms(symbols='C7H19Br2N2S', pbc=False)
# Molecule: Atoms(symbols='C4H16FOPSi', pbc=False)
# Molecule: Atoms(symbols='CH8Br2Cl2INS5', pbc=False)
# [03:41:51] non-ring atom 9 marked aromatic
# [03:41:51] Explicit valence for atom # 9 F, 2, is greater than permitted
# Molecule: Atoms(symbols='CH8Br2FINO4Si', pbc=False)
# Molecule: Atoms(symbols='C4H16Br2N2O2P', pbc=False)
# [03:41:51] non-ring atom 3 marked aromatic
# [03:41:52] non-ring atom 3 marked aromatic
# Molecule: Atoms(symbols='H7Br2FNO2SSi2', pbc=False)
# [03:41:52] Explicit valence for atom # 2 Br, 2, is greater than permitted
# [03:41:52] Explicit valence for atom # 2 Br, 2, is greater than permitted
# Molecule: Atoms(symbols='HBr4INO', pbc=False)
# Molecule: Atoms(symbols='C2H13Br2F2IP2Si2', pbc=False)
# [03:41:52] Explicit valence for atom # 1 F, 2, is greater than permitted
# Molecule: Atoms(symbols='C2H11ClFI2OP2', pbc=False)
# Molecule: Atoms(symbols='C3H18I2NP3SSi', pbc=False)
# [03:41:53] Explicit valence for atom # 1 Cl, 2, is greater than permitted
# Molecule: Atoms(symbols='H6BrCl3F3IN2S', pbc=False)
# [03:41:53] non-ring atom 3 marked aromatic
# Molecule: Atoms(symbols='CH8ClF2NP2S2', pbc=False)
# Molecule: Atoms(symbols='CH12FIN2O2SSi2', pbc=False)
# Molecule: Atoms(symbols='H3Br2ClFIO2P', pbc=False)
# Molecule: Atoms(symbols='C3H14ClFNOPS', pbc=False)
# [03:41:53] Explicit valence for atom # 4 F, 2, is greater than permitted
# [03:41:54] Explicit valence for atom # 1 Cl, 2, is greater than permitted
# [03:41:54] Explicit valence for atom # 2 Br, 2, is greater than permitted
# Molecule: Atoms(symbols='C2H14Br2ClFIO3P2S2Si2', pbc=False)
# Molecule: Atoms(symbols='C2H16BrCl2IP2SSi2', pbc=False)
# [03:41:55] Explicit valence for atom # 2 Cl, 2, is greater than permitted
# [03:41:55] Explicit valence for atom # 4 Br, 2, is greater than permitted
# Molecule: Atoms(symbols='CH10BrClIO3PSSi3', pbc=False)
# Molecule: Atoms(symbols='CH11BrClF2N2O2SSi', pbc=False)
# [03:41:55] Explicit valence for atom # 6 F, 2, is greater than permitted
# Molecule: Atoms(symbols='H17BrClFI2N6S3Si5', pbc=False)
# [03:41:55] Explicit valence for atom # 5 Br, 2, is greater than permitted
# Molecule: Atoms(symbols='C2H10Br3NO2P', pbc=False)
# Molecule: Atoms(symbols='CH8ClN2PS', pbc=False)
# [03:41:56] non-ring atom 0 marked aromatic
# Molecule: Atoms(symbols='CH14ClF2NOP2SSi2', pbc=False)
# Molecule: Atoms(symbols='H9Cl2NOP2Si', pbc=False)
# Molecule: Atoms(symbols='C3H16BrCl2FNOPSSi', pbc=False)
# [03:41:57] Explicit valence for atom # 3 F, 3, is greater than permitted
# Molecule: Atoms(symbols='H3FO5PS', pbc=False)
# Molecule: Atoms(symbols='C4H16ClNOP2Si', pbc=False)
# Molecule: Atoms(symbols='C5H15N', pbc=False)
# Molecule: Atoms(symbols='C4H19FIN2OSSi2', pbc=False)
# 0
# [03:41:57] Explicit valence for atom # 2 F, 2, is greater than permitted

# %%
print(len(generated_list))
# Out:
# 100

# %%
print(generated_list[0]["ase_atom"])
# Out:
# Atoms(symbols='C2H11BrCl2NSSi', pbc=False)

# %%
unique_formulas = set()
count_formulas = {}
count_valid = 0
total_atom_count = 0
for item in generated_list:
    if 'formula' in item:
        if item['formula'] not in count_formulas:
            count_formulas[item['formula']] = 1
        else:
            count_formulas[item['formula']] += 1
        unique_formulas.add(item['formula'])
    if 'is_valid' in item:
        if item['is_valid'] == True:
            count_valid += 1
    if 'atom_count' in item:
        total_atom_count += item['atom_count']

# %%
print(unique_formulas)
print("Average Number of atoms: ", total_atom_count / 100)
print("Number of Unique Formulas: ", len(unique_formulas))
print("Number of Valid Formulas: ", count_valid/(count_valid + num_errors))
# Out:
# {'H6BrCl3F5PSSi2', 'C2H14Br2ClFIO3P2S2Si2', 'C4H11ClF3IP2', 'CH8ClN2PS', 'C3H11BrF2INOSSi', 'H12BrF2IN2O3Si3', 'CH8OSSi', 'H10BrCl2F2NO5P2S', 'CH9ClF3OP3', 'C6H16Cl3FS', 'H7N2O3PSi', 'CH9BrClF2IN2O2PS', 'CH4FOPS', 'CH16Br2F2IN2OP3S2Si2', 'CH8BrClO2PSi', 'C2H11BrN3S', 'CH10ClINPS3Si2', 'C3H13Br2N2P', 'H11BrClF3NO2PSi3', 'C2H11ClFI2OP2', 'H7Br2FNO2SSi2', 'C3H18I2NP3SSi', 'H6BrCl3F3IN2S', 'HBr5Cl3FI3O2', 'C3H13Br2FI2NOSi', 'CH10Br4FIN2OSi2', 'C2H13Br2Cl2FN2OPSSi', 'CH8BrCl2F3IOP2SSi', 'CH8ClF2NP2S2', 'HBr3Cl2FOS', 'CH9Cl2F2NOSi', 'C2H5Br4Cl3F2I2N2OPS', 'CH11ClFN2P2SSi', 'C3H11BrCl2INOP2S', 'CH12BrCl2F2I2NO2P3S2Si2', 'C3H16BrCl2FNOPSSi', 'H17BrClFI2N6S3Si5', 'C5H15N', 'CH12FIN2O2SSi2', 'CH16Br3Cl5F4I3N3O2P2S3Si3', 'H7Br2OP3S', 'CH8BrClFN2OSi', 'CH12ClFINO2S2Si2', 'C4H16FOPSi', 'C4H16ClNOP2Si', 'HBr4INO', 'H3Br2ClFIO2P', 'CH11Br3Cl2FI2NO2P2SSi', 'CH11ClNO2P2Si', 'CH5Cl2FIN', 'C2H16F2NO2PS3Si3', 'H11BrClINOP3SSi', 'CH6Br2Cl2FI2O2SSi', 'C2H8Br2ClSi', 'C2H13Br2Cl2I3NPS2Si', 'C2H11BrCl2NSSi', 'H4Br2F2NOP', 'CH9ClF2NPSSi', 'C3H8OS', 'C4H20FNO2PSi', 'H7ClFIN2O3SSi', 'CH11BrClF2N2O2SSi', 'H4BrF2I2NSi', 'C2H7Br3F2INS', 'C2H10Br3NO2P', 'C2H9FIOPSi', 'H3FO5PS', 'C4H15Br2Cl2N2S2', 'CH8Br2FINO4Si', 'C2H13Br2F2IP2Si2', 'H3FINO', 'C3H13BrCl2FN2O2PSi', 'CH13Br2ClI2NSSi2', 'C2H9Br2FNPS', 'C2H9Br2Cl2F2I2NOP', 'CH8Br2Cl2INS5', 'C4H19FIN2OSSi2', 'H14ClNO2P4Si3', 'C4H11BrN2', 'H9Cl2NOP2Si', 'CH5Cl2FIO', 'C3H13F4IO2PS', 'C2H9BrCl2F4NPS2', 'CH8BrIN2OS2', 'C2H9BrCl4S3', 'C2H16BrCl2IP2SSi2', 'C2H14Cl2I2NPSSi', 'H13Cl2N3P2S2Si2', 'CH10BrClIO3PSSi3', 'C2H11Br2Cl2NOP2S2Si', 'CH12Br3ClFPSSi4', 'CH14Cl2F2N2O2P3S', 'H12ClFI3NP3SSi2', 'C3H12Cl2IN2OP', 'CH14ClF2NOP2SSi2', 'C3H21BrINOP3Si2', 'H5BrI2OSSi', 'C4H16Br2N2O2P', 'C3H14ClFNOPS', 'C7H19Br2N2S'}
# Average Number of atoms:  20.94
# Number of Unique Formulas:  100
# Number of Valid Formulas:  1.0

# %%
print(count_formulas)
# Out:
# {'C2H11BrCl2NSSi': 1, 'C3H11BrCl2INOP2S': 1, 'CH9BrClF2IN2O2PS': 1, 'H13Cl2N3P2S2Si2': 1, 'H12BrF2IN2O3Si3': 1, 'CH8BrIN2OS2': 1, 'C2H5Br4Cl3F2I2N2OPS': 1, 'C4H20FNO2PSi': 1, 'C2H9BrCl2F4NPS2': 1, 'CH9ClF3OP3': 1, 'H7N2O3PSi': 1, 'C3H13Br2N2P': 1, 'C3H8OS': 1, 'C4H15Br2Cl2N2S2': 1, 'C2H9BrCl4S3': 1, 'C2H11BrN3S': 1, 'C2H16F2NO2PS3Si3': 1, 'H10BrCl2F2NO5P2S': 1, 'C2H13Br2Cl2I3NPS2Si': 1, 'C3H13F4IO2PS': 1, 'CH16Br2F2IN2OP3S2Si2': 1, 'C2H9FIOPSi': 1, 'HBr3Cl2FOS': 1, 'CH5Cl2FIN': 1, 'C3H21BrINOP3Si2': 1, 'C2H9Br2FNPS': 1, 'CH8BrCl2F3IOP2SSi': 1, 'C2H9Br2Cl2F2I2NOP': 1, 'CH12Br3ClFPSSi4': 1, 'C2H8Br2ClSi': 1, 'C4H11ClF3IP2': 1, 'C2H11Br2Cl2NOP2S2Si': 1, 'CH10Br4FIN2OSi2': 1, 'CH5Cl2FIO': 1, 'H3FINO': 1, 'H11BrClF3NO2PSi3': 1, 'C3H13Br2FI2NOSi': 1, 'CH16Br3Cl5F4I3N3O2P2S3Si3': 1, 'CH12BrCl2F2I2NO2P3S2Si2': 1, 'CH4FOPS': 1, 'H6BrCl3F5PSSi2': 1, 'H4BrF2I2NSi': 1, 'CH14Cl2F2N2O2P3S': 1, 'H7Br2OP3S': 1, 'H4Br2F2NOP': 1, 'C6H16Cl3FS': 1, 'CH9Cl2F2NOSi': 1, 'C2H14Cl2I2NPSSi': 1, 'CH11Br3Cl2FI2NO2P2SSi': 1, 'C3H13BrCl2FN2O2PSi': 1, 'CH8BrClFN2OSi': 1, 'CH11ClNO2P2Si': 1, 'H11BrClINOP3SSi': 1, 'C2H13Br2Cl2FN2OPSSi': 1, 'CH13Br2ClI2NSSi2': 1, 'CH10ClINPS3Si2': 1, 'H5BrI2OSSi': 1, 'CH11ClFN2P2SSi': 1, 'C2H7Br3F2INS': 1, 'C3H12Cl2IN2OP': 1, 'CH12ClFINO2S2Si2': 1, 'H7ClFIN2O3SSi': 1, 'CH8BrClO2PSi': 1, 'HBr5Cl3FI3O2': 1, 'CH6Br2Cl2FI2O2SSi': 1, 'H14ClNO2P4Si3': 1, 'CH8OSSi': 1, 'H12ClFI3NP3SSi2': 1, 'C4H11BrN2': 1, 'CH9ClF2NPSSi': 1, 'C3H11BrF2INOSSi': 1, 'C7H19Br2N2S': 1, 'C4H16FOPSi': 1, 'CH8Br2Cl2INS5': 1, 'CH8Br2FINO4Si': 1, 'C4H16Br2N2O2P': 1, 'H7Br2FNO2SSi2': 1, 'HBr4INO': 1, 'C2H13Br2F2IP2Si2': 1, 'C2H11ClFI2OP2': 1, 'C3H18I2NP3SSi': 1, 'H6BrCl3F3IN2S': 1, 'CH8ClF2NP2S2': 1, 'CH12FIN2O2SSi2': 1, 'H3Br2ClFIO2P': 1, 'C3H14ClFNOPS': 1, 'C2H14Br2ClFIO3P2S2Si2': 1, 'C2H16BrCl2IP2SSi2': 1, 'CH10BrClIO3PSSi3': 1, 'CH11BrClF2N2O2SSi': 1, 'H17BrClFI2N6S3Si5': 1, 'C2H10Br3NO2P': 1, 'CH8ClN2PS': 1, 'CH14ClF2NOP2SSi2': 1, 'H9Cl2NOP2Si': 1, 'C3H16BrCl2FNOPSSi': 1, 'H3FO5PS': 1, 'C4H16ClNOP2Si': 1, 'C5H15N': 1, 'C4H19FIN2OSSi2': 1}

# %% [markdown]
# ### Novelty

# %%
with open("data/og_formulas.pkl", "rb") as file:
    og_formulas = pickle.load(file)

# %%
print(og_formulas)
print(len(og_formulas))
# Out:
# ['C4H10O2S2', 'C17H11BrClFN2O4', 'C7H7Br', 'C7H16BrN', 'C2HBrCl2O2', 'C4H6Br2', 'CBrCl3', 'C6H5F2N', 'C11H20O', 'C6BrF5', 'C10H24N2O4', 'C6H4ClNO2', 'C6H14O3', 'C10H22O5', 'C2H3BrO2', 'C8H18BrN', 'C7H5ClO2', 'C6H3Br3', 'C10H22OS', 'C7H6Br2', 'C14H15N5O6S', 'C10H16Cl3NOS', 'C3H5BrO', 'C2H4Br2', 'C8H14O', 'C6H6N2O', 'C22H25ClN2O9', 'C15H17N5O6S', 'C12H12', 'C6H12S', 'C8H14N4O7', 'C4H5NS', 'C4H10S', 'C3H12NO9P3', 'C6H4BrF', 'C22H24N2O8', 'C4H8BrCl', 'C11H10', 'C6H8N2S', 'C13H27Br', 'C10H12N6', 'C13H21N3O6S2', 'C14H29Br', 'C2H3FO2', 'C2H4N4O2', 'C14H16N2O4S', 'C11H24O6Si', 'C10H20O', 'C7H3Cl2FO', 'C3H5Br2Cl', 'C12H22F6N2O4S2', 'C9H17IN2', 'C8H12N4', 'C27H50O6', 'C2H5NO2', 'C9H6F3N', 'C7H6F3N', 'C11H16N8O8', 'H4N2O3', 'C2H5NO3', 'C4H10O3', 'C7H7ClS', 'C8H15IN2', 'C11H10FNO2S', 'C8H8O3', 'C12H16O7', 'C21H40O5', 'C13H22N4O3S', 'C9H10ClN5O2', 'C4H9NO4', 'C28H46O4', 'C8H5N3O4', 'C14H16ClN5O5S', 'C25H48O4', 'C16H10F3NO', 'C12H13ClF3N3O4', 'C12H8N2O5', 'C13H18N2O4', 'C10H22BrN', 'C6H11ClN2', 'C8H11N3O4', 'C5H6N2O2S', 'C13H16O3', 'C17H25N7O', 'C8H10N2', 'CHF3O3S', 'C37H61BrN2O4', 'C8H12N2O2', 'C5H13NO2', 'C9H10N4O2S2', 'C17H12Cl2N6O4', 'C22H28INO2', 'C5H4ClNO', 'C8H10O2', 'C15H27N3O', 'C10H22IN', 'C3H9O3P', 'C9H17ClN2', 'C3H3NO2', 'C6H12O2', 'C7H14O3', 'C2H3F3O', 'C21H23ClFNO5', 'C6H10', 'C22H42O4', 'C27H46O2', 'C8H17NO3', 'C15H16F5NO2S2', 'C10H14', 'C7H9NO3S', 'C5H7N3O2', 'C5H13N', 'C12H18N2O3S', 'C12H21N2O4P', 'C14H22O8', 'C14H22N2O3', 'C8H19NO', 'C12H19N3O', 'C10H11NO3', 'C9H10', 'C10H12O', 'C13H26O4', 'C7H3ClF3NO2', 'C8H7NO3', 'C7H5NO4', 'C9H19NO4', 'C8H14O3', 'C5H11NOS', 'C10H24N2', 'C34H58O4', 'C7H4F3NO2', 'C9H20S', 'C12H18', 'C5H10O', 'C3H6O', 'C4H6N2O', 'C19H36O2', 'C6H10N2O3', 'C15H21NO4', 'C7H5Cl2NO', 'C11H7NO4', 'C2H5NS', 'C5H8O4', 'C10H21NO', 'C5H12O3', 'C11H20O4', 'C8H10F3NO3S', 'C5H7N', 'C13H16O2', 'C4H8Cl2', 'C6H16N2', 'C9H16O', 'C7H14N2O', 'C4H10O4S', 'C10H6O8', 'C12H18O3', 'C13H19NO9', 'C10H15NO2', 'C13H24O4', 'C10H15F6N3O4S2', 'C12H10O3', 'C14H8Br2O2', 'C4H8O3', 'C17H21IO2', 'C11H15NO2S', 'C22H42O6', 'C14H17N3O3', 'C18H18O5', 'C11H22O2', 'C14H22O6', 'C6H14', 'C14H19ClO', 'C14H30O', 'C10H15N', 'C22H42O2', 'C9H20N2', 'C7H9NO2S', 'C7H10O2', 'C2H3NS', 'C2H3NO', 'C3H4Cl2', 'C12H12N2O2S', 'C5H8O', 'C4H6O2', 'CH2O', 'C16H13ClN2O2', 'C38H72N2O12', 'C22H20O13', 'C8H16O', 'C5H7ClO2', 'C26H47O3P', 'C8H18F6NP', 'C9H18N3OP', 'C9H16N4OS', 'C9H16F6N2O4S2', 'C5H11NO2', 'C5H9NO3S', 'C11H14N2O', 'C15H30N2', 'CH4N2O', 'C10H20O2S', 'C10H18F6N2O4S2', 'C7H14N2O4S', 'C4H12O3Si', 'C32H60O10', 'C9H13N3O3', 'C19H24N4O3', 'C2H7NO2S', 'C2H6OSi', 'C9H13F6N3O4S2', 'C8H24O2Si3', 'C7H22O2Si3', 'C6H7N', 'C12H2Br8O', 'C14H17BrN2O2', 'C12H10', 'C9H16N2', 'C6H14O6', 'C10H12O2', 'C16H14O3', 'C6H12O6', 'C4H8N2O2', 'C7H9N', 'C7H10O4S', 'C2H8N2O', 'C4H12N2O', 'C23H22ClF3O2', 'C7H16O', 'C12H22O11', 'C17H28N4O7S', 'C5H12O5', 'C14H28O2', 'C6H10O4', 'C6H18N4', 'C9H7N', 'C3H4N2', 'C4H4N2', 'C6H12N2', 'C6H6', 'C8H10N2O3S', 'C8H6O', 'C9H11N', 'C3H6O2', 'C10H14S', 'C10H12', 'C24H34N8O4S2', 'C6H7NO3S', 'C4H6O3', 'C3H4N2S', 'C12H14', 'C7H10O3', 'C2H3N3', 'C6H12N4', 'C16H33NO2', 'C4H8S2', 'C2H8O7P2', 'C13H30O6P2', 'C6H12Br2', 'C8H14ClN5', 'C17H26O', 'C11H18O3Si', 'C18H28O2', 'C9H13ClN6', 'C6H10O', 'C8H16', 'C7H12ClN5', 'C9H4Cl6O4', 'C21H25NO2', 'C14H21NO4', 'C7H14N2O3S', 'C24H45NO6S', 'C6H15Cl2NO', 'C8H13NO3S', 'C12H17N5O4S', 'C6H11NO2', 'C10H8N2', 'C12H24', 'C4H7ClO2', 'C8H12', 'C8H19O3PS2', 'C20H26', 'C18H35NO2', 'C8H20O5P2S2', 'C6H15O3P', 'C12H20ClN3O', 'C6H4Cl2', 'C31H52O3', 'C6H3Cl3', 'C12H8', 'C4H4O', 'C12H22', 'C7H6Cl2', 'C12H8O2', 'C10H8O2', 'C11H14N2', 'C10H10O3', 'C17H17N3O3', 'C4H6O', 'C9H8N2', 'C6H9N3O3', 'C13H22O', 'C12H27P', 'C28H52N2O4', 'C12H11NO3', 'C3H8N2O', 'C8H10ClN5O3S', 'C6H14N2O', 'C17H16O4', 'C10H18O3', 'C15H20ClN3O', 'C26H48O4', 'C15H10ClF3N2O6S', 'C9H21O2PS3', 'C16H34O4', 'C8H18O2', 'C17H34O2', 'C4H10O', 'C14H32N2O4', 'C14H6Cl2F4N2O2', 'C4H11N', 'C18H38N4O15S', 'C3H8S', 'C3H5ClO2', 'C8H18O3Si', 'C8H20O3Si', 'C23H31ClN2O', 'C10H11ClN4', 'C8H20ClN ...
# 3208

# %%
og_formulas = set(og_formulas)
print(og_formulas & unique_formulas)
print(len(og_formulas & unique_formulas))
print("Number of Novel Molecules: ", 100 - len(og_formulas & unique_formulas))
# Out:
# set()
# 0
# Number of Novel Molecules:  100

# %%
df = pd.DataFrame(list(count_formulas.items()), columns=['Formula', 'Count'])
sorted_df = df.sort_values(by='Count', ascending=False)
sorted_df.head(31)
# Out:
#                 Formula  Count
# 0        C2H11BrCl2NSSi      1
# 63         HBr5Cl3FI3O2      1
# 73        CH8Br2Cl2INS5      1
# 72           C4H16FOPSi      1
# 71          C7H19Br2N2S      1
# 70      C3H11BrF2INOSSi      1
# 69         CH9ClF2NPSSi      1
# 68            C4H11BrN2      1
# 67      H12ClFI3NP3SSi2      1
# 66              CH8OSSi      1
# 65        H14ClNO2P4Si3      1
# 64    CH6Br2Cl2FI2O2SSi      1
# 62         CH8BrClO2PSi      1
# 1      C3H11BrCl2INOP2S      1
# 61        H7ClFIN2O3SSi      1
# 60     CH12ClFINO2S2Si2      1
# 59        C3H12Cl2IN2OP      1
# 58         C2H7Br3F2INS      1
# 57       CH11ClFN2P2SSi      1
# 56           H5BrI2OSSi      1
# 55       CH10ClINPS3Si2      1
# 54     CH13Br2ClI2NSSi2      1
# 53  C2H13Br2Cl2FN2OPSSi      1
# 52      H11BrClINOP3SSi      1
# 74        CH8Br2FINO4Si      1
# 75        C4H16Br2N2O2P      1
# 76        H7Br2FNO2SSi2      1
# 77              HBr4INO      1
# 98               C5H15N      1
# 97        C4H16ClNOP2Si      1
# 96              H3FO5PS      1

# %%
sorted_df.to_csv("vae_generated_count_coulomb2.csv", index=False)

# %%
df = pd.DataFrame(generated_list)
df.head()
# Out:
#    atom_count  is_valid                                           ase_atom
# 0          19     False  (Atom('C', [9.526371839414058, 0.5800691723209...  \
# 1          23     False  (Atom('C', [9.304911805682842, 1.9821055772014...
# 2          21     False  (Atom('C', [1.187510713884079, 8.9877550376057...
# 3          24     False  (Atom('H', [1.463085375279074, 5.3510431018732...
# 4          24     False  (Atom('H', [0.9925289777960244, 4.592648447051...
#
#                                                  mol           formula
# 0  <rdkit.Chem.rdchem.RWMol object at 0x2aabb9a70...    C2H11BrCl2NSSi  \
# 1  <rdkit.Chem.rdchem.RWMol object at 0x2aabb9a01...  C3H11BrCl2INOP2S
# 2  <rdkit.Chem.rdchem.RWMol object at 0x2aabb9a55...  CH9BrClF2IN2O2PS
# 3  <rdkit.Chem.rdchem.RWMol object at 0x2aabb9a71...   H13Cl2N3P2S2Si2
# 4  <rdkit.Chem.rdchem.RWMol object at 0x2aabb9ad3...   H12BrF2IN2O3Si3
#
#      energy       bio
# 0 -3.000091  1.718690
# 1 -7.000013  0.615966
# 2 -7.000000  7.607859
# 3 -4.000700  0.737692
# 4 -8.000902  0.443336

# %%
print(df.columns)
# Out:
# Index(['atom_count', 'is_valid', 'ase_atom', 'mol', 'formula', 'energy',
#        'bio'],
#       dtype='object')

# %%
bio_formula = df[['formula', 'bio']]
sorted_df = bio_formula.sort_values(by='bio', ascending=False)
sorted_df.head(31)
# Out:
#               formula        bio
# 12             C3H8OS  90.851480
# 98             C5H15N  88.723159
# 34             H3FINO  79.318869
# 66            CH8OSSi  76.928306
# 10          H7N2O3PSi  56.796932
# 72         C4H16FOPSi  48.259726
# 96            H3FO5PS  32.567045
# 56         H5BrI2OSSi  22.514643
# 51      CH11ClNO2P2Si  19.064760
# 7        C4H20FNO2PSi  15.764488
# 21         C2H9FIOPSi  14.608009
# 61      H7ClFIN2O3SSi  14.118421
# 92          CH8ClN2PS  14.003468
# 68          C4H11BrN2  13.848755
# 39            CH4FOPS  12.990476
# 97      C4H16ClNOP2Si  12.782925
# 46       CH9Cl2F2NOSi  10.765592
# 94        H9Cl2NOP2Si  10.165674
# 62       CH8BrClO2PSi   8.880255
# 33          CH5Cl2FIO   8.791471
# 9          CH9ClF3OP3   8.724310
# 79      C2H11ClFI2OP2   8.000299
# 87  C2H16BrCl2IP2SSi2   7.871743
# 85       C3H14ClFNOPS   7.710706
# 43          H7Br2OP3S   7.657533
# 2    CH9BrClF2IN2O2PS   7.607859
# 80      C3H18I2NP3SSi   7.546537
# 95  C3H16BrCl2FNOPSSi   6.998956
# 19       C3H13F4IO2PS   6.151653
# 69       CH9ClF2NPSSi   5.649554
# 67    H12ClFI3NP3SSi2   5.476838

# %%
print(sorted_df['bio'].sum() / 100)
# Out:
# 8.300770946538762

# %%
df.to_csv('vae_generated_coulomb2.csv', index=False)

# %%
sorted_df.to_csv('vae_generated_bio_coulomb2.csv', index=False)

# %%
random_mol, random_formula = df[['mol','formula']].sample(n=1).iloc[0]
smiles = Chem.MolToSmiles(random_mol.GetMol())
print(random_formula)
print(smiles)
Chem.MolFromSmiles(smiles)
# Out:
# C4H15Br2Cl2N2S2
# CCN.CClBr.CNSS.ClBr
# [03:41:59] Explicit valence for atom # 4 Cl, 2, is greater than permitted

# %%
error_count = 0
success_count = 0

for index, row in df.iterrows():
    try:
        mol = row['mol']
        smiles = Chem.MolToSmiles(mol)
        new_mol = Chem.MolFromSmiles(smiles)
        if new_mol is not None:
            num_components = len(Chem.GetMolFrags(new_mol))
            if num_components == 1:
                success_count += 1
            else:
                error_count += 1
        else:
            error_count += 1
    except Exception as e:
        error_count += 1

print("Percentage of Valid Molecules", success_count / (error_count + success_count) * 100)
# Out:
# Percentage of Valid Molecules 4.0
# [03:49:39] Explicit valence for atom # 4 Cl, 2, is greater than permitted
# [03:49:39] non-ring atom 9 marked aromatic
# [03:49:39] Explicit valence for atom # 8 Br, 2, is greater than permitted
# [03:49:39] non-ring atom 8 marked aromatic
# [03:49:39] SMILES Parse Error: syntax error while parsing: FBrN[siH]i.N[SiH3].OOF.O[SiH3]
# [03:49:39] SMILES Parse Error: Failed parsing SMILES 'FBrN[siH]i.N[SiH3].OOF.O[SiH3]' for input: 'FBrN[siH]i.N[SiH3].OOF.O[SiH3]'
# [03:49:39] Explicit valence for atom # 5 F, 2, is greater than permitted
# [03:49:39] Explicit valence for atom # 8 F, 2, is greater than permitted
# [03:49:39] Explicit valence for atom # 4 Cl, 2, is greater than permitted
# [03:49:39] Explicit valence for atom # 3 Cl, 2, is greater than permitted
# [03:49:39] Explicit valence for atom # 3 Br, 2, is greater than permitted
# [03:49:39] Explicit valence for atom # 4 F, 2, is greater than permitted
# [03:49:39] Explicit valence for atom # 2 F, 2, is greater than permitted
# [03:49:39] Explicit valence for atom # 2 Cl, 2, is greater than permitted
# [03:49:39] Explicit valence for atom # 1 F, 2, is greater than permitted
# [03:49:39] SMILES Parse Error: syntax error while parsing: CSNF.OPNBrBr.SI.[SiH3][SiH2]P.fp
# [03:49:39] SMILES Parse Error: Failed parsing SMILES 'CSNF.OPNBrBr.SI.[SiH3][SiH2]P.fp' for input: 'CSNF.OPNBrBr.SI.[SiH3][SiH2]P.fp'
# [03:49:39] SMILES Parse Error: syntax error while parsing: BrClBrobr.SFCl
# [03:49:39] SMILES Parse Error: Failed parsing SMILES 'BrClBrobr.SFCl' for input: 'BrClBrobr.SFCl'
# [03:49:39] SMILES Parse Error: syntax error while parsing: CClF.Nicl
# [03:49:39] SMILES Parse Error: Failed parsing SMILES 'CClF.Nicl' for input: 'CClF.Nicl'
# [03:49:39] Explicit valence for atom # 3 Br, 2, is greater than permitted
# [03:49:39] Explicit valence for atom # 1 Br, 2, is greater than permitted
# [03:49:39] SMILES Parse Error: syntax error while parsing: FCl.Fpcl.O[IH]SF.P[SiH2]CBr
# [03:49:39] SMILES Parse Error: Failed parsing SMILES 'FCl.Fpcl.O[IH]SF.P[SiH2]CBr' for input: 'FCl.Fpcl.O[IH]SF.P[SiH2]CBr'
# [03:49:39] SMILES Parse Error: syntax error while parsing: CClI.FBrBr.FNP.OI.ccl
# [03:49:39] SMILES Parse Error: Failed parsing SMILES 'CClI.FBrBr.FNP.OI.ccl' for input: 'CClI.FBrBr.FNP.OI.ccl'
# [03:49:39] SMILES Parse Error: syntax error while parsing: C[SiH2]Br.F[SiH2][SiH2]BrsclBr.[SiH2]=P
# [03:49:39] SMILES Parse Error: Failed parsing SMILES 'C[SiH2]Br.F[SiH2][SiH2]BrsclBr.[SiH2]=P' for input: 'C[SiH2]Br.F[SiH2][SiH2]BrsclBr.[SiH2]=P'
# [03:49:39] Explicit valence for atom # 1 Cl, 2, is greater than permitted
# [03:49:39] SMILES Parse Error: syntax error while parsing: CCI.PPFfcCl.cf
# [03:49:39] SMILES Parse Error: Failed parsing SMILES 'CCI.PPFfcCl.cf' for input: 'CCI.PPFfcCl.cf'
# [03:49:39] Explicit valence for atom # 1 Cl, 2, is greater than permitted
# [03:49:39] SMILES Parse Error: syntax error while parsing: N[IH]C[SiH2]brnBr[SiH2]BrF.OBr
# [03:49:39] SMILES Parse Error: Failed parsing SMILES 'N[IH]C[SiH2]brnBr[SiH2]BrF.OBr' for input: 'N[IH]C[SiH2]brnBr[SiH2]BrF.OBr'
# [03:49:39] Explicit valence for atom # 4 Cl, 2, is greater than permitted
# [03:49:39] SMILES Parse Error: syntax error while parsing: FCl.F[SiH3].N[siH]fOBr.OP[SiH3]
# [03:49:39] SMILES Parse Error: Failed parsing SMILES 'FCl.F[SiH3].N[siH]fOBr.OP[SiH3]' for input: 'FCl.F[SiH3].N[siH]fOBr.OP[SiH3]'
# [03:49:39] Explicit valence for atom # 5 F, 2, is greater than permitted
# [03:49:39] Explicit valence for atom # 5 F, 4, is greater than permitted
# [03:49:39] SMILES Parse Error: syntax error while parsing: C=[SiH2].FNclbrO[IH]OS.SCl.[SiH]#P=IP.fp
# [03:49:39] SMILES Parse Error: Failed parsing SMILES 'C=[SiH2].FNclbrO[IH]OS.SCl.[SiH]#P=IP.fp' for input: 'C=[SiH2].FNclbrO[IH]OS.SCl.[SiH]#P=IP.fp'
# [03:49:39] SMILES Parse Error: syntax error while parsing: FBr.FCl.FS.[SiH3]FClf[siH]PCl
# [03:49:39] SMILES Parse Error: Failed parsing SMILES 'FBr.FCl.FS.[SiH3]FClf[siH]PCl' for input: 'FBr.FCl.FS.[SiH3]FClf[siH]PCl'
# [03:49:39] Explicit valence for atom # 1 F, 2, is greater than permitted
# [03:49:39] Explicit valence for atom # 11 Cl, 2, is greater than permitted
# [03:49:39] Explicit valence for atom # 6 Cl, 2, is greater than permitted
# [03:49:39] SMILES Parse Error: syntax error while parsing: CCl[SiH2]brbr.NBrOPPClO[IH]F.SI
# [03:49:39] SMILES Parse Error: Failed parsing SMILES 'CCl[SiH2]brbr.NBrOPPClO[IH]F.SI' for input: 'CCl[SiH2]brbr.NBrOPPClO[IH]F.SI'
# [03:49:39] Explicit valence for atom # 3 Cl, 2, is greater than permitted
# [03:49:39] Explicit valence for atom # 6 Br, 2, is greater than permitted
# [03:49:39] Explicit valence for atom # 3 Cl, 2, is greater than permitted
# [03:49:39] Explicit valence for atom # 1 F, 2, is greater than permitted
# [03:49:39] Explicit valence for atom # 1 Cl, 2, is greater than permitted
# [03:49:39] Explicit valence for atom # 7 Cl, 2, is greater than permitted
# [03:49:39] Explicit valence for atom # 3 F, 2, is greater than permitted
# [03:49:39] SMILES Parse Error: syntax error while parsing: NCPCClN.OCl.ci
# [03:49:39] SMILES Parse Error: Failed parsing SMILES 'NCPCClN.OCl.ci' for input: 'NCPCClN.OCl.ci'
# [03:49:39] non-ring atom 6 marked aromatic
# [03:49:39] SMILES Parse Error: syntax error while parsing: F[SiH3].NNOoio.SCl
# [03:49:39] SMILES Parse Error: Failed parsing SMILES 'F[SiH3].NNOoio.SCl' for input: 'F[SiH3].NNOoio.SCl'
# [03:49:39] Explicit valence for atom # 5 Br, 2, is greater than permitted
# [03:49:39] SMILES Parse Error: syntax error while parsing: Br#Br.BrI.ClBr.ClBr.ClioI.OF
# [03:49:39] SMILES Parse Error: Failed parsing SMILES 'Br#Br.BrI.ClBr.ClBr.ClioI.OF' for input: 'Br#Br.BrI.ClBr.ClBr.ClioI.OF'
# [03:49:39] SMILES Parse Error: syntax error while parsing: OFCl[IH]ClBrSBricO[SiH3]
# [03:49:39] SMILES Parse Error: Failed parsing SMILES 'OFCl[IH]ClBrSBricO[SiH3]' for input: 'OFCl[IH]ClBrSBricO[SiH3]'
# [03:49:39] Explicit valence for atom # 5 Cl, 2, is greater than permitted
# [03:49:39] SMILES Parse Error: syntax error while parsing: Ccsbr.NF.OFI.c[siH2]
# [03:49:39] SMILES Parse Error: Failed parsing SMILES 'Ccsbr.NF.OFI.c[siH2]' for input: 'Ccsbr.NF.OFI.c[siH2]'
# [03:49:39] Explicit valence for atom # 1 Br, 2, is greater than permitted
# [03:49:39] SMILES Parse Error: syntax error while parsing: CcliS.NSCl.SBr.SSBr
# [03:49:39] SMILES Parse Error: Failed parsing SMILES 'CcliS.NSCl.SBr.SSBr' for input: 'CcliS.NSCl.SBr.SSBr'
# [03:49:39] Explicit valence for atom # 1 F, 2, is greater than permitted
# [03:49:39] SMILES Parse Error: syntax error while parsing: CBr.CN.NPCbroCO
# [03:49:39] SMILES Parse Error: Failed parsing SMILES 'CBr.CN.NPCbroCO' for input: 'CBr.CN.NPCbroCO'
# [03:49:39] non-ring atom 1 marked aromatic
# [03:49:39] Explicit valence for atom # 2 Br, 2, is greater than permitted
# [03:49:39] Explicit valence for atom # 2 Br, 2, is greater than permitted
# [03:49:39] Explicit valence for atom # 1 F, 2, is greater than permitted
# [03:49:39] Explicit valence for atom # 1 F, 2, is greater than permitted
# [03:49:39] SMILES Parse Error: syntax error while parsing: FF.NCP.SpclS
# [03:49:39] SMILES Parse Error: Failed parsing SMILES 'FF.NCP.SpclS' for input: 'FF.NCP.SpclS'
# [03:49:39] SMILES Parse Error: syntax error while parsing: ClI.OBr.obrFP
# [03:49:39] SMILES Parse Error: Failed parsing SMILES 'ClI.OBr.obrFP' for input: 'ClI.OBr.obrFP'
# [03:49:39] Explicit valence for atom # 1 Cl, 2, is greater than permitted
# [03:49:39] Explicit valence for atom # 2 Cl, 3, is greater than permitted
# [03:49:39] Explicit valence for atom # 6 Cl, 2, is greater than permitted
# [03:49:39] Explicit valence for atom # 1 Cl, 2, is greater than permitted
# [03:49:39] SMILES Parse Error: syntax error while parsing: N#[SiH].N[SiH2]Br.N[SiH2]F[Si](=Cl)NSn([SiH3])i.SN[IH]S
# [03:49:39] SMILES Parse Error: Failed parsing SMILES 'N#[SiH].N[SiH2]Br.N[SiH2]F[Si](=Cl)NSn([SiH3])i.SN[IH]S' for input: 'N#[SiH].N[SiH2]Br.N[SiH2]F[Si](=Cl)NSn([SiH3])i.SN[IH]S'
# [03:49:39] Explicit valence for atom # 2 Br, 2, is greater than permitted
# [03:49:39] SMILES Parse Error: syntax error while parsing: CP.FCl.NO.[SiH3]Pf[siH]S
# [03:49:39] SMILES Parse Error: Failed parsing SMILES 'CP.FCl.NO.[SiH3]Pf[siH]S' for input: 'CP.FCl.NO.[SiH3]Pf[siH]S'
# [03:49:39] Explicit valence for atom # 3 O, 4, is greater than permitted
# [03:49:39] Explicit valence for atom # 5 F, 2, is greater than permitted
