# %%
import numpy as np
import os
import pandas as pd
import datetime
import torch
import gc
import io
import json
import matplotlib.lines as mlines
import matplotlib.pyplot as plt
import networkx as nx
from rdkit.Chem import rdmolops
from rdkit.Chem.rdmolops import AddHs
from rdkit.Chem.rdmolops import GetMolFrags
from rdkit import Chem, RDLogger
from rdkit import DataStructs
from rdkit.Chem import AllChem, Draw, Descriptors
from rdkit.Chem import AtomValenceException
from rdkit.Chem import Descriptors
from rdkit.Chem import MolFromSmiles
from rdkit.Chem import rdMolDescriptors
from rdkit.Chem import rdmolfiles
from rdkit.Chem.Draw import IPythonConsole, MolsToGridImage
from rdkit.Chem.Fingerprints import FingerprintMols
from rdkit.Chem.Scaffolds import MurckoScaffold
from rdkit.DataStructs.cDataStructs import TanimotoSimilarity
import rdkit.RDLogger as rdl
from tensorflow import keras
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.utils import plot_model
import tensorflow as tf
from scipy.spatial.distance import pdist, squareform
import concurrent.futures
from tqdm import tqdm
import base64
from IPython.display import display
from IPython.display import Image
from multiprocessing import Pool, cpu_count
from PIL import Image
import gzip
import pickle
import psutil
# import pygraphviz as pgv
import time
from torch_geometric.data import DataLoader, Data

# %%
from contextlib import contextmanager
import sys
import os
import torch
from ase import Atoms
from ase.data import chemical_symbols
from ase.calculators.morse import MorsePotential
from ase.optimize import QuasiNewton
import numpy as np
import pickle

import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from ase import Atoms
from ase.io import read
from torch_geometric.data import Data
from torch_geometric.nn import MessagePassing
from torch_geometric.utils import to_networkx
# from torch_geometric.data import DataLoader, TensorDataset
from torch_geometric.loader import DataLoader
from sklearn.model_selection import train_test_split
from ase.build import molecule
import pandas as pd
from rdkit import Chem
from rdkit.Chem import AllChem
import random
from torch_geometric.nn import global_add_pool, GATConv, CGConv, GCNConv, RGCNConv
from torch_geometric.nn.models.schnet import GaussianSmearing
from sklearn.metrics import roc_auc_score, precision_score, confusion_matrix
import matplotlib.pyplot as plt
import pickle
from collections import Counter
import seaborn as sns
import time
from torch.optim.lr_scheduler import StepLR
import torch
from torch_geometric.data import Data

# %%
# Code taken from https://github.com/bmacedo111/MedGAN/

# %%
with tf.device('/GPU:0'):
    atom_mapping = {
        "C": 0,
        "N": 1,
        "O": 2,
        "H": 3,
        "F": 4,
        "S": 5,
        "Cl": 6,
    }

    bond_mapping = {
        "SINGLE": 0,
        0: Chem.BondType.SINGLE,
        "DOUBLE": 1,
        1: Chem.BondType.DOUBLE,
        "TRIPLE": 2,
        2: Chem.BondType.TRIPLE,
        "AROMATIC": 3,
        3: Chem.BondType.AROMATIC,
    }

    charge_mapping = {
        -1: 7,
        1: 8,
    }

    NUM_ATOMS = 63
    ATOM_DIM = 11
    BOND_DIM = 4 + 1
    LATENT_DIM = 256

# %%
def GraphGenerator(
    dense_units, dropout_rate, latent_dim, adjacency_shape, feature_shape,
):
    z = keras.layers.Input(shape=(LATENT_DIM,))
    # Propagate through one or more densely connected layers
    x = z
    for units in dense_units:
        x = keras.layers.Dense(units, activation="tanh")(x)
        x = keras.layers.Dropout(dropout_rate)(x)

    # Map outputs of previous layer (x) to [continuous] adjacency tensors (x_adjacency)
    x_adjacency = keras.layers.Dense(tf.math.reduce_prod(adjacency_shape))(x)
    x_adjacency = keras.layers.Reshape(adjacency_shape)(x_adjacency)
    # Symmetrify tensors in the last two dimensions
    x_adjacency = (x_adjacency + tf.transpose(x_adjacency, (0, 1, 3, 2))) / 2
    x_adjacency = keras.layers.Softmax(axis=1)(x_adjacency)

    # Map outputs of previous layer (x) to [continuous] feature tensors (x_features)
    x_features = keras.layers.Dense(tf.math.reduce_prod(feature_shape))(x)
    x_features = keras.layers.Reshape(feature_shape)(x_features)
    x_features = keras.layers.Softmax(axis=2)(x_features)

    return keras.Model(inputs=z, outputs=[x_adjacency, x_features], name="Generator")

with tf.device('/GPU:0'):
    generator = GraphGenerator(
        dense_units=[128, 256, 512,1024,2048, 4096],
        dropout_rate=0.50,
        latent_dim=LATENT_DIM,
        adjacency_shape=(BOND_DIM, NUM_ATOMS, NUM_ATOMS),
        feature_shape=(NUM_ATOMS, ATOM_DIM),
    )
generator.summary()
# Out:
# Model: "Generator"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_4 (InputLayer)           [(None, 256)]        0           []
#
#  dense_11 (Dense)               (None, 128)          32896       ['input_4[0][0]']
#
#  dropout_8 (Dropout)            (None, 128)          0           ['dense_11[0][0]']
#
#  dense_12 (Dense)               (None, 256)          33024       ['dropout_8[0][0]']
#
#  dropout_9 (Dropout)            (None, 256)          0           ['dense_12[0][0]']
#
#  dense_13 (Dense)               (None, 512)          131584      ['dropout_9[0][0]']
#
#  dropout_10 (Dropout)           (None, 512)          0           ['dense_13[0][0]']
#
#  dense_14 (Dense)               (None, 1024)         525312      ['dropout_10[0][0]']
#
#  dropout_11 (Dropout)           (None, 1024)         0           ['dense_14[0][0]']
#
#  dense_15 (Dense)               (None, 2048)         2099200     ['dropout_11[0][0]']
#
#  dropout_12 (Dropout)           (None, 2048)         0           ['dense_15[0][0]']
#
#  dense_16 (Dense)               (None, 4096)         8392704     ['dropout_12[0][0]']
#
#  dropout_13 (Dropout)           (None, 4096)         0           ['dense_16[0][0]']
#
#  dense_17 (Dense)               (None, 19845)        81304965    ['dropout_13[0][0]']
#
#  reshape_2 (Reshape)            (None, 5, 63, 63)    0           ['dense_17[0][0]']
#
#  tf.compat.v1.transpose_1 (TFOp  (None, 5, 63, 63)   0           ['reshape_2[0][0]']
#  Lambda)
#
#  tf.__operators__.add_1 (TFOpLa  (None, 5, 63, 63)   0           ['reshape_2[0][0]',
#  mbda)                                                            'tf.compat.v1.transpose_1[0][0]'
#                                                                  ]
#
#  dense_18 (Dense)               (None, 693)          2839221     ['dropout_13[0][0]']
#
#  tf.math.truediv_1 (TFOpLambda)  (None, 5, 63, 63)   0           ['tf.__operators__.add_1[0][0]']
#
#  reshape_3 (Reshape)            (None, 63, 11)       0           ['dense_18[0][0]']
#
#  softmax_2 (Softmax)            (None, 5, 63, 63)    0           ['tf.math.truediv_1[0][0]']
#
#  softmax_3 (Softmax)            (None, 63, 11)       0           ['reshape_3[0][0]']
#
# ==================================================================================================
# Total params: 95,358,906
# Trainable params: 95,358,906
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
class RelationalGraphConvLayer(keras.layers.Layer):
    def __init__(
        self,
        units=128,  # 128
        activation="relu",
        use_bias=False,
        kernel_initializer="glorot_uniform",
        bias_initializer="zeros",
        kernel_regularizer=None,
        bias_regularizer=None,
        **kwargs
    ):
        super().__init__(**kwargs)

        self.units = units
        self.activation = keras.activations.get(activation)
        self.use_bias = use_bias
        self.kernel_initializer = keras.initializers.get(kernel_initializer)
        self.bias_initializer = keras.initializers.get(bias_initializer)
        self.kernel_regularizer = keras.regularizers.get(kernel_regularizer)
        self.bias_regularizer = keras.regularizers.get(bias_regularizer)

    def build(self, input_shape):
        bond_dim = input_shape[0][1]
        atom_dim = input_shape[1][2]

        self.kernel = self.add_weight(
            shape=(bond_dim, atom_dim, self.units),
            initializer=self.kernel_initializer,
            regularizer=self.kernel_regularizer,
            trainable=True,
            name="W",
            dtype=tf.float32,
        )

        if self.use_bias:
            self.bias = self.add_weight(
                shape=(bond_dim, 1, self.units),
                initializer=self.bias_initializer,
                regularizer=self.bias_regularizer,
                trainable=True,
                name="b",
                dtype=tf.float32,
            )

        self.built = True

    def call(self, inputs, training=False):
        adjacency, features = inputs
        # Aggregate information from neighbors
        x = tf.matmul(adjacency, features[:, None, :, :])
        # Apply linear transformation
        x = tf.matmul(x, self.kernel)
        if self.use_bias:
            x += self.bias
        # Reduce bond types dim
        x_reduced = tf.reduce_sum(x, axis=1)
        # Apply non-linear transformation
        return self.activation(x_reduced)


def GraphDiscriminator(
    gconv_units, dense_units, dropout_rate, adjacency_shape, feature_shape
):

    adjacency = keras.layers.Input(shape=adjacency_shape)
    features = keras.layers.Input(shape=feature_shape)

    # Propagate through one or more graph convolutional layers
    features_transformed = features
    for units in gconv_units:
        features_transformed = RelationalGraphConvLayer(units)(
            [adjacency, features_transformed]
        )

    # Reduce 2-D representation of molecule to 1-D
    x = keras.layers.GlobalAveragePooling1D()(features_transformed)

    # Propagate through one or more densely connected layers
    for units in dense_units:
        x = keras.layers.Dense(units, activation="relu")(x)
        x = keras.layers.Dropout(dropout_rate)(x)

    # For each molecule, output a single scalar value expressing the "realness" of the inputted molecule
    x_out = keras.layers.Dense(1, dtype="float32")(x)

    return keras.Model(inputs=[adjacency, features], outputs=x_out)

with tf.device('/GPU:0'):
    discriminator = GraphDiscriminator(
        gconv_units= [512, 512, 512, 512], 
        dense_units= [4096, 4096],
        dropout_rate=0.50,
        adjacency_shape=(BOND_DIM, NUM_ATOMS, NUM_ATOMS),
        feature_shape=(NUM_ATOMS, ATOM_DIM),
    )
discriminator.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_5 (InputLayer)           [(None, 5, 63, 63)]  0           []
#
#  input_6 (InputLayer)           [(None, 63, 11)]     0           []
#
#  relational_graph_conv_layer_4   (None, 63, 512)     28160       ['input_5[0][0]',
#  (RelationalGraphConvLayer)                                       'input_6[0][0]']
#
#  relational_graph_conv_layer_5   (None, 63, 512)     1310720     ['input_5[0][0]',
#  (RelationalGraphConvLayer)                                       'relational_graph_conv_layer_4[0
#                                                                  ][0]']
#
#  relational_graph_conv_layer_6   (None, 63, 512)     1310720     ['input_5[0][0]',
#  (RelationalGraphConvLayer)                                       'relational_graph_conv_layer_5[0
#                                                                  ][0]']
#
#  relational_graph_conv_layer_7   (None, 63, 512)     1310720     ['input_5[0][0]',
#  (RelationalGraphConvLayer)                                       'relational_graph_conv_layer_6[0
#                                                                  ][0]']
#
#  global_average_pooling1d_1 (Gl  (None, 512)         0           ['relational_graph_conv_layer_7[0
#  obalAveragePooling1D)                                           ][0]']
#
#  dense_19 (Dense)               (None, 4096)         2101248     ['global_average_pooling1d_1[0][0
#                                                                  ]']
#
#  dropout_14 (Dropout)           (None, 4096)         0           ['dense_19[0][0]']
#
#  dense_20 (Dense)               (None, 4096)         16781312    ['dropout_14[0][0]']
#
#  dropout_15 (Dropout)           (None, 4096)         0           ['dense_20[0][0]']
#
#  dense_21 (Dense)               (None, 1)            4097        ['dropout_15[0][0]']
#
# ==================================================================================================
# Total params: 22,846,977
# Trainable params: 22,846,977
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
class GraphWGAN(keras.Model):
    def __init__(
        self,
        generator,
        discriminator,
        discriminator_steps=4,
        generator_steps=1,
        gp_weight=10,
        **kwargs
    ):
        super().__init__(**kwargs)
        self.generator = generator
        self.discriminator = discriminator
        self.discriminator_steps = discriminator_steps
        self.generator_steps = generator_steps
        self.gp_weight = gp_weight
        self.latent_dim = self.generator.input_shape[-1]
        self.epoch = 0
        self.num_samples = 1
        self.metric_wgan_gen_loss = keras.metrics.Mean(name="wgan_gen_loss")

    def compile(self, optimizer_generator, optimizer_discriminator, **kwargs):
        super().compile(**kwargs)
        self.optimizer_generator = optimizer_generator
        self.optimizer_discriminator = optimizer_discriminator
        self.metric_generator = keras.metrics.Mean(name="loss_gen")
        self.metric_discriminator = keras.metrics.Mean(name="loss_dis")

    # code to train

    def train_step(self, inputs):
        start_time = time.time()

        if isinstance(inputs[0], tuple):
            inputs = inputs[0]

        graph_real = inputs
        self.batch_size = tf.shape(inputs[0])[0]

        # Train the discriminator for one or more steps
        for _ in range(self.discriminator_steps):
            z = tf.random.normal((self.batch_size, self.latent_dim))
            with tf.GradientTape() as tape:
                graph_generated = self.generator(z, training=True)
                loss = self._loss_discriminator(graph_real, graph_generated)
            grads = tape.gradient(loss, self.discriminator.trainable_weights)
            self.optimizer_discriminator.apply_gradients(zip(grads, self.discriminator.trainable_weights))
            self.metric_discriminator.update_state(loss)

        # Train the generator for one or more steps
        for _ in range(self.generator_steps):
            z = tf.random.normal((self.batch_size, self.latent_dim))

            with tf.GradientTape() as tape:
                graph_generated = self.generator(z, training=True)
                loss_wgan_generator = self._loss_generator(graph_generated)
                self.metric_wgan_gen_loss.update_state(loss_wgan_generator)
            grads = tape.gradient(loss_wgan_generator, self.generator.trainable_weights)
            self.optimizer_generator.apply_gradients(zip(grads, self.generator.trainable_weights))
            self.metric_generator.update_state(loss_wgan_generator)

        # end_time = time.time()
        # time_per_epoch = end_time - start_time

        # cpu_usage = get_cpu_usage()

        logs = {m.name: m.result() for m in self.metrics}
        # logs['time'] = time_per_epoch
        # logs['cpu_usage'] = cpu_usage

        return logs

    def _loss_discriminator(self, graph_real, graph_generated):
        logits_real = self.discriminator(graph_real, training=True)
        logits_generated = self.discriminator(graph_generated, training=True)
        loss = tf.reduce_mean(logits_generated) - tf.reduce_mean(logits_real)
        loss_gp = self._gradient_penalty(graph_real, graph_generated)
        return loss + loss_gp * self.gp_weight

    def _loss_generator(self, graph_generated):
        logits_generated = self.discriminator(graph_generated, training=True)
        return -tf.reduce_mean(logits_generated)

    def _gradient_penalty(self, graph_real, graph_generated):
        # Unpack graphs
        adjacency_real, features_real = graph_real
        adjacency_generated, features_generated = graph_generated

        # Generate interpolated graphs (adjacency_interp and features_interp)
        alpha = tf.random.uniform([self.batch_size])
        alpha = tf.reshape(alpha, (self.batch_size, 1, 1, 1))
        adjacency_interp = (adjacency_real * alpha) + (1 - alpha) * adjacency_generated
        alpha = tf.reshape(alpha, (self.batch_size, 1, 1))
        features_interp = (features_real * alpha) + (1 - alpha) * features_generated

        # Compute the logits of interpolated graphs
        with tf.GradientTape() as tape:
            tape.watch(adjacency_interp)
            tape.watch(features_interp)
            logits = self.discriminator(
                [adjacency_interp, features_interp], training=True
            )

        # Compute the gradients with respect to the interpolated graphs
        grads = tape.gradient(logits, [adjacency_interp, features_interp])
        # Compute the gradient penalty
        grads_adjacency_penalty = (1 - tf.norm(grads[0], axis=1)) ** 2
        grads_features_penalty = (1 - tf.norm(grads[1], axis=2)) ** 2
        return tf.reduce_mean(
            tf.reduce_mean(grads_adjacency_penalty, axis=(-2, -1))
            + tf.reduce_mean(grads_features_penalty, axis=(-1))
        )

    def save_model(self, folder_path="models/MedGAN"):
        if not os.path.exists(folder_path):
            os.makedirs(folder_path)
        self.generator.save(os.path.join(folder_path, "generator"))
        self.discriminator.save(os.path.join(folder_path, "discriminator"))

    def load_model(self, folder_path="models/MedGAN"):
        self.generator = keras.models.load_model(os.path.join(folder_path, "generator"))
        self.discriminator = keras.models.load_model(os.path.join(folder_path, "discriminator"))

# %%
with tf.device('/GPU:0'):
    wgan = GraphWGAN(generator, discriminator, discriminator_steps=1)

with tf.device('/GPU:0'):
    wgan.compile(
        optimizer_generator=keras.optimizers.RMSprop(1e-4),
        optimizer_discriminator=keras.optimizers.RMSprop(1e-4)
    )

# %%
with tf.device('/GPU:0'):
    bond_tensors = torch.load("data/bond_tensors.pt")
    bond_tensors = bond_tensors.numpy()
    bond_tensors = bond_tensors.reshape(3208, 5, 63, 63)
    print(bond_tensors.shape)
    atomic_tensors = torch.load("data/atomic_number_tensors.pt")
    atomic_tensors = atomic_tensors.numpy()
# Out:
# (3208, 5, 63, 63)

# %%
def data_generator(adjacency_tensor, feature_tensor, batch_size):
    dataset_size = len(adjacency_tensor)
    indices = np.arange(dataset_size)
    while True:
        # Shuffle indices at the start of each epoch
        #np.random.shuffle(indices)
        for i in range(0, dataset_size, batch_size):
            batch_indices = indices[i: min(i + batch_size, dataset_size)]
            batch_adjacency_tensor = adjacency_tensor[batch_indices]
            batch_feature_tensor = feature_tensor[batch_indices]
            yield [batch_adjacency_tensor, batch_feature_tensor]

# %%
batch_size = 32
with tf.device('/GPU:0'):
    data_gen = data_generator(bond_tensors, atomic_tensors, batch_size)

# %%
steps_per_epoch = len(atomic_tensors) // batch_size
if len(atomic_tensors) % batch_size != 0:
    steps_per_epoch += 1

with tf.device('/GPU:0'):
    # Train the model
    wgan.fit(
        data_gen,
        epochs=300,
        steps_per_epoch=steps_per_epoch
    )
# Out:
# 2024-04-17 01:31:33.964919: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# Epoch 1/300
# 101/101 [==============================] - 16s 41ms/step - wgan_gen_loss: 2.8300 - loss_gen: 2.8300 - loss_dis: 473.9540
# Epoch 2/300
# 101/101 [==============================] - 4s 41ms/step - wgan_gen_loss: -2.9686 - loss_gen: -2.9686 - loss_dis: 42.1990
# Epoch 3/300
# 101/101 [==============================] - 4s 40ms/step - wgan_gen_loss: 3.3282 - loss_gen: 3.3282 - loss_dis: 29.8331
# Epoch 4/300
# 101/101 [==============================] - 4s 40ms/step - wgan_gen_loss: 7.6923 - loss_gen: 7.6923 - loss_dis: 19.5191
# Epoch 5/300
# 101/101 [==============================] - 4s 41ms/step - wgan_gen_loss: 7.5694 - loss_gen: 7.5694 - loss_dis: 9.6508
# Epoch 6/300
# 101/101 [==============================] - 4s 40ms/step - wgan_gen_loss: 9.5465 - loss_gen: 9.5465 - loss_dis: 5.0613
# Epoch 7/300
# 101/101 [==============================] - 4s 40ms/step - wgan_gen_loss: 12.1275 - loss_gen: 12.1275 - loss_dis: -16.0885
# Epoch 8/300
# 101/101 [==============================] - 4s 41ms/step - wgan_gen_loss: 21.9894 - loss_gen: 21.9894 - loss_dis: -50.0755
# Epoch 9/300
# 101/101 [==============================] - 4s 41ms/step - wgan_gen_loss: 21.1960 - loss_gen: 21.1960 - loss_dis: -73.4818
# Epoch 10/300
# 101/101 [==============================] - 4s 40ms/step - wgan_gen_loss: 23.5570 - loss_gen: 23.5570 - loss_dis: -95.5098
# Epoch 11/300
# 101/101 [==============================] - 4s 41ms/step - wgan_gen_loss: 25.1130 - loss_gen: 25.1130 - loss_dis: -113.4670
# Epoch 12/300
# 101/101 [==============================] - 4s 40ms/step - wgan_gen_loss: 27.2705 - loss_gen: 27.2705 - loss_dis: -131.7984
# Epoch 13/300
# 101/101 [==============================] - 4s 40ms/step - wgan_gen_loss: 26.8469 - loss_gen: 26.8469 - loss_dis: -151.8838
# Epoch 14/300
# 101/101 [==============================] - 4s 40ms/step - wgan_gen_loss: 28.2479 - loss_gen: 28.2479 - loss_dis: -166.5695
# Epoch 15/300
# 101/101 [==============================] - 4s 40ms/step - wgan_gen_loss: 29.8137 - loss_gen: 29.8137 - loss_dis: -178.8319
# Epoch 16/300
# 101/101 [==============================] - 4s 41ms/step - wgan_gen_loss: 32.2677 - loss_gen: 32.2677 - loss_dis: -179.9527
# Epoch 17/300
# 101/101 [==============================] - 4s 40ms/step - wgan_gen_loss: 30.2095 - loss_gen: 30.2095 - loss_dis: -181.9032
# Epoch 18/300
# 101/101 [==============================] - 4s 41ms/step - wgan_gen_loss: 33.0087 - loss_gen: 33.0087 - loss_dis: -189.0903
# Epoch 19/300
# 101/101 [==============================] - 4s 40ms/step - wgan_gen_loss: 33.9002 - loss_gen: 33.9002 - loss_dis: -203.2493
# Epoch 20/300
# 101/101 [==============================] - 4s 40ms/step - wgan_gen_loss: 31.6993 - loss_gen: 31.6993 - loss_dis: -208.1871
# Epoch 21/300
# 101/101 [==============================] - 4s 41ms/step - wgan_gen_loss: 32.8090 - loss_gen: 32.8090 - loss_dis: -206.3723
# Epoch 22/300
# 101/101 [==============================] - 4s 41ms/step - wgan_gen_loss: 31.6578 - loss_gen: 31.6578 - loss_dis: -216.6495
# Epoch 23/300
# 101/101 [==============================] - 4s 40ms/step - wgan_gen_loss: 35.9129 - loss_gen: 35.9129 - loss_dis: -223.7591
# Epoch 24/300
# 101/101 [==============================] - 4s 44ms/step - wgan_gen_loss: 34.0377 - loss_gen: 34.0377 - loss_dis: -221.5231
# Epoch 25/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 38.7206 - loss_gen: 38.7206 - loss_dis: -228.9394
# Epoch 26/300
# 101/101 [==============================] - 5s 47ms/step - wgan_gen_loss: 34.3833 - loss_gen: 34.3833 - loss_dis: -237.2972
# Epoch 27/300
# 101/101 [==============================] - 5s 47ms/step - wgan_gen_loss: 35.6432 - loss_gen: 35.6432 - loss_dis: -236.6358
# Epoch 28/300
# 101/101 [==============================] - 5s 46ms/step - wgan_gen_loss: 38.2755 - loss_gen: 38.2755 - loss_dis: -243.0119
# Epoch 29/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 39.2549 - loss_gen: 39.2549 - loss_dis: -239.3280
# Epoch 30/300
# 101/101 [==============================] - 5s 49ms/step - wgan_gen_loss: 37.8946 - loss_gen: 37.8946 - loss_dis: -236.7687
# Epoch 31/300
# 101/101 [==============================] - 5s 52ms/step - wgan_gen_loss: 37.6550 - loss_gen: 37.6550 - loss_dis: -239.0895
# Epoch 32/300
# 101/101 [==============================] - 5s 47ms/step - wgan_gen_loss: 40.5290 - loss_gen: 40.5290 - loss_dis: -249.5383
# Epoch 33/300
# 101/101 [==============================] - 5s 46ms/step - wgan_gen_loss: 40.1084 - loss_gen: 40.1084 - loss_dis: -247.9251
# Epoch 34/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 40.3368 - loss_gen: 40.3368 - loss_dis: -248.5286
# Epoch 35/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 42.2371 - loss_gen: 42.2371 - loss_dis: -242.1548
# Epoch 36/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 39.9075 - loss_gen: 39.9075 - loss_dis: -248.2486
# Epoch 37/300
# 101/101 [==============================] - 5s 47ms/step - wgan_gen_loss: 39.4804 - loss_gen: 39.4804 - loss_dis: -245.9794
# Epoch 38/300
# 101/101 [==============================] - 5s 46ms/step - wgan_gen_loss: 39.4859 - loss_gen: 39.4859 - loss_dis: -253.3651
# Epoch 39/300
# 101/101 [==============================] - 5s 47ms/step - wgan_gen_loss: 43.5084 - loss_gen: 43.5084 - loss_dis: -248.3147
# Epoch 40/300
# 101/101 [==============================] - 5s 49ms/step - wgan_gen_loss: 41.8412 - loss_gen: 41.8412 - loss_dis: -255.9700
# Epoch 41/300
# 101/101 [==============================] - 5s 47ms/step - wgan_gen_loss: 41.9997 - loss_gen: 41.9997 - loss_dis: -246.0983
# Epoch 42/300
# 101/101 [==============================] - 5s 46ms/step - wgan_gen_loss: 41.2511 - loss_gen: 41.2511 - loss_dis: -245.8983
# Epoch 43/300
# 101/101 [==============================] - 5s 47ms/step - wgan_gen_loss: 42.3934 - loss_gen: 42.3934 - loss_dis: -266.8920
# Epoch 44/300
# 101/101 [==============================] - 5s 47ms/step - wgan_gen_loss: 43.1915 - loss_gen: 43.1915 - loss_dis: -268.1689
# Epoch 45/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 39.8209 - loss_gen: 39.8209 - loss_dis: -256.9948
# Epoch 46/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 43.9631 - loss_gen: 43.9631 - loss_dis: -261.1932
# Epoch 47/300
# 101/101 [==============================] - 5s 46ms/step - wgan_gen_loss: 41.1626 - loss_gen: 41.1626 - loss_dis: -259.8636
# Epoch 48/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 43.1829 - loss_gen: 43.1829 - loss_dis: -263.6439
# Epoch 49/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 42.7950 - loss_gen: 42.7950 - loss_dis: -258.9090
# Epoch 50/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 45.5590 - loss_gen: 45.5590 - loss_dis: -255.6670
# Epoch 51/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 42.4286 - loss_gen: 42.4286 - loss_dis: -268.2581
# Epoch 52/300
# 101/101 [==============================] - 5s 45ms/step - wgan_gen_loss: 44.2778 - loss_gen: 44.2778 - loss_dis: -263.1950
# Epoch 53/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 44.2763 - loss_gen: 44.2763 - loss_dis: -258.8284
# Epoch 54/300
# 101/101 [==============================] - 5s 47ms/step - wgan_gen_loss: 44.1587 - loss_gen: 44.1587 - loss_dis: -266.6495
# Epoch 55/300
# 101/101 [==============================] - 5s 49ms/step - wgan_gen_loss: 42.9585 - loss_gen: 42.9585 - loss_dis: -270.1559
# Epoch 56/300
# 101/101 [==============================] - 5s 47ms/step - wgan_gen_loss: 43.3079 - loss_gen: 43.3079 - loss_dis: -256.5496
# Epoch 57/300
# 101/101 [==============================] - 5s 46ms/step - wgan_gen_loss: 44.2367 - loss_gen: 44.2367 - loss_dis: -271.9315
# Epoch 58/300
# 101/101 [==============================] - 5s 49ms/step - wgan_gen_loss: 46.1476 - loss_gen: 46.1476 - loss_dis: -274.7958
# Epoch 59/300
# 101/101 [==============================] - 5s 47ms/step - wgan_gen_loss: 45.5577 - loss_gen: 45.5577 - loss_dis: -263.8553
# Epoch 60/300
# 101/101 [==============================] - 5s 49ms/step - wgan_gen_loss: 45.5244 - loss_gen: 45.5244 - loss_dis: -270.6654
# Epoch 61/300
# 101/101 [==============================] - 5s 45ms/step - wgan_gen_loss: 44.4656 - loss_gen: 44.4656 - loss_dis: -263.5668
# Epoch 62/300
# 101/101 [==============================] - 5s 49ms/step - wgan_gen_loss: 44.1693 - loss_gen: 44.1693 - loss_dis: -271.8780
# Epoch 63/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 46.1593 - loss_gen: 46.1593 - loss_dis: -256.1430
# Epoch 64/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 44.6430 - loss_gen: 44.6430 - loss_dis: -265.6702
# Epoch 65/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 43.9693 - loss_gen: 43.9693 - loss_dis: -277.0779
# Epoch 66/300
# 101/101 [==============================] - 5s 45ms/step - wgan_gen_loss: 45.0762 - loss_gen: 45.0762 - loss_dis: -275.8359
# Epoch 67/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 44.5529 - loss_gen: 44.5529 - loss_dis: -278.5926
# Epoch 68/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 45.8805 - loss_gen: 45.8805 - loss_dis: -262.3080
# Epoch 69/300
# 101/101 [==============================] - 5s 49ms/step - wgan_gen_loss: 44.7528 - loss_gen: 44.7528 - loss_dis: -279.1071
# Epoch 70/300
# 101/101 [==============================] - 5s 45ms/step - wgan_gen_loss: 44.0187 - loss_gen: 44.0187 - loss_dis: -286.9447
# Epoch 71/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 46.2341 - loss_gen: 46.2341 - loss_dis: -259.1398
# Epoch 72/300
# 101/101 [==============================] - 5s 47ms/step - wgan_gen_loss: 45.8677 - loss_gen: 45.8677 - loss_dis: -267.4728
# Epoch 73/300
# 101/101 [==============================] - 5s 49ms/step - wgan_gen_loss: 43.1479 - loss_gen: 43.1479 - loss_dis: -288.1986
# Epoch 74/300
# 101/101 [==============================] - 5s 49ms/step - wgan_gen_loss: 44.0797 - loss_gen: 44.0797 - loss_dis: -282.3434
# Epoch 75/300
# 101/101 [==============================] - 5s 45ms/step - wgan_gen_loss: 43.5292 - loss_gen: 43.5292 - loss_dis: -276.6907
# Epoch 76/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 45.8667 - loss_gen: 45.8667 - loss_dis: -290.6020
# Epoch 77/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 46.4402 - loss_gen: 46.4402 - loss_dis: -274.4309
# Epoch 78/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 44.2408 - loss_gen: 44.2408 - loss_dis: -283.5651
# Epoch 79/300
# 101/101 [==============================] - 5s 46ms/step - wgan_gen_loss: 45.0398 - loss_gen: 45.0398 - loss_dis: -276.1361
# Epoch 80/300
# 101/101 [==============================] - 5s 49ms/step - wgan_gen_loss: 45.0013 - loss_gen: 45.0013 - loss_dis: -270.6396
# Epoch 81/300
# 101/101 [==============================] - 5s 47ms/step - wgan_gen_loss: 43.9964 - loss_gen: 43.9964 - loss_dis: -278.3293
# Epoch 82/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 44.9387 - loss_gen: 44.9387 - loss_dis: -271.8300
# Epoch 83/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 45.9680 - loss_gen: 45.9680 - loss_dis: -285.6535
# Epoch 84/300
# 101/101 [==============================] - 5s 46ms/step - wgan_gen_loss: 44.9800 - loss_gen: 44.9800 - loss_dis: -274.4734
# Epoch 85/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 45.6631 - loss_gen: 45.6631 - loss_dis: -281.1582
# Epoch 86/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 46.2317 - loss_gen: 46.2317 - loss_dis: -291.6353
# Epoch 87/300
# 101/101 [==============================] - 5s 49ms/step - wgan_gen_loss: 45.6482 - loss_gen: 45.6482 - loss_dis: -288.6556
# Epoch 88/300
# 101/101 [==============================] - 5s 47ms/step - wgan_gen_loss: 43.6031 - loss_gen: 43.6031 - loss_dis: -273.9985
# Epoch 89/300
# 101/101 [==============================] - 5s 47ms/step - wgan_gen_loss: 46.6304 - loss_gen: 46.6304 - loss_dis: -275.6301
# Epoch 90/300
# 101/101 [==============================] - 5s 47ms/step - wgan_gen_loss: 46.0189 - loss_gen: 46.0189 - loss_dis: -270.0157
# Epoch 91/300
# 101/101 [==============================] - 5s 49ms/step - wgan_gen_loss: 46.3104 - loss_gen: 46.3104 - loss_dis: -277.6616
# Epoch 92/300
# 101/101 [==============================] - 5s 49ms/step - wgan_gen_loss: 44.7629 - loss_gen: 44.7629 - loss_dis: -284.2144
# Epoch 93/300
# 101/101 [==============================] - 5s 45ms/step - wgan_gen_loss: 46.7744 - loss_gen: 46.7744 - loss_dis: -271.4787
# Epoch 94/300
# 101/101 [==============================] - 5s 49ms/step - wgan_gen_loss: 45.2581 - loss_gen: 45.2581 - loss_dis: -271.2600
# Epoch 95/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 45.5848 - loss_gen: 45.5848 - loss_dis: -268.9026
# Epoch 96/300
# 101/101 [==============================] - 5s 49ms/step - wgan_gen_loss: 45.8771 - loss_gen: 45.8771 - loss_dis: -265.0979
# Epoch 97/300
# 101/101 [==============================] - 5s 47ms/step - wgan_gen_loss: 46.1266 - loss_gen: 46.1266 - loss_dis: -278.6271
# Epoch 98/300
# 101/101 [==============================] - 5s 47ms/step - wgan_gen_loss: 48.8116 - loss_gen: 48.8116 - loss_dis: -292.2511
# Epoch 99/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 45.3724 - loss_gen: 45.3724 - loss_dis: -289.4094
# Epoch 100/300
# 101/101 [==============================] - 5s 49ms/step - wgan_gen_loss: 45.7558 - loss_gen: 45.7558 - loss_dis: -276.7515
# Epoch 101/300
# 101/101 [==============================] - 5s 49ms/step - wgan_gen_loss: 45.3110 - loss_gen: 45.3110 - loss_dis: -272.0262
# Epoch 102/300
# 101/101 [==============================] - 5s 45ms/step - wgan_gen_loss: 46.3852 - loss_gen: 46.3852 - loss_dis: -279.6127
# Epoch 103/300
# 101/101 [==============================] - 5s 49ms/step - wgan_gen_loss: 44.2635 - loss_gen: 44.2635 - loss_dis: -276.4779
# Epoch 104/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 45.9545 - loss_gen: 45.9545 - loss_dis: -293.7508
# Epoch 105/300
# 101/101 [==============================] - 5s 49ms/step - wgan_gen_loss: 45.6937 - loss_gen: 45.6937 - loss_dis: -287.9574
# Epoch 106/300
# 101/101 [==============================] - 5s 46ms/step - wgan_gen_loss: 46.9097 - loss_gen: 46.9097 - loss_dis: -287.1532
# Epoch 107/300
# 101/101 [==============================] - 5s 47ms/step - wgan_gen_loss: 47.3647 - loss_gen: 47.3647 - loss_dis: -275.1891
# Epoch 108/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 44.3149 - loss_gen: 44.3149 - loss_dis: -277.6147
# Epoch 109/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 44.3258 - loss_gen: 44.3258 - loss_dis: -278.4010
# Epoch 110/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 45.4998 - loss_gen: 45.4998 - loss_dis: -274.1992
# Epoch 111/300
# 101/101 [==============================] - 5s 46ms/step - wgan_gen_loss: 45.3257 - loss_gen: 45.3257 - loss_dis: -281.4157
# Epoch 112/300
# 101/101 [==============================] - 5s 49ms/step - wgan_gen_loss: 46.9616 - loss_gen: 46.9616 - loss_dis: -291.2283
# Epoch 113/300
# 101/101 [==============================] - 5s 47ms/step - wgan_gen_loss: 43.8302 - loss_gen: 43.8302 - loss_dis: -285.2238
# Epoch 114/300
# 101/101 [==============================] - 5s 49ms/step - wgan_gen_loss: 46.8292 - loss_gen: 46.8292 - loss_dis: -289.1424
# Epoch 115/300
# 101/101 [==============================] - 5s 46ms/step - wgan_gen_loss: 44.3412 - loss_gen: 44.3412 - loss_dis: -271.1291
# Epoch 116/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 46.4764 - loss_gen: 46.4764 - loss_dis: -267.4674
# Epoch 117/300
# 101/101 [==============================] - 5s 49ms/step - wgan_gen_loss: 46.0957 - loss_gen: 46.0957 - loss_dis: -288.9845
# Epoch 118/300
# 101/101 [==============================] - 5s 47ms/step - wgan_gen_loss: 44.4491 - loss_gen: 44.4491 - loss_dis: -277.1619
# Epoch 119/300
# 101/101 [==============================] - 5s 49ms/step - wgan_gen_loss: 47.7404 - loss_gen: 47.7404 - loss_dis: -276.0116
# Epoch 120/300
# 101/101 [==============================] - 5s 46ms/step - wgan_gen_loss: 47.7312 - loss_gen: 47.7312 - loss_dis: -278.1509
# Epoch 121/300
# 101/101 [==============================] - 5s 49ms/step - wgan_gen_loss: 48.3944 - loss_gen: 48.3944 - loss_dis: -279.0390
# Epoch 122/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 46.7861 - loss_gen: 46.7861 - loss_dis: -259.3454
# Epoch 123/300
# 101/101 [==============================] - 5s 50ms/step - wgan_gen_loss: 46.0543 - loss_gen: 46.0543 - loss_dis: -259.7535
# Epoch 124/300
# 101/101 [==============================] - 5s 49ms/step - wgan_gen_loss: 45.8011 - loss_gen: 45.8011 - loss_dis: -263.2413
# Epoch 125/300
# 101/101 [==============================] - 5s 47ms/step - wgan_gen_loss: 45.7329 - loss_gen: 45.7329 - loss_dis: -253.8215
# Epoch 126/300
# 101/101 [==============================] - 5s 49ms/step - wgan_gen_loss: 49.0631 - loss_gen: 49.0631 - loss_dis: -253.0729
# Epoch 127/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 50.0583 - loss_gen: 50.0583 - loss_dis: -261.2958
# Epoch 128/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 48.6618 - loss_gen: 48.6618 - loss_dis: -256.2534
# Epoch 129/300
# 101/101 [==============================] - 5s 45ms/step - wgan_gen_loss: 47.7302 - loss_gen: 47.7302 - loss_dis: -264.2965
# Epoch 130/300
# 101/101 [==============================] - 5s 49ms/step - wgan_gen_loss: 48.8318 - loss_gen: 48.8318 - loss_dis: -262.3468
# Epoch 131/300
# 101/101 [==============================] - 5s 49ms/step - wgan_gen_loss: 50.7369 - loss_gen: 50.7369 - loss_dis: -271.9547
# Epoch 132/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 48.1231 - loss_gen: 48.1231 - loss_dis: -257.5597
# Epoch 133/300
# 101/101 [==============================] - 5s 45ms/step - wgan_gen_loss: 49.8944 - loss_gen: 49.8944 - loss_dis: -262.6689
# Epoch 134/300
# 101/101 [==============================] - 5s 49ms/step - wgan_gen_loss: 48.0017 - loss_gen: 48.0017 - loss_dis: -265.3220
# Epoch 135/300
# 101/101 [==============================] - 5s 50ms/step - wgan_gen_loss: 48.2114 - loss_gen: 48.2114 - loss_dis: -255.8938
# Epoch 136/300
# 101/101 [==============================] - 5s 49ms/step - wgan_gen_loss: 48.7811 - loss_gen: 48.7811 - loss_dis: -252.6881
# Epoch 137/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 46.2553 - loss_gen: 46.2553 - loss_dis: -259.1873
# Epoch 138/300
# 101/101 [==============================] - 5s 46ms/step - wgan_gen_loss: 48.0673 - loss_gen: 48.0673 - loss_dis: -261.7033
# Epoch 139/300
# 101/101 [==============================] - 5s 49ms/step - wgan_gen_loss: 48.3724 - loss_gen: 48.3724 - loss_dis: -260.7092
# Epoch 140/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 47.6762 - loss_gen: 47.6762 - loss_dis: -264.0341
# Epoch 141/300
# 101/101 [==============================] - 5s 49ms/step - wgan_gen_loss: 49.3467 - loss_gen: 49.3467 - loss_dis: -267.4108
# Epoch 142/300
# 101/101 [==============================] - 5s 45ms/step - wgan_gen_loss: 44.6233 - loss_gen: 44.6233 - loss_dis: -269.5622
# Epoch 143/300
# 101/101 [==============================] - 5s 49ms/step - wgan_gen_loss: 47.6050 - loss_gen: 47.6050 - loss_dis: -263.3752
# Epoch 144/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 48.0741 - loss_gen: 48.0741 - loss_dis: -257.7278
# Epoch 145/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 47.0852 - loss_gen: 47.0852 - loss_dis: -261.5092
# Epoch 146/300
# 101/101 [==============================] - 5s 45ms/step - wgan_gen_loss: 46.5556 - loss_gen: 46.5556 - loss_dis: -253.4641
# Epoch 147/300
# 101/101 [==============================] - 6s 55ms/step - wgan_gen_loss: 47.4607 - loss_gen: 47.4607 - loss_dis: -265.5461
# Epoch 148/300
# 101/101 [==============================] - 5s 52ms/step - wgan_gen_loss: 48.2714 - loss_gen: 48.2714 - loss_dis: -269.1134
# Epoch 149/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 47.0620 - loss_gen: 47.0620 - loss_dis: -260.5550
# Epoch 150/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 44.8785 - loss_gen: 44.8785 - loss_dis: -261.6094
# Epoch 151/300
# 101/101 [==============================] - 5s 46ms/step - wgan_gen_loss: 46.5035 - loss_gen: 46.5035 - loss_dis: -264.1077
# Epoch 152/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 45.4392 - loss_gen: 45.4392 - loss_dis: -262.2122
# Epoch 153/300
# 101/101 [==============================] - 6s 55ms/step - wgan_gen_loss: 47.3358 - loss_gen: 47.3358 - loss_dis: -282.8246
# Epoch 154/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 48.7126 - loss_gen: 48.7126 - loss_dis: -278.4676
# Epoch 155/300
# 101/101 [==============================] - 5s 49ms/step - wgan_gen_loss: 46.7750 - loss_gen: 46.7750 - loss_dis: -272.0015
# Epoch 156/300
# 101/101 [==============================] - 5s 45ms/step - wgan_gen_loss: 46.7833 - loss_gen: 46.7833 - loss_dis: -267.7610
# Epoch 157/300
# 101/101 [==============================] - 5s 49ms/step - wgan_gen_loss: 45.6521 - loss_gen: 45.6521 - loss_dis: -267.8919
# Epoch 158/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 42.6027 - loss_gen: 42.6027 - loss_dis: -262.2036
# Epoch 159/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 45.6068 - loss_gen: 45.6068 - loss_dis: -264.9235
# Epoch 160/300
# 101/101 [==============================] - 5s 46ms/step - wgan_gen_loss: 43.3100 - loss_gen: 43.3100 - loss_dis: -266.1674
# Epoch 161/300
# 101/101 [==============================] - 5s 49ms/step - wgan_gen_loss: 45.7061 - loss_gen: 45.7061 - loss_dis: -266.2105
# Epoch 162/300
# 101/101 [==============================] - 5s 49ms/step - wgan_gen_loss: 44.8485 - loss_gen: 44.8485 - loss_dis: -277.3163
# Epoch 163/300
# 101/101 [==============================] - 5s 49ms/step - wgan_gen_loss: 43.9347 - loss_gen: 43.9347 - loss_dis: -268.1314
# Epoch 164/300
# 101/101 [==============================] - 6s 64ms/step - wgan_gen_loss: 46.2205 - loss_gen: 46.2205 - loss_dis: -274.8045
# Epoch 165/300
# 101/101 [==============================] - 5s 46ms/step - wgan_gen_loss: 43.6470 - loss_gen: 43.6470 - loss_dis: -266.3593
# Epoch 166/300
# 101/101 [==============================] - 5s 47ms/step - wgan_gen_loss: 42.2606 - loss_gen: 42.2606 - loss_dis: -257.1113
# Epoch 167/300
# 101/101 [==============================] - 5s 49ms/step - wgan_gen_loss: 42.5288 - loss_gen: 42.5288 - loss_dis: -268.0420
# Epoch 168/300
# 101/101 [==============================] - 5s 47ms/step - wgan_gen_loss: 43.2045 - loss_gen: 43.2045 - loss_dis: -269.1198
# Epoch 169/300
# 101/101 [==============================] - 5s 49ms/step - wgan_gen_loss: 45.1471 - loss_gen: 45.1471 - loss_dis: -276.4726
# Epoch 170/300
# 101/101 [==============================] - 5s 46ms/step - wgan_gen_loss: 43.0040 - loss_gen: 43.0040 - loss_dis: -275.2733
# Epoch 171/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 41.8113 - loss_gen: 41.8113 - loss_dis: -266.5964
# Epoch 172/300
# 101/101 [==============================] - 5s 49ms/step - wgan_gen_loss: 44.1858 - loss_gen: 44.1858 - loss_dis: -275.7273
# Epoch 173/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 42.3364 - loss_gen: 42.3364 - loss_dis: -268.1734
# Epoch 174/300
# 101/101 [==============================] - 5s 46ms/step - wgan_gen_loss: 42.2927 - loss_gen: 42.2927 - loss_dis: -267.5081
# Epoch 175/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 44.4013 - loss_gen: 44.4013 - loss_dis: -275.7870
# Epoch 176/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 42.4104 - loss_gen: 42.4104 - loss_dis: -271.2653
# Epoch 177/300
# 101/101 [==============================] - 5s 49ms/step - wgan_gen_loss: 41.6644 - loss_gen: 41.6644 - loss_dis: -279.1884
# Epoch 178/300
# 101/101 [==============================] - 5s 46ms/step - wgan_gen_loss: 42.8434 - loss_gen: 42.8434 - loss_dis: -273.4838
# Epoch 179/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 40.8748 - loss_gen: 40.8748 - loss_dis: -273.3599
# Epoch 180/300
# 101/101 [==============================] - 5s 49ms/step - wgan_gen_loss: 41.3352 - loss_gen: 41.3352 - loss_dis: -284.0121
# Epoch 181/300
# 101/101 [==============================] - 5s 49ms/step - wgan_gen_loss: 38.7553 - loss_gen: 38.7553 - loss_dis: -281.9215
# Epoch 182/300
# 101/101 [==============================] - 5s 45ms/step - wgan_gen_loss: 42.9954 - loss_gen: 42.9954 - loss_dis: -272.6953
# Epoch 183/300
# 101/101 [==============================] - 5s 49ms/step - wgan_gen_loss: 40.6603 - loss_gen: 40.6603 - loss_dis: -280.2167
# Epoch 184/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 42.0485 - loss_gen: 42.0485 - loss_dis: -276.2301
# Epoch 185/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 43.0460 - loss_gen: 43.0460 - loss_dis: -282.0879
# Epoch 186/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 42.2494 - loss_gen: 42.2494 - loss_dis: -275.8825
# Epoch 187/300
# 101/101 [==============================] - 5s 47ms/step - wgan_gen_loss: 41.4686 - loss_gen: 41.4686 - loss_dis: -277.3593
# Epoch 188/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 40.2815 - loss_gen: 40.2815 - loss_dis: -268.1349
# Epoch 189/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 43.6524 - loss_gen: 43.6524 - loss_dis: -273.2380
# Epoch 190/300
# 101/101 [==============================] - 5s 46ms/step - wgan_gen_loss: 42.2213 - loss_gen: 42.2213 - loss_dis: -260.4913
# Epoch 191/300
# 101/101 [==============================] - 5s 46ms/step - wgan_gen_loss: 40.0752 - loss_gen: 40.0752 - loss_dis: -288.3602
# Epoch 192/300
# 101/101 [==============================] - 5s 49ms/step - wgan_gen_loss: 40.6086 - loss_gen: 40.6086 - loss_dis: -270.7463
# Epoch 193/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 41.7428 - loss_gen: 41.7428 - loss_dis: -272.4563
# Epoch 194/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 39.2005 - loss_gen: 39.2005 - loss_dis: -266.0674
# Epoch 195/300
# 101/101 [==============================] - 5s 46ms/step - wgan_gen_loss: 42.0158 - loss_gen: 42.0158 - loss_dis: -281.8004
# Epoch 196/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 42.7362 - loss_gen: 42.7362 - loss_dis: -273.1032
# Epoch 197/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 40.9627 - loss_gen: 40.9627 - loss_dis: -270.4243
# Epoch 198/300
# 101/101 [==============================] - 5s 50ms/step - wgan_gen_loss: 39.9261 - loss_gen: 39.9261 - loss_dis: -272.3769
# Epoch 199/300
# 101/101 [==============================] - 5s 46ms/step - wgan_gen_loss: 39.3150 - loss_gen: 39.3150 - loss_dis: -275.7067
# Epoch 200/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 42.1877 - loss_gen: 42.1877 - loss_dis: -273.7432
# Epoch 201/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 37.4605 - loss_gen: 37.4605 - loss_dis: -279.8090
# Epoch 202/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 40.6988 - loss_gen: 40.6988 - loss_dis: -292.5041
# Epoch 203/300
# 101/101 [==============================] - 5s 47ms/step - wgan_gen_loss: 40.3493 - loss_gen: 40.3493 - loss_dis: -266.3073
# Epoch 204/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 37.3095 - loss_gen: 37.3095 - loss_dis: -281.9821
# Epoch 205/300
# 101/101 [==============================] - 5s 49ms/step - wgan_gen_loss: 39.2629 - loss_gen: 39.2629 - loss_dis: -275.3439
# Epoch 206/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 40.9151 - loss_gen: 40.9151 - loss_dis: -277.6196
# Epoch 207/300
# 101/101 [==============================] - 5s 46ms/step - wgan_gen_loss: 40.6163 - loss_gen: 40.6163 - loss_dis: -272.9016
# Epoch 208/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 39.7425 - loss_gen: 39.7425 - loss_dis: -277.6244
# Epoch 209/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 39.4119 - loss_gen: 39.4119 - loss_dis: -275.6046
# Epoch 210/300
# 101/101 [==============================] - 5s 49ms/step - wgan_gen_loss: 40.1123 - loss_gen: 40.1123 - loss_dis: -282.4744
# Epoch 211/300
# 101/101 [==============================] - 5s 46ms/step - wgan_gen_loss: 39.7034 - loss_gen: 39.7034 - loss_dis: -282.1544
# Epoch 212/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 37.5333 - loss_gen: 37.5333 - loss_dis: -274.2958
# Epoch 213/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 38.0356 - loss_gen: 38.0356 - loss_dis: -275.9765
# Epoch 214/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 37.7582 - loss_gen: 37.7582 - loss_dis: -279.8258
# Epoch 215/300
# 101/101 [==============================] - 5s 47ms/step - wgan_gen_loss: 37.6429 - loss_gen: 37.6429 - loss_dis: -273.1723
# Epoch 216/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 38.7518 - loss_gen: 38.7518 - loss_dis: -288.3658
# Epoch 217/300
# 101/101 [==============================] - 5s 49ms/step - wgan_gen_loss: 35.9929 - loss_gen: 35.9929 - loss_dis: -270.9213
# Epoch 218/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 37.7384 - loss_gen: 37.7384 - loss_dis: -271.2616
# Epoch 219/300
# 101/101 [==============================] - 5s 46ms/step - wgan_gen_loss: 36.0457 - loss_gen: 36.0457 - loss_dis: -274.7321
# Epoch 220/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 37.1116 - loss_gen: 37.1116 - loss_dis: -269.9945
# Epoch 221/300
# 101/101 [==============================] - 5s 49ms/step - wgan_gen_loss: 36.5673 - loss_gen: 36.5673 - loss_dis: -286.2376
# Epoch 222/300
# 101/101 [==============================] - 5s 49ms/step - wgan_gen_loss: 36.3147 - loss_gen: 36.3147 - loss_dis: -279.2476
# Epoch 223/300
# 101/101 [==============================] - 5s 46ms/step - wgan_gen_loss: 36.4813 - loss_gen: 36.4813 - loss_dis: -282.6649
# Epoch 224/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 37.5946 - loss_gen: 37.5946 - loss_dis: -279.4968
# Epoch 225/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 38.9746 - loss_gen: 38.9746 - loss_dis: -267.9413
# Epoch 226/300
# 101/101 [==============================] - 5s 50ms/step - wgan_gen_loss: 37.2663 - loss_gen: 37.2663 - loss_dis: -267.0914
# Epoch 227/300
# 101/101 [==============================] - 5s 45ms/step - wgan_gen_loss: 35.6519 - loss_gen: 35.6519 - loss_dis: -283.8581
# Epoch 228/300
# 101/101 [==============================] - 5s 50ms/step - wgan_gen_loss: 34.9315 - loss_gen: 34.9315 - loss_dis: -288.7010
# Epoch 229/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 36.0343 - loss_gen: 36.0343 - loss_dis: -268.8369
# Epoch 230/300
# 101/101 [==============================] - 5s 49ms/step - wgan_gen_loss: 35.9779 - loss_gen: 35.9779 - loss_dis: -283.4405
# Epoch 231/300
# 101/101 [==============================] - 5s 46ms/step - wgan_gen_loss: 36.1528 - loss_gen: 36.1528 - loss_dis: -276.8207
# Epoch 232/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 36.1809 - loss_gen: 36.1809 - loss_dis: -290.4177
# Epoch 233/300
# 101/101 [==============================] - 5s 49ms/step - wgan_gen_loss: 36.2524 - loss_gen: 36.2524 - loss_dis: -272.8939
# Epoch 234/300
# 101/101 [==============================] - 5s 47ms/step - wgan_gen_loss: 37.4363 - loss_gen: 37.4363 - loss_dis: -294.1500
# Epoch 235/300
# 101/101 [==============================] - 5s 47ms/step - wgan_gen_loss: 37.8332 - loss_gen: 37.8332 - loss_dis: -278.1476
# Epoch 236/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 36.4336 - loss_gen: 36.4336 - loss_dis: -267.3828
# Epoch 237/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 34.1846 - loss_gen: 34.1846 - loss_dis: -274.6385
# Epoch 238/300
# 101/101 [==============================] - 5s 49ms/step - wgan_gen_loss: 32.8509 - loss_gen: 32.8509 - loss_dis: -271.8483
# Epoch 239/300
# 101/101 [==============================] - 5s 46ms/step - wgan_gen_loss: 31.6390 - loss_gen: 31.6390 - loss_dis: -266.5530
# Epoch 240/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 34.4073 - loss_gen: 34.4073 - loss_dis: -271.4527
# Epoch 241/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 35.5468 - loss_gen: 35.5468 - loss_dis: -262.2992
# Epoch 242/300
# 101/101 [==============================] - 5s 49ms/step - wgan_gen_loss: 34.6819 - loss_gen: 34.6819 - loss_dis: -285.3060
# Epoch 243/300
# 101/101 [==============================] - 5s 46ms/step - wgan_gen_loss: 34.4662 - loss_gen: 34.4662 - loss_dis: -278.5599
# Epoch 244/300
# 101/101 [==============================] - 5s 50ms/step - wgan_gen_loss: 33.5411 - loss_gen: 33.5411 - loss_dis: -273.7816
# Epoch 245/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 35.1123 - loss_gen: 35.1123 - loss_dis: -289.0776
# Epoch 246/300
# 101/101 [==============================] - 5s 49ms/step - wgan_gen_loss: 34.6879 - loss_gen: 34.6879 - loss_dis: -280.5124
# Epoch 247/300
# 101/101 [==============================] - 5s 47ms/step - wgan_gen_loss: 36.5056 - loss_gen: 36.5056 - loss_dis: -276.2885
# Epoch 248/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 36.1759 - loss_gen: 36.1759 - loss_dis: -280.3618
# Epoch 249/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 34.3956 - loss_gen: 34.3956 - loss_dis: -275.9152
# Epoch 250/300
# 101/101 [==============================] - 5s 49ms/step - wgan_gen_loss: 34.8664 - loss_gen: 34.8664 - loss_dis: -268.2525
# Epoch 251/300
# 101/101 [==============================] - 5s 47ms/step - wgan_gen_loss: 35.2683 - loss_gen: 35.2683 - loss_dis: -274.7135
# Epoch 252/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 37.6785 - loss_gen: 37.6785 - loss_dis: -277.0675
# Epoch 253/300
# 101/101 [==============================] - 5s 49ms/step - wgan_gen_loss: 34.5871 - loss_gen: 34.5871 - loss_dis: -271.8669
# Epoch 254/300
# 101/101 [==============================] - 5s 47ms/step - wgan_gen_loss: 33.7057 - loss_gen: 33.7057 - loss_dis: -269.4443
# Epoch 255/300
# 101/101 [==============================] - 5s 47ms/step - wgan_gen_loss: 33.9335 - loss_gen: 33.9335 - loss_dis: -276.1935
# Epoch 256/300
# 101/101 [==============================] - 5s 49ms/step - wgan_gen_loss: 35.6516 - loss_gen: 35.6516 - loss_dis: -278.5539
# Epoch 257/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 35.1661 - loss_gen: 35.1661 - loss_dis: -273.3132
# Epoch 258/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 36.0288 - loss_gen: 36.0288 - loss_dis: -298.2471
# Epoch 259/300
# 101/101 [==============================] - 5s 47ms/step - wgan_gen_loss: 34.6981 - loss_gen: 34.6981 - loss_dis: -299.2625
# Epoch 260/300
# 101/101 [==============================] - 5s 49ms/step - wgan_gen_loss: 33.7910 - loss_gen: 33.7910 - loss_dis: -269.4432
# Epoch 261/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 34.4487 - loss_gen: 34.4487 - loss_dis: -272.8299
# Epoch 262/300
# 101/101 [==============================] - 5s 47ms/step - wgan_gen_loss: 35.7783 - loss_gen: 35.7783 - loss_dis: -286.0531
# Epoch 263/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 36.0457 - loss_gen: 36.0457 - loss_dis: -279.4196
# Epoch 264/300
# 101/101 [==============================] - 5s 49ms/step - wgan_gen_loss: 36.8327 - loss_gen: 36.8327 - loss_dis: -290.1903
# Epoch 265/300
# 101/101 [==============================] - 5s 49ms/step - wgan_gen_loss: 34.8782 - loss_gen: 34.8782 - loss_dis: -287.2706
# Epoch 266/300
# 101/101 [==============================] - 5s 46ms/step - wgan_gen_loss: 36.2564 - loss_gen: 36.2564 - loss_dis: -306.4625
# Epoch 267/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 34.5598 - loss_gen: 34.5598 - loss_dis: -289.7579
# Epoch 268/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 35.8631 - loss_gen: 35.8631 - loss_dis: -271.9732
# Epoch 269/300
# 101/101 [==============================] - 5s 49ms/step - wgan_gen_loss: 34.6179 - loss_gen: 34.6179 - loss_dis: -298.6358
# Epoch 270/300
# 101/101 [==============================] - 5s 47ms/step - wgan_gen_loss: 36.5520 - loss_gen: 36.5520 - loss_dis: -278.8867
# Epoch 271/300
# 101/101 [==============================] - 5s 49ms/step - wgan_gen_loss: 36.4404 - loss_gen: 36.4404 - loss_dis: -275.3016
# Epoch 272/300
# 101/101 [==============================] - 5s 49ms/step - wgan_gen_loss: 38.6182 - loss_gen: 38.6182 - loss_dis: -288.4644
# Epoch 273/300
# 101/101 [==============================] - 5s 50ms/step - wgan_gen_loss: 36.1187 - loss_gen: 36.1187 - loss_dis: -266.9842
# Epoch 274/300
# 101/101 [==============================] - 5s 46ms/step - wgan_gen_loss: 33.5497 - loss_gen: 33.5497 - loss_dis: -295.1562
# Epoch 275/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 34.3952 - loss_gen: 34.3952 - loss_dis: -290.2576
# Epoch 276/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 36.6339 - loss_gen: 36.6339 - loss_dis: -288.6266
# Epoch 277/300
# 101/101 [==============================] - 5s 49ms/step - wgan_gen_loss: 33.7153 - loss_gen: 33.7153 - loss_dis: -289.0604
# Epoch 278/300
# 101/101 [==============================] - 5s 47ms/step - wgan_gen_loss: 34.2512 - loss_gen: 34.2512 - loss_dis: -286.9915
# Epoch 279/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 35.1207 - loss_gen: 35.1207 - loss_dis: -292.9535
# Epoch 280/300
# 101/101 [==============================] - 5s 49ms/step - wgan_gen_loss: 35.1518 - loss_gen: 35.1518 - loss_dis: -281.1468
# Epoch 281/300
# 101/101 [==============================] - 5s 49ms/step - wgan_gen_loss: 36.6580 - loss_gen: 36.6580 - loss_dis: -289.9565
# Epoch 282/300
# 101/101 [==============================] - 5s 45ms/step - wgan_gen_loss: 33.8820 - loss_gen: 33.8820 - loss_dis: -292.1501
# Epoch 283/300
# 101/101 [==============================] - 5s 49ms/step - wgan_gen_loss: 36.7939 - loss_gen: 36.7939 - loss_dis: -292.5782
# Epoch 284/300
# 101/101 [==============================] - 5s 49ms/step - wgan_gen_loss: 33.1835 - loss_gen: 33.1835 - loss_dis: -283.7225
# Epoch 285/300
# 101/101 [==============================] - 5s 49ms/step - wgan_gen_loss: 35.5872 - loss_gen: 35.5872 - loss_dis: -295.0723
# Epoch 286/300
# 101/101 [==============================] - 5s 46ms/step - wgan_gen_loss: 35.1826 - loss_gen: 35.1826 - loss_dis: -296.6035
# Epoch 287/300
# 101/101 [==============================] - 5s 50ms/step - wgan_gen_loss: 35.0075 - loss_gen: 35.0075 - loss_dis: -279.2492
# Epoch 288/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 34.3894 - loss_gen: 34.3894 - loss_dis: -283.7202
# Epoch 289/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 34.9496 - loss_gen: 34.9496 - loss_dis: -293.8675
# Epoch 290/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 34.6008 - loss_gen: 34.6008 - loss_dis: -302.7066
# Epoch 291/300
# 101/101 [==============================] - 5s 49ms/step - wgan_gen_loss: 37.1188 - loss_gen: 37.1188 - loss_dis: -272.4798
# Epoch 292/300
# 101/101 [==============================] - 5s 49ms/step - wgan_gen_loss: 34.3677 - loss_gen: 34.3677 - loss_dis: -285.6130
# Epoch 293/300
# 101/101 [==============================] - 5s 46ms/step - wgan_gen_loss: 36.4725 - loss_gen: 36.4725 - loss_dis: -284.2531
# Epoch 294/300
# 101/101 [==============================] - 5s 50ms/step - wgan_gen_loss: 31.8677 - loss_gen: 31.8677 - loss_dis: -302.0578
# Epoch 295/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 33.8590 - loss_gen: 33.8590 - loss_dis: -277.2655
# Epoch 296/300
# 101/101 [==============================] - 5s 49ms/step - wgan_gen_loss: 34.7922 - loss_gen: 34.7922 - loss_dis: -288.5381
# Epoch 297/300
# 101/101 [==============================] - 5s 46ms/step - wgan_gen_loss: 31.8880 - loss_gen: 31.8880 - loss_dis: -305.2150
# Epoch 298/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 35.7166 - loss_gen: 35.7166 - loss_dis: -282.3306
# Epoch 299/300
# 101/101 [==============================] - 5s 48ms/step - wgan_gen_loss: 30.7593 - loss_gen: 30.7593 - loss_dis: -283.9933
# Epoch 300/300
# 101/101 [==============================] - 5s 49ms/step - wgan_gen_loss: 33.7603 - loss_gen: 33.7603 - loss_dis: -305.9205

# %%
z = tf.random.normal((batch_size, LATENT_DIM))
graph = generator.predict(z)
adjacency = tf.argmax(graph[0], axis=1)
adjacency = tf.one_hot(adjacency, depth=BOND_DIM, axis=1)
adjacency = tf.linalg.set_diag(adjacency, tf.zeros(tf.shape(adjacency)[:-1]))
features = tf.argmax(graph[1], axis=2)
features = tf.one_hot(features, depth=ATOM_DIM, axis=2)
molecules = []
none_counter = 0
# for i in tqdm(range(batch_size), desc="Generating molecules"):
#     try:
#         mol = 
#         molecules.append(mol)
#     except AtomValenceException:
#         molecules.append(None)
#         none_counter += 1  # Increment the counter

def save_model(self, folder_path="models/WGAN/"):
    if not os.path.exists(folder_path):
        os.makedirs(folder_path)
    self.generator.save(os.path.join(folder_path, "generator"))
    self.discriminator.save(os.path.join(folder_path, "discriminator"))
# Out:
# 1/1 [==============================] - 0s 59ms/step

# %%
wgan.save_model()
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 2024-04-17 01:58:12.435403: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,128]
# 	 [[{{node inputs}}]]
# 2024-04-17 01:58:12.458157: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,256]
# 	 [[{{node inputs}}]]
# 2024-04-17 01:58:12.480055: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,512]
# 	 [[{{node inputs}}]]
# 2024-04-17 01:58:12.489639: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,1024]
# 	 [[{{node inputs}}]]
# 2024-04-17 01:58:12.520129: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,2048]
# 	 [[{{node inputs}}]]
# 2024-04-17 01:58:12.529611: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,4096]
# 	 [[{{node inputs}}]]
# 2024-04-17 01:58:12.557926: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,19845]
# 	 [[{{node inputs}}]]
# 2024-04-17 01:58:12.564490: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,693]
# 	 [[{{node inputs}}]]
# 2024-04-17 01:58:13.103775: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,128]
# 	 [[{{node inputs}}]]
# 2024-04-17 01:58:13.141272: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,256]
# 	 [[{{node inputs}}]]
# 2024-04-17 01:58:13.202025: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,512]
# 	 [[{{node inputs}}]]
# 2024-04-17 01:58:13.237889: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,1024]
# 	 [[{{node inputs}}]]
# 2024-04-17 01:58:13.290465: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,2048]
# 	 [[{{node inputs}}]]
# 2024-04-17 01:58:13.330999: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,4096]
# 	 [[{{node inputs}}]]
# 2024-04-17 01:58:13.379262: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,19845]
# 	 [[{{node inputs}}]]
# 2024-04-17 01:58:13.429849: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,693]
# 	 [[{{node inputs}}]]
# INFO:tensorflow:Assets written to: models/MedGAN/generator/assets
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 2024-04-17 01:58:15.867414: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,4096]
# 	 [[{{node inputs}}]]
# 2024-04-17 01:58:15.892828: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,4096]
# 	 [[{{node inputs}}]]
# 2024-04-17 01:58:16.457307: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,4096]
# 	 [[{{node inputs}}]]
# 2024-04-17 01:58:16.495846: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,4096]
# 	 [[{{node inputs}}]]
# INFO:tensorflow:Assets written to: models/MedGAN/discriminator/assets

# %%
np.array(features)[:,:,-1].sum()/32
# Out:
# 31.375

# %%
np.array(adjacency).reshape((32,63,63,5))[:, :, :, -1].sum()
# Out:
# 25431.0

# %%
32*63*63
# Out:
# 127008

# %%
25042/32
# Out:
# 782.5625

# %%
def mol_sample(generator, batch_size):
    z = tf.random.normal((batch_size, LATENT_DIM))
    graph = generator.predict(z)
    adjacency = tf.argmax(graph[0], axis=1)
    adjacency = tf.one_hot(adjacency, depth=BOND_DIM, axis=1)
    adjacency = tf.linalg.set_diag(adjacency, tf.zeros(tf.shape(adjacency)[:-1]))
    features = tf.argmax(graph[1], axis=2)
    features = tf.one_hot(features, depth=ATOM_DIM, axis=2)
    molecules = []
    none_counter = 0
    for i in tqdm(range(batch_size), desc="Generating molecules"):
        try:
            mol = process_graph_data_to_data_objects(adjacency[i].numpy(), features[i].numpy())
            molecules.append(mol)
        except AtomValenceException:
            molecules.append(None)
            none_counter += 1  # Increment the counter
    return molecules, none_counter  # Return the counter

# %%
def process_graph_data_to_data_objects(adjacency, atoms, grad = False):
    num_nodes = NUM_ATOMS
    num_bond_types = BOND_DIM - 1  # Exclude 'no bond' type
    num_atom_types = ATOM_DIM - 1  # Exclude 'no atom' type

    adjacency = adjacency.reshape(NUM_ATOMS, NUM_ATOMS, BOND_DIM)
    adjacency = torch.tensor(adjacency)
    atoms = torch.tensor(atoms)
    
    data_objects = []

    edge_index = []
    edge_attr = []
    x = []
    node_index_map = {}
    
    new_idx = 0
    for i in range(num_nodes):
        atom_type_i = torch.argmax(atoms[i])
        if atom_type_i < num_atom_types:  # Ensure atom exists
            node_index_map[i] = new_idx
            # x.append(atoms[i, :num_atom_types])  # Add existing atom types only
            x.append(torch.nn.functional.one_hot(atom_type_i.clone().detach(), num_classes=num_atom_types).float())
            new_idx += 1

    for i in range(num_nodes):
        for j in range(i + 1, num_nodes):  # Only look at one direction to avoid duplicates
            if i in node_index_map and j in node_index_map:
                bond_type = torch.argmax(adjacency[i, j])
                # if adjacency[i,j][num_bond_types] > 0.2 or adjacency[i,j][bond_type] < 0.3:
                #     # print('overwrite')
                #     continue
                if bond_type < num_bond_types:  # Bond exists
                    edge_index.append([node_index_map[i], node_index_map[j]])
                    bond_one_hot = torch.zeros(num_bond_types)
                    bond_one_hot[bond_type] = 1
                    edge_attr.append(bond_type)
                    # print(bond_type)
                    # edge_attr.append(bond_type/num_bond_types)

    if edge_index:
        edge_index_tensor = torch.tensor(edge_index, dtype=torch.long).t().contiguous()
        edge_attr_tensor = torch.stack(edge_attr, dim=0)

    else:
        # No edges, create dummy tensors to handle this case
        edge_index_tensor = torch.empty((2, 0), dtype=torch.long)
        edge_attr_tensor = torch.empty((0, num_bond_types), dtype=torch.float)
        # return None

    if x:
        node_features_tensor = torch.stack(x, dim=0)
    else:
        # return None
        node_features_tensor = torch.empty((0, num_atom_types), dtype=torch.float)

    # Create a PyTorch Geometric Data object
    # if grad:
    #     node_features_tensor.requires_grad_(True)
    #     edge_attr.requires_grad_(True)
    graph_data = Data(x=node_features_tensor, edge_index=edge_index_tensor, edge_attr=edge_attr_tensor)

    return graph_data

# %%
mols, counds = mol_sample(wgan.generator, batch_size)
# Out:
# 1/1 [==============================] - 0s 59ms/step
# Generating molecules: 100%|██████████| 32/32 [00:00<00:00, 34.05it/s]

# %%
print(mols[0])
# Out:
# Data(x=[29, 10], edge_index=[2, 381], edge_attr=[381])

# %%
atomic_mapping = {0: 6, 1: 7, 2:8, 3:9, 4:14, 5:15, 6:16, 7:17, 8:35, 9:53}

# %%
def get_molecule(datapoint):
    #atomic_numbers = datapoint.x.argmax(dim=1).tolist()
    atomic_numbers_unmapped = datapoint.x.argmax(dim=1).tolist()
    atomic_numbers = []
    for at in atomic_numbers_unmapped:
        atomic_numbers.append(atomic_mapping[at])
    # positions = datapoint.positions.numpy()
    positions = np.random.rand(len(atomic_numbers), 3) * 10  # Random positions within a 10x10x10 Å box

    molecule = Atoms(numbers=atomic_numbers, positions=positions)
    return molecule

@contextmanager
def suppress_stdout():
    with open(os.devnull, "w") as devnull:
        old_stdout = sys.stdout
        sys.stdout = devnull
        try:
            yield
        finally:
            sys.stdout = old_stdout

def get_dft(datapoint, De=0.242, re=0.74, alpha=1.5):
    molecule = get_molecule(datapoint)
    print('Molecule:', molecule)
    dft_calculator = MorsePotential(De=De, r0=re, alpha=alpha)
    molecule.set_calculator(dft_calculator)
    # energy = molecule.get_potential_energy()
    with suppress_stdout():
        opt = QuasiNewton(molecule)
        opt.run(fmax=0.02)
    optimized_energy = molecule.get_potential_energy()
    return optimized_energy

energy = get_dft(mols[0])

print(f'DFT Energy: {energy} eV')
# Out:
# Molecule: Atoms(symbols='OBrOSSiSBrI2NISiSNClP2NSO2NOFCOS2N', pbc=False)
# DFT Energy: -5.999999409890069 eV

# %%
class GraphEncoder(nn.Module):
    def __init__(self, input_dim, num_relations):
        super(GraphEncoder, self).__init__()
        self.rgcnconv1 = RGCNConv(input_dim, 512, num_relations=num_relations)
        self.rgcnconv2 = RGCNConv(512, 256, num_relations=num_relations)
        self.rgcnconv3 = RGCNConv(256, 128, num_relations=num_relations)

    def forward(self, x, edge_index, edge_attr):
        x = self.rgcnconv1(x, edge_index, edge_attr)
        x = nn.ReLU()(x)
        x = self.rgcnconv2(x, edge_index, edge_attr)
        x = nn.ReLU()(x)
        x = self.rgcnconv3(x, edge_index, edge_attr)
        x = nn.ReLU()(x)
        return x

class BioClassifier(nn.Module):
    def __init__(self, input_dim, num_heads):
        super(BioClassifier, self).__init__()

        self.encoder = GraphEncoder(input_dim, num_heads)
        self.fc1 = nn.Linear(128, 64)
        self.bn1 = nn.BatchNorm1d(64)
        self.fc2 = nn.Linear(64, 1)
        self.dropout = nn.Dropout(0.4)

    def forward(self, data):
        x, edge_index, edge_attr = data.x, data.edge_index, data.edge_attr
        x = x.float()

        x = self.encoder(x, edge_index, edge_attr)
        x = global_add_pool(x, data.batch)
        x = self.dropout(x)
        x = self.fc1(x)
        x = nn.ReLU()(x)
        x = self.bn1(x)
        x = self.dropout(x)
        x = self.fc2(x)
        x = torch.sigmoid(x)
        return x.squeeze(dim=1)

# %%
model_bio_eval = BioClassifier(10, 4)

state_dict = torch.load('models/rcgn_model_7428.pt')
model_bio_eval.load_state_dict(state_dict)

model_bio_eval.eval()
def get_model_prediction(datapoint):
    pred = model_bio_eval(datapoint)
    return pred.item()

# %%
dft = get_dft(mols[0])
y = get_model_prediction(mols[0]) * 100

print(f'DFT (remember negative is good): {dft}')
print(f'Chance of Biodgradability: {y:.2f}%')
# Out:
# Molecule: Atoms(symbols='OBrOSSiSBrI2NISiSNClP2NSO2NOFCOS2N', pbc=False)
# DFT (remember negative is good): -14.99999977448502
# Chance of Biodgradability: 0.00%
